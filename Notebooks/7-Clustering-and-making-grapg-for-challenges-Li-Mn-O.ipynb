# %%
import sys
from pyprojroot import here
sys.path.append(str(here()))
import dotenv
import os
import openai
from langchain_openai import ChatOpenAI, AzureChatOpenAI

# Load environment variables from .env file
dotenv.load_dotenv()

# Set Azure OpenAI credentials
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_EMBEDDING_DEPLOYMENT_NAME = os.getenv("AZURE_EMBEDDING_DEPLOYMENT_NAME") # Deployment name
AZURE_EMBEDDING_MODEL_NAME = os.getenv("AZURE_EMBEDDING_MODEL_NAME")  # Model name
AZURE_EMBEDDING_MODEL_VERSION = os.getenv("AZURE_EMBEDDING_MODEL_VERSION")  # Model version
AZURE_OPENAI_API_VERSION=os.getenv("AZURE_OPENAI_API_VERSION")

# %%
import json
data_dir = here("data/papers/Li-Mn-O")
input_file = os.path.join(data_dir, "d2dt01964g_synthesis_and_challenges.json")

with open(input_file, "r", encoding="utf-8") as f:
    synthesis_data = json.load(f)

challenges_info = synthesis_data.get("challenges_info", [])

# Prepare challenge and solution texts
challenge_texts = [c["challenge"]["description"] + " " + c["challenge"]["type"] + " " + c["challenge"]["impact"] for c in challenges_info]
solution_texts = [c["solution"]["description"] + " " + c["solution"]["methodology"] + " " + c["solution"]["effectiveness"] for c in challenges_info]
materials_names = [c["material"] for c in challenges_info]
stages = [c["stage"] for c in challenges_info]

print("Materials:", materials_names)
print("Stages:", stages)
print("Challenges:", challenge_texts)
print("Solutions:", solution_texts)
# Out:
# Materials: ['Li4Mn5O12', 'Li4Mn5O12', 'LiMn2O4', 'λ-MnO2']
# Stages: ['synthesis', 'testing', 'synthesis', 'application']
# Challenges: ['Achieving a chemically ordered spinel structure at low synthesis temperatures. structural Low synthesis temperatures may lead to local ionic disorder, where lithium and manganese ions occupy random positions, potentially affecting catalytic performance.', 'Amorphization of the catalyst surface during long-term stability testing. structural Amorphization may reduce the crystallinity of the surface, potentially affecting the long-term catalytic performance.', 'Achieving nanorod morphology with consistent size distribution. morphological Increased size of nanorods due to high-temperature synthesis conditions may reduce surface area and catalytic activity.', 'Lower surface area compared to LiMn2O4, potentially limiting catalytic activity. morphological Reduced surface area may decrease the accessibility of electrolytes to catalytic sites, impacting water oxidation efficiency.']
# Solutions: ['Synthesis performed at 280°C, significantly lower than conventional temperatures (400–700°C). Low-temperature solid-state reaction using γ-MnOOH precursor. Resulted in enhanced catalytic activity, but the end product may not be perfectly chemically ordered.', 'Characterization of the catalyst before and after stability testing to monitor changes. XPS and TEM analyses conducted after 12 hours of stability testing. Confirmed that Mn oxidation states and surface morphology largely remained intact, but amorphous regions were observed.', 'Optimization of synthesis temperature and precursor treatment. γ-MnOOH precursor treated at 300°C for 3 hours, followed by heat treatment at 750°C for 10 hours. Produced nanorods with diameters in the range of 75–175 nm, larger than Li4Mn5O12 nanorods.', 'Utilization of delithiated λ-MnO2 with structural flexibility. Delithiation of LiMn2O4 to form λ-MnO2, enhancing structural flexibility and catalytic performance. Outperformed LiMn2O4 in water oxidation activity despite lower surface area.']

# %%
import openai
from openai import AzureOpenAI

# Setup Azure client (new SDK structure)
client = AzureOpenAI(
    api_key=AZURE_OPENAI_API_KEY,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
)

# Embedding function using the new SDK
def get_embeddings(texts, deployment_name):
    embeddings = []
    for text in texts:
        response = client.embeddings.create(
            input=text,
            model=deployment_name,  # Must match your Azure deployment name
        )
        embeddings.append(response.data[0].embedding)
    return embeddings

# %%
challenge_embeddings_openai_embed = get_embeddings(challenge_texts, AZURE_EMBEDDING_DEPLOYMENT_NAME)
solution_embeddings_openai_embed = get_embeddings(solution_texts, AZURE_EMBEDDING_DEPLOYMENT_NAME)

# %%
challenge_embeddings_openai_embed
# Out:
# [[0.0004588415613397956,
#   0.02461986243724823,
#   0.021073848009109497,
#   -0.0310647115111351,
#   -0.034866902977228165,
#   0.03691631183028221,
#   -0.013220029883086681,
#   -0.021815409883856773,
#   -0.0006943718180991709,
#   -0.028395088389515877,
#   0.024983901530504227,
#   0.03670058399438858,
#   0.00026376015739515424,
#   0.019712070003151894,
#   -0.0005860868841409683,
#   0.013267220929265022,
#   0.024390652775764465,
#   0.021694062277674675,
#   0.01206049695611,
#   0.011251519434154034,
#   -0.030525393784046173,
#   -0.00891896989196539,
#   -0.008952677249908447,
#   -0.0004386171349324286,
#   -0.011224553920328617,
#   -0.022664835676550865,
#   0.006643722299486399,
#   -0.018323326483368874,
#   -0.0275726281106472,
#   0.020049143582582474,
#   0.018323326483368874,
#   -0.0016516611212864518,
#   -0.0156941507011652,
#   -0.010220074094831944,
#   -0.02618388459086418,
#   0.00043651042506098747,
#   0.011521179229021072,
#   -0.027882736176252365,
#   0.013307669200003147,
#   -0.02785577066242695,
#   0.02575243078172207,
#   0.0027302969247102737,
#   0.005713399033993483,
#   0.019348029047250748,
#   -0.013766089454293251,
#   0.006441478151828051,
#   -0.007536967750638723,
#   0.0313883014023304,
#   -0.004628021735697985,
#   0.004199938382953405,
#   0.030822018161416054,
#   0.011918925680220127,
#   -0.02449851669371128,
#   -0.003149953670799732,
#   -0.005002173595130444,
#   -0.026615338400006294,
#   0.012141394428908825,
#   0.010381869971752167,
#   -0.007233601529151201,
#   -0.010658269748091698,
#   0.010186366736888885,
#   0.006936976686120033,
#   -0.012269482016563416,
#   0.03324894979596138,
#   -0.008844813331961632,
#   -0.014952588826417923,
#   0.0046988073736429214,
#   0.0009176831226795912,
#   0.003889830317348242,
#   -0.002983102109283209,
#   0.014440236613154411,
#   0.018080633133649826,
#   -0.013375083915889263,
#   -0.024808622896671295,
#   0.0005089812912046909,
#   0.010348162613809109,
#   -0.0021994058042764664,
#   -0.012100945226848125,
#   0.0005789240822196007,
#   0.002667938359081745,
#   0.016610991209745407,
#   0.00027429370675235987,
#   -0.00758415786549449,
#   0.033356811851263046,
#   -0.004125781822949648,
#   0.023999646306037903,
#   -0.01030771341174841,
#   -0.011440280824899673,
#   -0.00978862028568983,
#   -0.007422362919896841,
#   -0.0016634586500003934,
#   0.01924016699194908,
# %%
# prepare the list of all JSON files for research papers
import json
import os
from tqdm.auto import tqdm

data_dir = here("data/papers/Li-Mn-O")

files = os.listdir(data_dir)
files = [f for f in files if f.endswith('_synthesis_and_challenges.json')]

#
challenge_texts = []
solution_texts = []
materials_names = []
stages = []

# Loop through each file and extract the relevant information
for file in tqdm(files):
    input_file = os.path.join(data_dir, file)

    with open(input_file, "r", encoding="utf-8") as f:
        synthesis_data = json.load(f)

    challenges_info = synthesis_data.get("challenges_info", [])

    # Prepare challenge and solution texts
    for c in challenges_info:
        challenge_texts.append(c.get("challenge", {}).get("description", "") + " " + c.get("challenge", {}).get("type", "") + " " + c.get("challenge", {}).get("impact", ""))
        solution_texts.append(c.get("solution", {}).get("description", "") + " " + c.get("solution", {}).get("methodology", "") + " " + c.get("solution", {}).get("effectiveness", ""))
        materials_names.append(c.get("material", ""))
        stages.append(c.get("stage", ""))
    

print("Num. of materials:", len(materials_names), "Materials:", materials_names)
print("Num. of stages:", len(stages), "Stages:", stages)
print("Num. of challenges:", len(challenge_texts), "Challenges:", challenge_texts)
print("Num. of solutions:", len(solution_texts), "Solutions:", solution_texts)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
# Num. of materials: 173 Materials: ['Li1.2Ni0.23Co0.12Mn0.5O2', 'Li1.2Ni0.23Co0.12Mn0.5O2', 'Li1.2Ni0.23Co0.12Mn0.5O2', 'Li1.2Ni0.23Co0.12Mn0.5O2', 'LiMn2−xTixO4', 'LiMn2−xTixO4', 'LiMnTiO4', 'LiNiVO4', 'LiMn2O4', 'Zn2SnO4', 'LiMn2O4 (Sample A)', 'LiMn2O4 (Sample A)', 'LiMn2O4', 'LiMn2O4', 'LiMn2O4', 'LiMn2O4', 'LiMn2O4', 'LixMn3−xO4', 'LiMn2O4', 'LiMn2O4', 'Li2MnO3', 'Li2MnO3', 'Li2MnO3', 'LiMn2O4', 'Li1−xMn2+xO4', 'LiMn2O4', 'LiMn2O4', 'LiₓMn₁₊ₓFe₂₋₂ₓO₄', 'LiₓMn₁₊ₓFe₂₋₂ₓO₄', 'LiₓMn₁₊ₓFe₂₋₂ₓO₄', 'LiMn2O4', 'Li4Mn5O12', 'Li4Mn5O12', 'Li4Mn5O12', 'LiCoxMn2−xO4', 'LiCoxMn2−xO4', 'LiCoxMn2−xO4', 'LiMnO2', 'LixMnO2 (x < 0.1)', 'LixMnO2 (x < 0.1)', 'Li1+δMn2O4 (0 ≤ δ ≤ 1)', 'Li1+δMn2O4 (0 ≤ δ ≤ 1)', 'Li1+δMn2O4 (0 ≤ δ ≤ 1)', 'CuMn2O4', 'LiMg0.5Mn1.5O4', 'LiCo0.5Mn1.5O4', 'CuMg0.5Mn1.5O4', 'LiMn2O4', 'LiMn2O4', 'LiMn2O4', 'LiMnO2', 'LiMnO2', 'orthorhombic LiMnO2', 'rock salt Li0.5Mn0.5O', 'spinel LiMn2O4', 'Li1.27Mn1.73O4', 'Protonated MnO2', 'Deuterated MnO2', 'Li2MnO3', 'Li2MnO3', 'Li2Mn1−xRuxO3 (x = 0.05, 0.1)', 'Li2Mn1−xRuxO3 (x = 0.05, 0.1)', 'Li2Mn1−xRuxO3 (x = 0.05, 0.1)', 'LiMn2-yCryO4', 'LiMn2-yCryO4', 'LiMn2-yCryO4', 'LiMn2O4', 'LiMn2O4', 'LiMn2O4', 'LiMn2O4', 
# Num. of stages: 173 Stages: ['application', 'application', 'application', 'characterization', 'characterization', 'application', 'synthesis', 'synthesis', 'application', 'synthesis', 'application', 'characterization', 'synthesis', 'characterization', 'testing', 'characterization', 'characterization', 'characterization', 'application', 'characterization', 'synthesis', 'characterization', 'post-processing', 'synthesis', 'application', 'synthesis', 'characterization', 'synthesis', 'characterization', 'testing', 'annealing', 'synthesis', 'characterization', 'application', 'synthesis', 'testing', 'post-processing', 'synthesis', 'characterization', 'application', 'synthesis', 'testing', 'application', 'synthesis', 'synthesis', 'synthesis', 'post-processing', 'synthesis', 'characterization', 'application', 'synthesis', 'application', 'electrochemical cycling', 'electrochemical cycling', 'electrochemical cycling', 'synthesis', 're-lithiation', 'characterization', 'synthesis', 'characterization', 'synthesis', 'application', 'characterization', 'application', 'synthesis', 'characterization', 'synthesis', 'characterization', 'characterization', 'application', 'testing', 'application', 'synthesis', 'synthesis', 'post-processing', 'characterization', 'synthesis', 'application', 'synthesis', 'characterization', 'application', 'application', 'testing', 'testing', 'synthesis', 'testing', 'synthesis', 'testing', 'application', 'synthesis', 'characterization', 'synthesis', 'characterization', 'application', 'characterization', 'modeling', 'synthesis', 'synthesis', 'application', 'application', 'application', 'synthesis', 'application', 'synthesis', 'testing', 'synthesis', 'application', 'testing', 'storage', 'storage', 'storage', 'synthesis', 'characterization', 'application', 'application', 'testing', 'characterization', 'application', 'characterization', 'synthesis', 'application', 'conversion to A-MnO2', 'structure determination', 'structure refinement', 'structure refinement', 'application', 'testing', 'application', 'synthesis', 'post-processing', 'characterization', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'characterization', 'application', 'characterization', 'testing', 'characterization', 'characterization', 'synthesis', 'synthesis', 'synthesis', 'application', 'application', 'synthesis', 'application', 'application', 'application', 'application', 'cycling', 'synthesis', 'synthesis', 'application', 'characterization', 'synthesis', 'testing', 'synthesis', 'application', 'application', 'characterization', 'simulation', 'application', 'testing', 'synthesis', 'testing', 'synthesis', 'characterization', 'application', 'testing']
# Num. of challenges: 173 Challenges: ['Severe capacity fade during cycling. performance Reduces the long-term energy storage capability of lithium-ion batteries, limiting their practical application.', 'Voltage decay during cycling, thought to originate from a transformation to a spinel-like phase at 3V. structural Voltage decay reduces the energy density and efficiency of the battery over time.', 'Poor cycle performance of F-doped material, retaining only ∼70% capacity after 200 cycles. performance Limits the long-term usability of the material in practical battery applications.', 'Difficulty in determining the crystallographic position of low-level dopants (F and Cr). procedural Complicates the understanding of the relationship between doping and electrochemical performance.', "The ordered structural model with lithium in tetrahedral 8a site and manganese and titanium in octahedral 16d site did not give satisfactory results for x ≥ 0.5. structural The inability to accurately model the cationic distribution affects the understanding of the material's structural properties and its potential applications.", "Substitution by non-magnetic d0 Ti4+ ions weakens the magnetic interactions between manganese ions. magnetic Weakening of magnetic interactions reduces the material's magnetic moment and affects its performance in applications requiring strong magnetic properties.", "Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. procedural High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance.", 'Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. chemical Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.', "Phase transition observed around 280–290 K with hysteresis, leading to a dramatic drop in conductivity. structural Limits the material's performance as a cathode in rechargeable Li-ion batteries, particularly at lower temperatures.", 'No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. chemical Limits the ability to achieve desired structural properties for specific applications.', "Capacity fading during cycling occurs in the higher charge voltage range (x < 0.45). structural This problem limits the material's long-term performance and reliability as a cathode in lithium-ion batteries.", 'Structural instability during lithium extraction leads to peak splitting in XRD patterns at higher charge depths (x = 0.25). structural This instability indicates a transition from a two-phase to a one-phase structure, which contributes to capacity fading.', 'Formation of Mn3O4 impurity during synthesis. chemical The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.', 'Difficulty in detecting and quantifying Mn3O4 impurity due to structural similarity with LiMn2O4. structural Undetected Mn3O4 impurities can lead to inaccurate assessment of material purity and performance.', 'Degradation of electrochemical performance due to Mn3O4 impurity. performance Lower specific capacity and rate capability in battery applications.', 'Overlapping peaks in PXRD patterns of LiMn2O4 and Mn3O4. instrumental Makes it difficult to distinguish between the two phases, leading to potential misidentification.', "Uncertainty in the experimentally-determined oxidation degree of manganese ions. chemical This uncertainty complicates the precise determination of the spinel unit-cell content, which is critical for understanding the material's structure and properties.", "Difficulty in determining lithium ion limits and distribution in the spinel structure. structural This challenge affects the understanding of the material's stoichiometry and its electrochemical performance.", 'Poor cyclability of the charge-discharge p ...
# Num. of solutions: 173 Solutions: ['Doping with 2% Cr improved cycle performance by ∼13%. Cationic substitution at the R3̅m metal (3a) site. Effective in enhancing cycle performance but resulted in a small reduction in capacity.', 'Cr doping suppressed voltage decay. Cationic substitution at the R3̅m metal (3a) site. Effective in reducing voltage decay, particularly during discharge, but did not enhance capacity.', 'F doping enhanced capacity and rate performance but worsened cycle stability. Anionic substitution at the R3̅m oxygen (6c) site. Improved initial capacity and rate performance but led to structural instability during cycling.', 'Used neutron powder diffraction (NPD) combined with Rietveld refinement to model dopant positions. High-resolution NPD data and structural modeling techniques. Provided insights into dopant positions but could not rule out the presence of minute amounts of dopants in secondary phases.', 'Introduced disorder in the cationic distribution to account for the observed electron density in the 8a and 16d sites. Refined structural models considering partial occupancy of Mn2+ in the 8a site alongside Li and Ti4+. The new model (Model 2) provided better agreement with bond valence sums and experimental data, though it contradicted previous XPS results.', 'Studied the temperature and magnetic field dependencies of magnetization to understand the impact of Ti substitution. Measured Field Cooled (FC) and Zero Field Cooled (ZFC) magnetization curves and fitted data using Curie–Weiss law. Confirmed the weakening of local antiferromagnetic interactions due to dilution of the Mn–O network by Ti4+ cations.', 'Used the Pechini method to prepare denser samples with better connectivity. Synthesized samples using a precursor gel method involving citric acid and ethylene glycol, followed by calcination and sintering. Pechini samples displayed lower porosity (18% vs. 30%) and better electrical conductivity compared to solid-state samples.', 'Proposed annealing at lower temperatures for very long durations or using low-temperature soft synthetic methods. Extended annealing and alternative synthesis routes. Partially effective; local to intermediate-range cation ordering can be increased, but long-range ordering remains challenging.', 'Investigated local and long-range cation arrangements above the phase transition temperature to understand the behavior. Neutron PDF data collection and refinement of charge-ordered phase structure. Provided insights into short-range charge ordering persisting above the transition temperature, but further theoretical work is needed.', 'Refined short-range structure to confirm full cation ordering within one-unit cell length. Local structure refinement using neutron PDF data. Successfully identified short-range ordering but unable to achieve long-range ordering.', 'Use of nonstoichiometric spinel Li1+xMn2O4 (Sample B) synthesized via the melt-impregnation method. Modification of stoichiometry to introduce manganese vacancies in the spinel structure. Highly effective, as Sample B preserved about 98% of its initial capacity for the first 100 cycles compared to Sample A, which lost about 12%.', 'Adoption of nonstoichiometric spinel Li1+xMn2O4 (Sample B) with a homogeneous phase reaction over the entire intercalated range. Introduction of manganese vacancies to stabilize the structure during lithium extraction. Effective, as Sample B exhibited no peak splitting in XRD patterns over the examined region, indicating structural stability.', 'Careful control of synthesis parameters such as reaction time and precursor concentrations. Adjusting LiOH concentration and reaction time to minimize Mn3O4 formation. Partially effective; Mn3O4 content was reduced but not completely eliminated.', 'Use of Rietveld refinement and high-quality PXRD data to distinguish between phases. Application of Rietveld refinement to PXRD data instead of simple peak matching. Effective in identifying and quantifying Mn3O ...

# %%
# Create embeddings for all challenges and solutions
challenge_embeddings_openai_embed = get_embeddings(challenge_texts, AZURE_EMBEDDING_DEPLOYMENT_NAME)
solution_embeddings_openai_embed = get_embeddings(solution_texts, AZURE_EMBEDDING_DEPLOYMENT_NAME)

# %%
print("Num of embedding vectors in challenges:", len(challenge_embeddings_openai_embed), "shape of each vector:", len(challenge_embeddings_openai_embed[0]))
# Out:
# Num of embedding vectors in challenges: 173 shape of each vector: 1536

# %% [markdown]
# ⚠️ Challenges with High-Dimensional, Low-Sample-Size Data
# Curse of Dimensionality: In high-dimensional spaces, distances between points become less meaningful, making it difficult for clustering algorithms to identify distinct groups.​
#
# Small Sample Size: With only 14 samples, estimating reliable clusters becomes challenging, potentially leading to overfitting or identifying spurious clusters.​
#
# ✅ Recommended Approach
# To effectively apply Agglomerative Clustering to your dataset, consider the following steps:
#
# 1. Dimensionality Reduction
# Reduce the dimensionality of your data to mitigate the curse of dimensionality. Options include:​
#
# Principal Component Analysis (PCA): Linear technique that projects data onto directions of maximum variance.​
#
# Uniform Manifold Approximation and Projection (UMAP): Non-linear technique that preserves both local and global data structure, often yielding better clustering results in high-dimensional data.​
#
# t-Distributed Stochastic Neighbor Embedding (t-SNE): Non-linear technique that excels at preserving local structure but may distort global relationships.

# %%
from sklearn.decomposition import PCA

# Reduce dimensionality to 2 components
pca = PCA(n_components=2)
reduced_vectors_PCA = pca.fit_transform(challenge_embeddings_openai_embed)
reduced_vectors_PCA[0]
# Out:
# array([-0.25275564, -0.20023009])

# %%
import umap

# Reduce dimensionality to 2 components
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=42)
reduced_vectors_umap = reducer.fit_transform(challenge_embeddings_openai_embed)
reduced_vectors_umap[0]
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# array([4.6759615, 8.796318 ], dtype=float32)

# %%
# t-SNE
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Reduce dimensionality to 2 components using t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000, metric='cosine')
reduced_vectors_tsne = tsne.fit_transform(np.array(challenge_embeddings_openai_embed))

# Apply KMeans clustering on t-SNE reduced data
kmeans = KMeans(n_clusters=4, random_state=0)
labels_tsne = kmeans.fit_predict(reduced_vectors_tsne)
score = silhouette_score(reduced_vectors_tsne, labels_tsne)
print("Silhouette Score for t-SNE clustering:", score)
print("Silhouette Score:", score)

# Visualize the clusters

plt.figure(figsize=(10, 8))
plt.scatter(reduced_vectors_tsne[:, 0], reduced_vectors_tsne[:, 1], c=labels_tsne, cmap='Spectral', s=50)
plt.title('K-Means Clustering after t-SNE')
plt.colorbar(label='Cluster Label')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.show()
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Silhouette Score for t-SNE clustering: 0.40183377
# Silhouette Score: 0.40183377

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

scores = []
# Compute silhouette score for different numbers of clusters
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    labels = kmeans.fit_predict(reduced_vectors_PCA)
    score = silhouette_score(reduced_vectors_PCA, labels)
    scores.append(score)
    print(f"Number of clusters: {n_clusters}, Silhouette Score: {score}")
# Out:
# Number of clusters: 2, Silhouette Score: 0.36412653290366526
# Number of clusters: 3, Silhouette Score: 0.4125154270862255
# Number of clusters: 4, Silhouette Score: 0.3747429309140724
# Number of clusters: 5, Silhouette Score: 0.35695998137229856
# Number of clusters: 6, Silhouette Score: 0.39273212264549917
# Number of clusters: 7, Silhouette Score: 0.3780880270868974
# Number of clusters: 8, Silhouette Score: 0.3545301770578756
# Number of clusters: 9, Silhouette Score: 0.363849781213491

# %%
import matplotlib.pyplot as plt

plt.plot(range(2, 10), scores, marker='o')
plt.title('Silhouette Scores vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
from sklearn.metrics import silhouette_score
scores = []
# Compute silhouette score for different numbers of clusters
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    labels = kmeans.fit_predict(reduced_vectors_umap)
    score = silhouette_score(reduced_vectors_umap, labels)
    scores.append(score)
    print(f"Number of clusters: {n_clusters}, Silhouette Score: {score}")
# Out:
# Number of clusters: 2, Silhouette Score: 0.44786494970321655
# Number of clusters: 3, Silhouette Score: 0.3757545053958893
# Number of clusters: 4, Silhouette Score: 0.45325323939323425
# Number of clusters: 5, Silhouette Score: 0.41755446791648865
# Number of clusters: 6, Silhouette Score: 0.39340782165527344
# Number of clusters: 7, Silhouette Score: 0.3900996744632721
# Number of clusters: 8, Silhouette Score: 0.357751727104187
# Number of clusters: 9, Silhouette Score: 0.348481684923172

# %%
import matplotlib.pyplot as plt

plt.plot(range(2, 10), scores, marker='o')
plt.title('Silhouette Scores vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# # KMeans clustering

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt


# Initialize KMeans
kmeans = KMeans(n_clusters=4, random_state=0)

# Fit the model
kmeans.fit(reduced_vectors_PCA)

# Predict the clusters
labels = kmeans.predict(reduced_vectors_PCA)

# Cluster centers
centroids = kmeans.cluster_centers_

# %%
print(centroids.shape)
print(centroids)
print(labels)

challenge = 0
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# (4, 2)
# [[ 0.18922554 -0.10247485]
#  [-0.13144823 -0.08617706]
#  [-0.03947959  0.12760514]
#  [ 0.07689948  0.02045092]]
# [1 1 1 0 3 2 3 3 1 3 1 1 2 2 1 3 2 3 1 0 3 0 3 2 1 3 0 3 3 3 2 2 0 1 2 1 2
#  2 0 3 0 0 1 3 2 2 3 2 0 2 2 3 2 1 3 2 2 0 3 0 3 1 3 1 3 0 3 0 0 2 2 2 2 2
#  2 0 2 1 2 0 2 1 2 1 2 1 2 1 1 0 3 2 0 1 0 3 3 3 1 1 1 3 1 0 0 2 2 1 1 2 1
#  2 0 2 1 1 1 1 3 2 2 2 3 0 0 1 1 1 3 1 0 3 3 3 3 3 2 1 1 3 1 0 0 2 2 3 1 1
#  2 3 2 1 1 1 2 1 2 0 2 3 3 2 1 1 3 2 1 2 2 3 0 1 1]
# Challenge: Difficulty in determining the crystallographic position of low-level dopants (F and Cr). procedural Complicates the understanding of the relationship between doping and electrochemical performance.
# Challenge: Structural phase transition from cubic to tetragonal at 290 K in stoichiometric samples. structural Causes anomalies in resistivity and susceptibility, potentially affecting material stability and performance.
# Challenge: Discrepancies in modeling the experimental X-ray diffraction pattern profile and interpreting electron diffraction patterns. procedural Uncertainty in structural characterization affects the reliability of the material's structural model and its correlation with performance.
# Challenge: Presence of twinning in the orthorhombic phase at low temperatures. structural Twinning complicates the determination of the crystal structure and lattice parameters, affecting the accuracy of structural analysis.
# Challenge: Determining the distribution of lithium ions was difficult due to their weak X-ray scattering properties. procedural Accurate determination of lithium ion distribution is essential for understanding the material's electrochemical performance and structural stability.
# Challenge: Presence of additional spots indicating superlattice structure and diffuse scattering in X-ray precession photographs. structural These features suggest ordered local structure or short-range ordering, complicating the determination of the average structure.
# Challenge: Preparation of an extremely thick electrode with high active material loading for neutron diffraction studies. procedural High loading density is required to ensure sufficient material for neutron diffraction, but achieving this without compromising electrode performance is challenging.
# Challenge: Minimizing background noise in neutron diffraction data caused by hydrogen-rich components in the electrochemical cell. procedural High background noise can obscure critical structural information about the material under study.
# Challenge: Broadening and shifting of XRD peaks due to microstructural parameters such as small crystallite size and microstrain. structural Makes accurate refinement of cationic occupancy factors difficult, potentially affecting structural analysis.
# Challenge: Difficulty in directly determining the positions of hydrogen or deuterium atoms in the lattice. structural Lack of precise atomic positioning data limits understanding of the proton/deuteron insertion mechanism and its effects on the material's properties.
# Challenge: Difficulties in obtaining reasonable values for the Mn atomic magnetic moment during neutron diffraction analysis. procedural Inaccurate determination of magnetic moments can lead to incorrect modeling of the material's magnetic structure.
# Challenge: Difficulty in determining detailed structural information using X-ray diffraction alone. procedural Limited understanding of Cr substitution effects and structural properties, which are critical for optimizing performance.
# Challenge: Powder diffraction techniques do not fully resolve the true crystal symmetry and structural transition mechanism. structural Incomplete understanding of the structural phase transition and physical properties of the material.
# Challenge: Subtle alteration of diffraction intensities due to the complex structure comprising 504 atoms at 18 crystallographically independent sites in a unit cell of ~5000 Å³. structural This complexity makes accurate structural determination difficult, potentially leading to errors in understanding the material's properties.
# Challenge: Poor agreement in structural refinement due to elongated nuclear densities near oxygen atom sites. structural Elongated nuclear densities suggest static disorder of oxygen atoms, complicating accurate structural modeling.
# Challenge: Low scattering power of X-rays by lithium ions, making it difficult to determine their exact positions in the structure. procedural Complicates the structural refinement and accurate determination of lithium ion distribution.
# Challenge: Formation of multiphase systems during quenching due to temperature gradients and limited thermal conductivity. procedural Multiphase systems complicate structural analysis and reduce sample homogeneity.
# Challenge: Abnormal widening of the (110) diffraction line in X-ray powder diffraction diagrams, attributed to the mixing of a regular diffraction peak of the phase under study and poorly crystallized unreacted Mn2O3. structural This abnormal peak complicates the accurate structural refinement and modeling of the material.
# Challenge: Discrepancies in determining lithium ion content and distribution using different X-ray diffraction methods. procedural Inaccurate determination of lithium ion content and distribution affects the understanding of the material's structural properties and its application potential.
# Challenge: Small concentration of defects formed by gamma irradiation is difficult to detect in bulk samples using conventional XRD techniques. procedural Limits the ability to characterize and understand the influence of defects on the material's properties.
# Challenge: Nanometric samples exhibit different behavior compared to micrometric samples, with Jahn-Teller distortion absent in nanometric samples. structural Complicates the interpretation of results and the design of materials for specific applications.
# Challenge: Difficulty in achieving satisfactory fits using the inverse spinel model for quenched samples. structural This issue complicates the accurate determination of cation distribution and structural properties of the material.
# Challenge: Presence of microstructural effects causing underestimation of calculated intensities for certain reflections. microstructural Leads to discrepancies between observed and calculated diffraction patterns, reducing the accuracy of the refinement.
# Challenge: Negative isotropic thermal factor (Biso) value for the Li1 site. thermal/structural Anomalous thermal factor values can indicate issues with the structural model or data quality, potentially affecting the reliability of the refinement.
# Challenge: Low scattering power of lithium complicates precise refinement of Li positions from X-ray diffraction data. procedural Limits the accuracy of structural analysis and understanding of cation distribution.
# Challenge: High background noise in neutron diffraction data due to incoherent scattering from hydrogenous components in the electrolyte. procedural The high background noise could obscure diffraction peaks, reducing the accuracy of structural refinements.
# Challenge: Formation of mainly three twin components inside the crystal during structural analysis. structural The presence of twin components complicates the accurate measurement of intensity data and structural refinement.
# Challenge: Presence of protons introduced incoherent hydrogen scattering, complicating neutron diffraction refinement. procedural The incoherent scattering increased background noise, reducing the accuracy of structural refinement and site occupancy determination.
# Challenge: Broadening of XRD diffraction peaks with increasing cobalt content. structural Broadening indicates microstrain and smaller crystallite sizes, which can affect material performance.

# %%
challenge = 1
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Severe capacity fade during cycling. performance Reduces the long-term energy storage capability of lithium-ion batteries, limiting their practical application.
# Challenge: Voltage decay during cycling, thought to originate from a transformation to a spinel-like phase at 3V. structural Voltage decay reduces the energy density and efficiency of the battery over time.
# Challenge: Poor cycle performance of F-doped material, retaining only ∼70% capacity after 200 cycles. performance Limits the long-term usability of the material in practical battery applications.
# Challenge: Phase transition observed around 280–290 K with hysteresis, leading to a dramatic drop in conductivity. structural Limits the material's performance as a cathode in rechargeable Li-ion batteries, particularly at lower temperatures.
# Challenge: Capacity fading during cycling occurs in the higher charge voltage range (x < 0.45). structural This problem limits the material's long-term performance and reliability as a cathode in lithium-ion batteries.
# Challenge: Structural instability during lithium extraction leads to peak splitting in XRD patterns at higher charge depths (x = 0.25). structural This instability indicates a transition from a two-phase to a one-phase structure, which contributes to capacity fading.
# Challenge: Degradation of electrochemical performance due to Mn3O4 impurity. performance Lower specific capacity and rate capability in battery applications.
# Challenge: Poor cyclability of the charge-discharge process in the 4-V region. procedural Limits commercial applications of LiMn2O4 as a cathode material for rechargeable lithium batteries.
# Challenge: Sensitivity of phase transitions to lithium deficiency. chemical Even a small lithium deficit (0.02 Li) can induce phase transitions, which may compromise the material's performance and reliability in battery applications.
# Challenge: Structural changes caused by Jahn-Teller distortion upon deep discharging could degrade cycling performance. structural Jahn-Teller distortion leads to structural instability, reducing the material's effectiveness as a cathode in rechargeable batteries.
# Challenge: Decrease in discharge capacity (Qdis) at higher Co content (x = 1). electrochemical The reduced capacity limits the material's effectiveness as a high-energy-density electrode.
# Challenge: Irreversible phase transition at the 2.7 V plateau due to Jahn-Teller distortion of Mn3+ in the tetragonal phase. structural The distortion causes anisotropic strain, leading to particle fracture and internal contact loss upon cycling, which degrades battery performance.
# Challenge: Formation of rock salt phase is dependent on cycling rate, with higher current densities leading to larger quantities of rock salt structure. procedural Higher current densities hinder structural reordering of rock salt phase to spinel, potentially reducing battery performance.
# Challenge: High impedance in parent composition (x = 0.0) limits transport properties. electronic Reduced efficiency in applications requiring fast electron transport.
# Challenge: Fast capacity fading during charge/discharge cycling at relatively high temperatures (e.g., 55°C). procedural This problem significantly reduces the cycle stability and overall performance of the material as a cathode in lithium-ion batteries.
# Challenge: Capacity decline observed during cycling, particularly when cycling over both voltage plateaus. performance Capacity fade reduces the practical utility of the material as a rechargeable battery cathode.
# Challenge: Capacity fade due to particle cracking and pulverization during extended cycling. structural Leads to reduced cycle life and diminished electrochemical performance of the electrode.
# Challenge: Two-phase reaction of LiMO2 phase during charging leads to significant lattice mismatch and stress. structural Induces particle cracking and contributes to capacity fade over extended cycling.
# Challenge: Decreased electrical conductivity with increasing titanium content. electrical Lower electrical conductivity can reduce the efficiency of the electrode material in battery applications.
# Challenge: High capacity loss (~95 mAh/g) was observed during the first cycling of o-LiMnO2 electrodes. electrochemical The significant capacity loss reduces the initial performance and long-term reliability of the material as a cathode in Li-ion batteries.
# Challenge: Capacity fading in batteries using LiMn2O4 as an anode material due to phase transitions. structural Phase transitions lead to structural instability, reducing battery performance and lifespan.
# Challenge: High-temperature-prepared LiMnO2 materials generally exhibit poor electrochemical reactivity, leading to low capacities (~70 mAh/g). electrochemical Poor electrochemical performance limits the material's viability as a cathode in lithium rechargeable batteries.
# Challenge: High synthesis temperatures lead to ordered crystalline domains, which hinder the formation of smooth Li percolation paths. structural Reduced smooth Li percolation paths negatively affect Li utilization and battery capacity.
# Challenge: Severe capacity fading during long-term charge-discharge cycles. structural Capacity fading reduces the effectiveness and lifespan of the cathode material in lithium-ion batteries.
# Challenge: Capacity decay at high temperatures due to aggravated Jahn-Teller distortions and HF acid attack. chemical High-temperature cycling leads to faster degradation of the cathode material, limiting its performance in practical applications.
# Challenge: Presence of Jahn-Teller distortion significantly affects the reversibility of lithium insertion/deinsertion processes and creates high cell polarization even at low cycling currents. structural Reduces the efficiency and stability of the material when used as a cathode in lithium-ion batteries.
# Challenge: Cycling efficiency and lithium-ion diffusion rate are inferior compared to other electrodes when discharged at the same current density. procedural Reduced cycling efficiency and diffusion rate can limit the practical application of the material in lithium-ion batteries.
# Challenge: Significant capacity failure observed after high-temperature storage, particularly for shallow de-lithiated phases. structural The capacity failure reduces the effectiveness of the material as a cathode in lithium-ion batteries, limiting its practical application.
# Challenge: Fully charged state exhibits Mn dissolution and structural instability during high-temperature storage. chemical Mn dissolution reduces the material's capacity and leads to the formation of secondary phases, degrading battery performance.
# Challenge: Capacity fading upon cycling, which becomes severe at elevated temperatures (40°C). structural Reduces the long-term performance and reliability of the material as a cathode in lithium-ion batteries.
# Challenge: Discharge capacity reduces upon doping with Fe and Mg. chemical Limits the energy storage capacity of the material, which is a key performance metric for battery applications.
# Challenge: Particles are slightly agglomerated, reducing open surface area and increasing surface energy. morphological Agglomeration can lower packing density and bulk capacity, affecting battery performance.
# Challenge: Capacity fading due to structural instability induced by Jahn-Teller distortion and manganese dissolution via Mn3+ disproportionation reaction. structural Reduces the long-term electrochemical performance and stability of the cathode material in lithium-ion batteries.
# Challenge: Thermal decomposition of the material is accelerated in the presence of electrolyte. chemical This acceleration leads to structural instability and formation of secondary phases, which can compromise the safety and performance of lithium-ion batteries.
# Challenge: Defect sites in the fully charged state act as nucleation sites for new phases during thermal decomposition in the presence of electrolyte. structural These defect sites lead to the formation of undesirable secondary phases, reducing the material's stability and performance.
# Challenge: Thermal instability towards electrolyte in electrochemically delithiated state. chemical This instability leads to oxygen release and formation of secondary phases, compromising battery safety and performance.
# Challenge: Acid treatment causes partial dissolution of the solid and changes in chemical composition and XRD patterns. chemical Partial dissolution and lithium deintercalation can degrade the material's structural and electrochemical properties.
# Challenge: Significant stacking faults and cation mixing in the transition-metal layers. structural Structural defects can hinder lithium-ion migration and reduce electrochemical performance.
# Challenge: High Coulomb potential barriers caused by Mn4+ ions obstructing lithium-ion migration paths. chemical Reduced lithium-ion mobility negatively impacts charge-discharge capacity and overall battery performance.
# Challenge: Formation of a solid layer on the cathode surface during charging. chemical This layer could consume charge and affect the accuracy of lithium extraction measurements, potentially impacting battery performance.
# Challenge: Capacity fading becomes very fast for high Cr content (y=0.75). structural Rapid capacity fading limits the material's effectiveness as a positive electrode in lithium batteries.
# Challenge: Structural defects such as Td and 16c defects accumulate upon cycling, especially at high Cr content. structural Defects reduce the number of accessible sites for lithium ions, leading to capacity loss and lower battery performance.
# Challenge: High irreversible capacity loss with oxygen removal during the first charge. chemical This reduces the efficiency and energy density of the material, undermining its commercial viability for applications like electric vehicles.
# Challenge: Low electronic conductivity. structural Limits the rate capability and overall performance of the material in practical applications.
# Challenge: Inevitable phase transformation from layered to spinel phase during cycling. structural Degrades the structural stability and leads to capacity fade over cycles, reducing the lifespan of the material.
# Challenge: Acid treatment introduced significant amounts of protons, resulting in partial replacement of lithium by hydrogen and altering the stoichiometry. chemical The proton exchange affects the material's composition and structural stability, potentially impacting its electrochemical performance.
# Challenge: Formation of ordered Li/vacancy arrangement at x ≈ 0.5, leading to a two-phase coexistence reaction. structural This ordered arrangement causes a flat voltage profile, which can limit the performance and stability of the material in lithium-ion batteries.
# Challenge: Difficulty in accurately evaluating the molar amount of lithium ions removed during electrochemical measurements due to self-discharge reactions. procedural This introduces errors in determining the composition x, which affects the accuracy of entropy and potential measurements.
# Challenge: Structural changes after cycling due to the presence of Jahn–Teller active Mn3+ ions. structural Leads to battery failure and reduced cycling stability.
# Challenge: Reduction in initial charge capacity with increasing cobalt content. electrochemical Lower initial capacity reduces the energy density of the battery.
# Challenge: Phase transition near ambient temperature in undoped LiMn2O4. structural Phase transition leads to structural instability and capacity fading during cycling.

# %%
challenge = 2
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Substitution by non-magnetic d0 Ti4+ ions weakens the magnetic interactions between manganese ions. magnetic Weakening of magnetic interactions reduces the material's magnetic moment and affects its performance in applications requiring strong magnetic properties.
# Challenge: Formation of Mn3O4 impurity during synthesis. chemical The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.
# Challenge: Difficulty in detecting and quantifying Mn3O4 impurity due to structural similarity with LiMn2O4. structural Undetected Mn3O4 impurities can lead to inaccurate assessment of material purity and performance.
# Challenge: Uncertainty in the experimentally-determined oxidation degree of manganese ions. chemical This uncertainty complicates the precise determination of the spinel unit-cell content, which is critical for understanding the material's structure and properties.
# Challenge: Formation of tetragonal spinel phases during high-temperature synthesis. structural The tetragonal distortion affects the material's stability and electrochemical performance, which is critical for its application in lithium-ion batteries.
# Challenge: Formation of Mn2O3 as a second phase during annealing under oxygen pressure. chemical The presence of Mn2O3 changes the reaction scheme and introduces manganese vacancies in the spinel phase, potentially affecting the material's properties and performance.
# Challenge: The lattice parameter of Li4Mn5O12 was found to be sensitive to synthesis temperature due to variations in manganese valence. chemical This sensitivity affects the stoichiometry and structural integrity of the material, which is critical for its performance as a cathode material.
# Challenge: Presence of Li2MnO3 impurities in samples with x ≥ 0.75. chemical The impurities are electrochemically inactive, leading to a significant reduction in the rechargeable capacity (Qrech) and energy density (W).
# Challenge: Increase in Li2MnO3 impurity content with higher sintering temperatures for x = 1. procedural Higher impurity levels reduce the electrochemical activity and discharge capacity of the material.
# Challenge: Gradual and irreversible structural transformation of orthorhombic LiMnO2 into a spinel-type structure during several discharge-charge cycles. structural This structural change is generally unfavorable for practical applications as it affects the stability and performance of the electrode material.
# Challenge: Correct oxygen content could not be achieved during synthesis. chemical Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.
# Challenge: Correct oxygen content could not be achieved during synthesis. chemical Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.
# Challenge: Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. chemical Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.
# Challenge: Stoichiometry deviations in Li-rich spinel phase (Li1-yMn2-yO4) affecting conductivity and Jahn-Teller distortion behavior. chemical Small deviations in stoichiometry can lead to variations in conductivity and structural transitions, impacting performance in electrochemical applications.
# Challenge: Structural disorder caused by the presence of manganese ions in lithium positions (MnLi) and lithium ions in manganese ones (LiMn). structural This disorder affects the material's magnetic properties and contributes to the appearance of weak ferromagnetism, which may hinder its performance as a cathode material.
# Challenge: Irreversible phase transition from orthorhombic LiMnO2 to spinel LiMn2O4 and rock salt Li0.5Mn0.5O during cycling. structural This phase transition critically impacts charge and discharge capacity and cycle life, reducing the material's effectiveness as a cathode.
# Challenge: Reduction of tetravalent Mn above 400°C in air, making it difficult to obtain well-crystallized Mn4+ lithium manganate spinels. chemical This reduction compromises the high Mn4+ content and phase purity, which are critical for the material's intended applications.
# Challenge: Loss of oxygen during re-lithiation in LiOH solution, leading to slight oxygen deficiency in the relithiated spinel compound. chemical Oxygen deficiency affects the structural integrity and chemical properties of the relithiated material.
# Challenge: Poor transport property in the 3 × 3 × 1 superstructure due to the formation of a truncated square tessellation of Mn4+ ions, which immobilizes polarons via spin blockade. electronic This immobilization seriously affects the performance of Li-ion conduction, limiting the material's effectiveness as a cathode in Li-ion batteries.
# Challenge: Irreversible structural change during the first charge process, transforming orthorhombic HT-LiMnO2 into a new phase (Phase II). structural This structural change affects the electrochemical properties and limits the material's initial discharge capacity.
# Challenge: Complete conversion to spinel LiMn2O4 after the first charge without the intermediate transition to Phase II. structural This rapid conversion limits the ability to study intermediate phases and their contributions to electrochemical performance.
# Challenge: Presence of impurity phase (Li2MnO3) in the synthesized sample. chemical The impurity phase directly contributes to capacity loss in battery applications, as lithium extraction from Li2MnO3 is precluded due to the manganese ions already being in the Mn4+ oxidation state.
# Challenge: Oxygen loss during high-temperature quenching at 800°C and 925°C. chemical Oxygen loss alters the stoichiometry and structural integrity of the spinel phase, leading to the formation of an additional lithium-rich phase (Li2MnO3).
# Challenge: Oxygen vacancies induced by low-temperature ammonia treatment at 200°C. chemical Oxygen vacancies lead to a decrease in manganese oxidation state and structural changes, including increased atomic displacement parameters and altered stoichiometry.
# Challenge: The resulting products from synthesis using aqueous solutions often have stoichiometries differing from LiMnO2, contain water or protons, are of poor crystallinity, or do not maintain their structure during cycling. structural and chemical These issues compromise the material's performance and stability as a rechargeable battery electrode.
# Challenge: Difficulty in achieving complete lithium extraction beyond the composition Li0.5[Mn2]O4. procedural Limits the ability to fully delithiate the material, which is critical for its application as an electrode in lithium-ion batteries.
# Challenge: Phase transition observed near the composition Li0.5[Mn2]O4, with a sudden decrease in lattice parameter. structural Uncertainty in the nature of the phase transition affects the stability and performance of the material in battery applications.
# Challenge: Irreversible oxygen evolution reaction during charging beyond 4.5 V. chemical Results in structural decomposition of Li2MnO3 to MnO2-like phase, contributing to initial capacity loss and poor cycling performance.
# Challenge: Presence of MnO second phase in all samples. chemical The MnO second phase can negatively affect the purity and performance of the electrode material.
# Challenge: Conventional solid-state reaction methods for synthesizing o-LiMnO2 require high temperatures (700–1050 °C) and involve complicated powder preparation routes, including multiple calcination and physical grinding steps. procedural The complexity and high-temperature requirements make the synthesis process inefficient and less practical for large-scale production.
# Challenge: The synthesis of orthorhombic LiMnO2 cannot be performed under air due to its reaction with oxygen, leading to the formation of undesired phases like Li2MnO3 and LiMn2O4. chemical This reaction compromises the purity and stoichiometry of the desired LiMnO2 phase, affecting its structural and electrochemical properties.
# Challenge: Loss of oxygen during synthesis at higher temperatures and longer reaction times. chemical Oxygen loss alters the stoichiometry and stability of the material, potentially degrading its electrochemical properties.
# Challenge: Electrochemical reduction of Li2Mn4O9 to Li5Mn4O9 reduces manganese-ion valency and may induce structural changes. chemical Reduction in manganese valency can affect the cubic symmetry and stability of the electrode structure.
# Challenge: The shallow de-lithiated phase is highly unstable and undergoes significant decomposition during high-temperature storage. chemical Decomposition leads to phase transitions and Mn dissolution, which degrade the material's electrochemical performance.
# Challenge: Irreversible decomposition of the spinel phase occurs between 600°C and 800°C under N2 flow. chemical This decomposition leads to the formation of Mn3O4 and orthorhombic LiMnO2 phases, which compromises the stability and integrity of the spinel structure.
# Challenge: Oxygen release during high-temperature treatments leads to changes in cation distribution and oxidation states. chemical This affects the charge balance and stability of the spinel structure, potentially reducing its performance in applications like lithium-ion batteries.
# Challenge: Incomplete reaction when using lower valent manganese oxides or larger amounts of material. procedural Incomplete reaction leads to impurities and affects the purity and structural integrity of the synthesized material.
# Challenge: Metastable nature of A-MnO2 leads to reversion to more stable phases upon heating. structural Limits the thermal stability and long-term usability of A-MnO2 in high-temperature applications.
# Challenge: Incomplete conversion of LiMn2O4 to A-MnO2 at higher pH levels. chemical Residual lithium and manganese in lower oxidation states affect the purity and performance of A-MnO2.
# Challenge: Formation of materials away from the Li2MnO3−Li2NiO3 pseudobinary line during synthesis. procedural Deviation from the intended composition could affect the structural and electrochemical properties of the material.
# Challenge: Formation of single-phase Li4Mn5O12 at moderate temperatures is hindered by the rapid decomposition and complete oxidation of MnCO3 while only partly reacting with the Li2O component of Li2CO3. chemical This prevents the synthesis of a stoichiometric single-phase product, which is critical for achieving desired material properties.
# Challenge: The spinel product was lithium-deficient with vacancies on the tetrahedral 8a sites. structural Lithium deficiency and site vacancies can negatively affect the material's electrochemical performance and stability.
# Challenge: Incomplete oxidation of CaFeO2.5 to CaFeO3 due to limited concentration of sodium hypochlorite solution (6%). chemical Resulted in a mixture with only ~40% Fe4+ content, limiting the purity and effectiveness of the synthesized material.
# Challenge: Rapid dissolution and O2 evolution during acid treatment due to high redox potential of Ni4+ ions. chemical Complete dissolution of the solid within minutes, preventing isolation of the material for further use.
# Challenge: Low-temperature solid-state reaction consistently yielded products containing traces of unreacted lithium carbonate and/or manganese dioxide, broad X-ray reflections, and a manganese oxidation state much lower than the theoretical value of 4.0. chemical and structural The presence of unreacted reagents and broad reflections indicates incomplete reaction and poor crystallinity, which negatively affects the material's properties and performance.
# Challenge: Thermal decomposition of the proton-containing spinel occurred at 350°C in oxygen, leading to phase changes and loss of structural integrity. thermal stability The decomposition limits the material's operational temperature range and affects its long-term stability in applications.
# Challenge: Achieving a chemically ordered spinel structure at low synthesis temperatures. structural Low synthesis temperatures may lead to local ionic disorder, where lithium and manganese ions occupy random positions, potentially affecting catalytic performance.
# Challenge: Lower surface area compared to LiMn2O4, potentially limiting catalytic activity. morphological Reduced surface area may decrease the accessibility of electrolytes to catalytic sites, impacting water oxidation efficiency.
# Challenge: Electrochemical inactivity due to Mn in tetravalent oxidation state. chemical Limits the material's ability to function effectively as a cathode in lithium-ion batteries.
# Challenge: Formation of spinel phase during synthesis with increased aluminum substitution. structural Spinel phase formation alters the intended monoclinic structure, potentially affecting electrochemical performance.
# Challenge: Side reactions involving Mn3+ ions leading to Mn2+ dissolution in non-aqueous electrolytes. chemical Causes battery failure and reduces cycling stability due to loss of active material.

# %%
challenge = 3
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: The ordered structural model with lithium in tetrahedral 8a site and manganese and titanium in octahedral 16d site did not give satisfactory results for x ≥ 0.5. structural The inability to accurately model the cationic distribution affects the understanding of the material's structural properties and its potential applications.
# Challenge: Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. procedural High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance.
# Challenge: Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. chemical Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.
# Challenge: No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. chemical Limits the ability to achieve desired structural properties for specific applications.
# Challenge: Overlapping peaks in PXRD patterns of LiMn2O4 and Mn3O4. instrumental Makes it difficult to distinguish between the two phases, leading to potential misidentification.
# Challenge: Difficulty in determining lithium ion limits and distribution in the spinel structure. structural This challenge affects the understanding of the material's stoichiometry and its electrochemical performance.
# Challenge: The synthesis of a material free of stacking faults is not possible with the described synthesis routes. structural Stacking faults affect the structural integrity and potentially the performance of the material in its intended applications.
# Challenge: Presence of spinel-type defects at the surface of particles synthesized at high temperatures. chemical Surface defects can alter the material's electrochemical properties and reduce its performance in battery applications.
# Challenge: Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4. procedural The lack of high-quality single crystals hinders precise structural investigations and understanding of the material's properties.
# Challenge: Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure. procedural Deviation from optimal conditions can lead to the formation of multiple phases or incomplete reactions, compromising material properties.
# Challenge: Determining the site occupation of Mn ions in different oxidation states and their distribution between tetrahedral and octahedral sites. structural Uncertainty in cation distribution affects understanding of material properties and their correlation with magnetic behavior.
# Challenge: Expected increase in saturation magnetization (MS) with increasing x is not observed. magnetic Deviation from expected behavior complicates the correlation between cation distribution and magnetic properties.
# Challenge: Fragility and surface grooves observed in the delithiated crystals, along with a color change from black to brown. procedural These changes indicate potential mechanical instability and altered material properties, which could affect performance in practical applications.
# Challenge: Attempts to prepare pure samples of CuMn2O4 were unsuccessful. procedural The inability to synthesize pure samples limits the ability to study the material's properties and applications.
# Challenge: Rapid cooling during post-processing led to deviations in cation distribution. procedural Rapid cooling caused Mn ions to remain on A-sites, disrupting the ideal cation distribution and affecting magnetic properties.
# Challenge: Weak ferromagnetism observed in the antiferromagnetic phase at low temperatures. magnetic The weak ferromagnetic component could interfere with the material's magnetic stability and performance in applications requiring precise magnetic properties.
# Challenge: Spinel structure exhibits cationic disorder, with about 9% of Li positions occupied by Mn and vice versa. chemical Cationic disorder may affect electrochemical behavior and stability compared to the ordered phase.
# Challenge: Powder samples prepared by solid-state reaction showed significant cationic disorder with up to 3% Mn on the Li sites. chemical Cationic disorder can negatively affect the structural integrity and magnetic properties of the material, which are critical for its application.
# Challenge: Lattice distortion due to size mismatch between Ru+5 and Mn+3 ions. structural Distortion in the lattice affects the material's stability and properties.
# Challenge: Difficulty in confirming mixed valence states of Mn and Ru ions. chemical Uncertainty in understanding the redox mechanisms and material behavior.
# Challenge: Broadening of diffraction profiles dependent on Cr content, indicating structural strain and reduced crystallite size. structural Reduced crystallite size increases surface area, which can lead to Mn dissolution and negatively affect cycle performance.
# Challenge: Difficulty in synthesizing high-quality single crystals of LiMn2O4. procedural Poor quality single crystals hinder accurate structural and physical property investigations.
# Challenge: Difficulty in distinguishing between Mn2+ and Mn3+ ions using X-ray diffraction methods. chemical Inability to accurately determine manganese ion distribution affects understanding of structural stability.
# Challenge: Poor lattice parameter reproduction for binary oxide α-Mn2O3 using fitted interatomic potentials. chemical Inaccurate modeling of binary oxides affects the transferability and reliability of interatomic potentials for complex mixed-metal compounds.
# Challenge: Structural defects such as stacking faults and Li/Mn atomic mixing are prevalent in the synthesized material. structural These defects hinder precise structural analysis and affect the electrochemical behavior of the material.
# Challenge: At low synthesis temperatures, disordered domains dominate, containing a large number of stacking faults and significant Li/Mn atomic mixing. structural Disordered domains promote smooth Li percolation paths but lead to decreased structural order, affecting capacity and performance.
# Challenge: Determining the optimal Co3O4 coating amount for enhanced electrochemical performance. procedural Excessive Co3O4 coating adversely affects electrochemical performance, while insufficient coating fails to provide adequate protection.
# Challenge: Existence of a second phase with different lattice parameters, leading to spot splitting on the (400) plane. structural Complicates the crystallographic analysis and affects the prediction of battery performance.
# Challenge: Ambiguity in determining the correct monoclinic space group for Li2MnO3. structural Incorrect space group assignment could lead to inaccurate structural models and misinterpretation of the material's properties.
# Challenge: Non-stoichiometry in the synthesized oxides affects cation distribution and structural properties. chemical Non-stoichiometry leads to deviations in cation distribution, which can alter the material's structural integrity and its intended application.
# Challenge: No superstructure detected despite strong Mg–Mn chemical contrast. structural Absence of superstructure limits the ability to induce cation ordering, which is critical for optimizing material properties.
# Challenge: Extensive Li/Zn cation inversion observed, leading to additional high-frequency bands in IR and Raman spectra. chemical Cation inversion alters the structural symmetry and affects the material's electrochemical properties.
# Challenge: Presence of NiO impurity in synthesized sample. chemical Impurity reduces phase purity, which can negatively affect electrochemical performance and structural integrity.
# Challenge: Large batch synthesis resulted in significant fraction of unreacted CuO impurity. procedural Impurity compromises phase purity and structural integrity, affecting material performance.
# Challenge: Minor amounts of LiGa5O8 impurity detected in synthesized sample. chemical Impurity reduces phase purity, potentially affecting electrochemical performance and structural stability.
# Challenge: Discrepancies in lithium content measurements between electrochemical and crystallographic methods. procedural This discrepancy raises questions about the accuracy of lithium content determination, which is critical for understanding the material's electrochemical performance.
# Challenge: The spinel product exhibited vacancies on both tetrahedral and octahedral sites, indicating incomplete reaction and structural defects. structural Structural defects and site vacancies can compromise the material's stability and electrochemical properties.
# Challenge: Severe oxidative delithiation during acid treatment, leading to structural changes and reduction in layer spacing. structural Adverse crystal structure changes and reduced interlayer spacing from 4.73 Å to 4.32 Å, affecting material stability and performance.
# Challenge: Amorphization of the catalyst surface during long-term stability testing. structural Amorphization may reduce the crystallinity of the surface, potentially affecting the long-term catalytic performance.
# Challenge: Achieving nanorod morphology with consistent size distribution. morphological Increased size of nanorods due to high-temperature synthesis conditions may reduce surface area and catalytic activity.
# Challenge: Long computation times for Monte Carlo simulations due to the long-range nature of Coulombic interactions. computational This limits the efficiency of simulations and delays the determination of ground-state configurations for Li/vacancy ordering.
# Challenge: Formation of impurities during synthesis at low temperatures. chemical Impurities can negatively affect the structural and electrochemical properties of the material.

# %%
import matplotlib.pyplot as plt

plt.scatter(reduced_vectors_PCA[:, 0], reduced_vectors_PCA[:, 1], c=labels, cmap='Spectral', s=50)
plt.title('K-Means Clustering after PCA')
plt.colorbar(label='Cluster Label')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Evaluate clustering
silhouette = silhouette_score(reduced_vectors_PCA, labels)
davies_bouldin = davies_bouldin_score(reduced_vectors_PCA, labels)
calinski_harabasz = calinski_harabasz_score(reduced_vectors_PCA, labels)

print(f"Silhouette Score: {silhouette}")
print(f"Davies-Bouldin Index: {davies_bouldin}")
print(f"Calinski-Harabasz Index: {calinski_harabasz}")
# Out:
# Silhouette Score: 0.37474242044442535
# Davies-Bouldin Index: 0.8885286653807021
# Calinski-Harabasz Index: 159.05941795659493

# %% [markdown]
# 1. Silhouette Score (0.3935)
# The Silhouette Score measures how similar an object is to its own cluster compared to other clusters. It ranges from -1 to 1:​
# DZone
# +3
# Wikipedia
# +3
# Analytics Vidhya
# +3
#
# > 0.7: Strong structure
#
# 0.5 – 0.7: Reasonable structure
#
# 0.25 – 0.5: Weak structure
#
# < 0.25: No substantial structure​
# Wikipedia
# mishasv.com
# +6
# Wikipedia
# +6
# Wikipedia
# +6
# Communalytic
# +8
# Cross Validated
# +8
# Analytics Yogi
# +8
#
# A score of 0.3935 falls into the "weak structure" category, indicating that while there is some clustering structure, it's not particularly strong. ​
#
# 2. Davies-Bouldin Index (0.4722)
# The Davies-Bouldin Index evaluates the average similarity between each cluster and its most similar one, considering both cluster dispersion and separation. Lower values indicate better clustering.​
# GPTutorPro
#
# A score of 0.4722 is relatively low, suggesting that the clusters are compact and well-separated, which is favorable. ​
# GeeksforGeeks
#
# 3. Calinski-Harabasz Index (14.03)
# The Calinski-Harabasz Index assesses cluster dispersion; higher values signify better-defined clusters. However, this index is sensitive to the dataset's size and dimensionality.​
#
# A score of 14.03 is moderate. Without a benchmark or comparison to other clustering solutions on the same dataset, it's challenging to determine its adequacy.

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt


# Initialize KMeans
kmeans = KMeans(n_clusters=4, random_state=0)

# Fit the model
kmeans.fit(reduced_vectors_umap)

# Predict the clusters
labels = kmeans.predict(reduced_vectors_umap)

# Cluster centers
centroids = kmeans.cluster_centers_

# %%
import matplotlib.pyplot as plt

plt.scatter(reduced_vectors_umap[:, 0], reduced_vectors_umap[:, 1], c=labels, cmap='Spectral', s=50)
plt.title('K-Means Clustering after UMAP')
plt.colorbar(label='Cluster Label')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %%
challenge = 0
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Difficulty in determining the crystallographic position of low-level dopants (F and Cr). procedural Complicates the understanding of the relationship between doping and electrochemical performance.
# Challenge: The ordered structural model with lithium in tetrahedral 8a site and manganese and titanium in octahedral 16d site did not give satisfactory results for x ≥ 0.5. structural The inability to accurately model the cationic distribution affects the understanding of the material's structural properties and its potential applications.
# Challenge: Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. chemical Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.
# Challenge: No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. chemical Limits the ability to achieve desired structural properties for specific applications.
# Challenge: Difficulty in determining lithium ion limits and distribution in the spinel structure. structural This challenge affects the understanding of the material's stoichiometry and its electrochemical performance.
# Challenge: Structural phase transition from cubic to tetragonal at 290 K in stoichiometric samples. structural Causes anomalies in resistivity and susceptibility, potentially affecting material stability and performance.
# Challenge: Discrepancies in modeling the experimental X-ray diffraction pattern profile and interpreting electron diffraction patterns. procedural Uncertainty in structural characterization affects the reliability of the material's structural model and its correlation with performance.
# Challenge: Presence of twinning in the orthorhombic phase at low temperatures. structural Twinning complicates the determination of the crystal structure and lattice parameters, affecting the accuracy of structural analysis.
# Challenge: Expected increase in saturation magnetization (MS) with increasing x is not observed. magnetic Deviation from expected behavior complicates the correlation between cation distribution and magnetic properties.
# Challenge: Determining the distribution of lithium ions was difficult due to their weak X-ray scattering properties. procedural Accurate determination of lithium ion distribution is essential for understanding the material's electrochemical performance and structural stability.
# Challenge: Presence of additional spots indicating superlattice structure and diffuse scattering in X-ray precession photographs. structural These features suggest ordered local structure or short-range ordering, complicating the determination of the average structure.
# Challenge: Preparation of an extremely thick electrode with high active material loading for neutron diffraction studies. procedural High loading density is required to ensure sufficient material for neutron diffraction, but achieving this without compromising electrode performance is challenging.
# Challenge: Minimizing background noise in neutron diffraction data caused by hydrogen-rich components in the electrochemical cell. procedural High background noise can obscure critical structural information about the material under study.
# Challenge: Rapid cooling during post-processing led to deviations in cation distribution. procedural Rapid cooling caused Mn ions to remain on A-sites, disrupting the ideal cation distribution and affecting magnetic properties.
# Challenge: Broadening and shifting of XRD peaks due to microstructural parameters such as small crystallite size and microstrain. structural Makes accurate refinement of cationic occupancy factors difficult, potentially affecting structural analysis.
# Challenge: Difficulty in directly determining the positions of hydrogen or deuterium atoms in the lattice. structural Lack of precise atomic positioning data limits understanding of the proton/deuteron insertion mechanism and its effects on the material's properties.
# Challenge: Difficulties in obtaining reasonable values for the Mn atomic magnetic moment during neutron diffraction analysis. procedural Inaccurate determination of magnetic moments can lead to incorrect modeling of the material's magnetic structure.
# Challenge: Broadening of diffraction profiles dependent on Cr content, indicating structural strain and reduced crystallite size. structural Reduced crystallite size increases surface area, which can lead to Mn dissolution and negatively affect cycle performance.
# Challenge: Difficulty in determining detailed structural information using X-ray diffraction alone. procedural Limited understanding of Cr substitution effects and structural properties, which are critical for optimizing performance.
# Challenge: Powder diffraction techniques do not fully resolve the true crystal symmetry and structural transition mechanism. structural Incomplete understanding of the structural phase transition and physical properties of the material.
# Challenge: Subtle alteration of diffraction intensities due to the complex structure comprising 504 atoms at 18 crystallographically independent sites in a unit cell of ~5000 Å³. structural This complexity makes accurate structural determination difficult, potentially leading to errors in understanding the material's properties.
# Challenge: Poor agreement in structural refinement due to elongated nuclear densities near oxygen atom sites. structural Elongated nuclear densities suggest static disorder of oxygen atoms, complicating accurate structural modeling.
# Challenge: Low scattering power of X-rays by lithium ions, making it difficult to determine their exact positions in the structure. procedural Complicates the structural refinement and accurate determination of lithium ion distribution.
# Challenge: Formation of multiphase systems during quenching due to temperature gradients and limited thermal conductivity. procedural Multiphase systems complicate structural analysis and reduce sample homogeneity.
# Challenge: Difficulty in distinguishing between Mn2+ and Mn3+ ions using X-ray diffraction methods. chemical Inability to accurately determine manganese ion distribution affects understanding of structural stability.
# Challenge: Abnormal widening of the (110) diffraction line in X-ray powder diffraction diagrams, attributed to the mixing of a regular diffraction peak of the phase under study and poorly crystallized unreacted Mn2O3. structural This abnormal peak complicates the accurate structural refinement and modeling of the material.
# Challenge: Discrepancies in determining lithium ion content and distribution using different X-ray diffraction methods. procedural Inaccurate determination of lithium ion content and distribution affects the understanding of the material's structural properties and its application potential.
# Challenge: Small concentration of defects formed by gamma irradiation is difficult to detect in bulk samples using conventional XRD techniques. procedural Limits the ability to characterize and understand the influence of defects on the material's properties.
# Challenge: Nanometric samples exhibit different behavior compared to micrometric samples, with Jahn-Teller distortion absent in nanometric samples. structural Complicates the interpretation of results and the design of materials for specific applications.
# Challenge: Difficulty in achieving satisfactory fits using the inverse spinel model for quenched samples. structural This issue complicates the accurate determination of cation distribution and structural properties of the material.
# Challenge: Presence of microstructural effects causing underestimation of calculated intensities for certain reflections. microstructural Leads to discrepancies between observed and calculated diffraction patterns, reducing the accuracy of the refinement.
# Challenge: Negative isotropic thermal factor (Biso) value for the Li1 site. thermal/structural Anomalous thermal factor values can indicate issues with the structural model or data quality, potentially affecting the reliability of the refinement.
# Challenge: Low scattering power of lithium complicates precise refinement of Li positions from X-ray diffraction data. procedural Limits the accuracy of structural analysis and understanding of cation distribution.
# Challenge: No superstructure detected despite strong Mg–Mn chemical contrast. structural Absence of superstructure limits the ability to induce cation ordering, which is critical for optimizing material properties.
# Challenge: Discrepancies in lithium content measurements between electrochemical and crystallographic methods. procedural This discrepancy raises questions about the accuracy of lithium content determination, which is critical for understanding the material's electrochemical performance.
# Challenge: High background noise in neutron diffraction data due to incoherent scattering from hydrogenous components in the electrolyte. procedural The high background noise could obscure diffraction peaks, reducing the accuracy of structural refinements.
# Challenge: Formation of mainly three twin components inside the crystal during structural analysis. structural The presence of twin components complicates the accurate measurement of intensity data and structural refinement.
# Challenge: Presence of protons introduced incoherent hydrogen scattering, complicating neutron diffraction refinement. procedural The incoherent scattering increased background noise, reducing the accuracy of structural refinement and site occupancy determination.
# Challenge: Difficulty in accurately evaluating the molar amount of lithium ions removed during electrochemical measurements due to self-discharge reactions. procedural This introduces errors in determining the composition x, which affects the accuracy of entropy and potential measurements.
# Challenge: Long computation times for Monte Carlo simulations due to the long-range nature of Coulombic interactions. computational This limits the efficiency of simulations and delays the determination of ground-state configurations for Li/vacancy ordering.
# Challenge: Broadening of XRD diffraction peaks with increasing cobalt content. structural Broadening indicates microstrain and smaller crystallite sizes, which can affect material performance.

# %%
challenge = 1
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Presence of spinel-type defects at the surface of particles synthesized at high temperatures. chemical Surface defects can alter the material's electrochemical properties and reduce its performance in battery applications.
# Challenge: Formation of tetragonal spinel phases during high-temperature synthesis. structural The tetragonal distortion affects the material's stability and electrochemical performance, which is critical for its application in lithium-ion batteries.
# Challenge: Sensitivity of phase transitions to lithium deficiency. chemical Even a small lithium deficit (0.02 Li) can induce phase transitions, which may compromise the material's performance and reliability in battery applications.
# Challenge: Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4. procedural The lack of high-quality single crystals hinders precise structural investigations and understanding of the material's properties.
# Challenge: Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure. procedural Deviation from optimal conditions can lead to the formation of multiple phases or incomplete reactions, compromising material properties.
# Challenge: Formation of Mn2O3 as a second phase during annealing under oxygen pressure. chemical The presence of Mn2O3 changes the reaction scheme and introduces manganese vacancies in the spinel phase, potentially affecting the material's properties and performance.
# Challenge: Gradual and irreversible structural transformation of orthorhombic LiMnO2 into a spinel-type structure during several discharge-charge cycles. structural This structural change is generally unfavorable for practical applications as it affects the stability and performance of the electrode material.
# Challenge: Fragility and surface grooves observed in the delithiated crystals, along with a color change from black to brown. procedural These changes indicate potential mechanical instability and altered material properties, which could affect performance in practical applications.
# Challenge: Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. chemical Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.
# Challenge: Stoichiometry deviations in Li-rich spinel phase (Li1-yMn2-yO4) affecting conductivity and Jahn-Teller distortion behavior. chemical Small deviations in stoichiometry can lead to variations in conductivity and structural transitions, impacting performance in electrochemical applications.
# Challenge: Irreversible phase transition from orthorhombic LiMnO2 to spinel LiMn2O4 and rock salt Li0.5Mn0.5O during cycling. structural This phase transition critically impacts charge and discharge capacity and cycle life, reducing the material's effectiveness as a cathode.
# Challenge: Formation of rock salt phase is dependent on cycling rate, with higher current densities leading to larger quantities of rock salt structure. procedural Higher current densities hinder structural reordering of rock salt phase to spinel, potentially reducing battery performance.
# Challenge: Spinel structure exhibits cationic disorder, with about 9% of Li positions occupied by Mn and vice versa. chemical Cationic disorder may affect electrochemical behavior and stability compared to the ordered phase.
# Challenge: Reduction of tetravalent Mn above 400°C in air, making it difficult to obtain well-crystallized Mn4+ lithium manganate spinels. chemical This reduction compromises the high Mn4+ content and phase purity, which are critical for the material's intended applications.
# Challenge: Loss of oxygen during re-lithiation in LiOH solution, leading to slight oxygen deficiency in the relithiated spinel compound. chemical Oxygen deficiency affects the structural integrity and chemical properties of the relithiated material.
# Challenge: Irreversible structural change during the first charge process, transforming orthorhombic HT-LiMnO2 into a new phase (Phase II). structural This structural change affects the electrochemical properties and limits the material's initial discharge capacity.
# Challenge: Complete conversion to spinel LiMn2O4 after the first charge without the intermediate transition to Phase II. structural This rapid conversion limits the ability to study intermediate phases and their contributions to electrochemical performance.
# Challenge: Oxygen loss during high-temperature quenching at 800°C and 925°C. chemical Oxygen loss alters the stoichiometry and structural integrity of the spinel phase, leading to the formation of an additional lithium-rich phase (Li2MnO3).
# Challenge: Oxygen vacancies induced by low-temperature ammonia treatment at 200°C. chemical Oxygen vacancies lead to a decrease in manganese oxidation state and structural changes, including increased atomic displacement parameters and altered stoichiometry.
# Challenge: Phase transition observed near the composition Li0.5[Mn2]O4, with a sudden decrease in lattice parameter. structural Uncertainty in the nature of the phase transition affects the stability and performance of the material in battery applications.
# Challenge: Structural defects such as stacking faults and Li/Mn atomic mixing are prevalent in the synthesized material. structural These defects hinder precise structural analysis and affect the electrochemical behavior of the material.
# Challenge: At low synthesis temperatures, disordered domains dominate, containing a large number of stacking faults and significant Li/Mn atomic mixing. structural Disordered domains promote smooth Li percolation paths but lead to decreased structural order, affecting capacity and performance.
# Challenge: High synthesis temperatures lead to ordered crystalline domains, which hinder the formation of smooth Li percolation paths. structural Reduced smooth Li percolation paths negatively affect Li utilization and battery capacity.
# Challenge: Irreversible decomposition of the spinel phase occurs between 600°C and 800°C under N2 flow. chemical This decomposition leads to the formation of Mn3O4 and orthorhombic LiMnO2 phases, which compromises the stability and integrity of the spinel structure.
# Challenge: Oxygen release during high-temperature treatments leads to changes in cation distribution and oxidation states. chemical This affects the charge balance and stability of the spinel structure, potentially reducing its performance in applications like lithium-ion batteries.
# Challenge: Metastable nature of A-MnO2 leads to reversion to more stable phases upon heating. structural Limits the thermal stability and long-term usability of A-MnO2 in high-temperature applications.
# Challenge: Thermal decomposition of the material is accelerated in the presence of electrolyte. chemical This acceleration leads to structural instability and formation of secondary phases, which can compromise the safety and performance of lithium-ion batteries.
# Challenge: Defect sites in the fully charged state act as nucleation sites for new phases during thermal decomposition in the presence of electrolyte. structural These defect sites lead to the formation of undesirable secondary phases, reducing the material's stability and performance.
# Challenge: Acid treatment causes partial dissolution of the solid and changes in chemical composition and XRD patterns. chemical Partial dissolution and lithium deintercalation can degrade the material's structural and electrochemical properties.
# Challenge: Extensive Li/Zn cation inversion observed, leading to additional high-frequency bands in IR and Raman spectra. chemical Cation inversion alters the structural symmetry and affects the material's electrochemical properties.
# Challenge: The spinel product was lithium-deficient with vacancies on the tetrahedral 8a sites. structural Lithium deficiency and site vacancies can negatively affect the material's electrochemical performance and stability.
# Challenge: The spinel product exhibited vacancies on both tetrahedral and octahedral sites, indicating incomplete reaction and structural defects. structural Structural defects and site vacancies can compromise the material's stability and electrochemical properties.
# Challenge: Severe oxidative delithiation during acid treatment, leading to structural changes and reduction in layer spacing. structural Adverse crystal structure changes and reduced interlayer spacing from 4.73 Å to 4.32 Å, affecting material stability and performance.
# Challenge: Rapid dissolution and O2 evolution during acid treatment due to high redox potential of Ni4+ ions. chemical Complete dissolution of the solid within minutes, preventing isolation of the material for further use.
# Challenge: Acid treatment introduced significant amounts of protons, resulting in partial replacement of lithium by hydrogen and altering the stoichiometry. chemical The proton exchange affects the material's composition and structural stability, potentially impacting its electrochemical performance.
# Challenge: Thermal decomposition of the proton-containing spinel occurred at 350°C in oxygen, leading to phase changes and loss of structural integrity. thermal stability The decomposition limits the material's operational temperature range and affects its long-term stability in applications.
# Challenge: Achieving a chemically ordered spinel structure at low synthesis temperatures. structural Low synthesis temperatures may lead to local ionic disorder, where lithium and manganese ions occupy random positions, potentially affecting catalytic performance.
# Challenge: Formation of ordered Li/vacancy arrangement at x ≈ 0.5, leading to a two-phase coexistence reaction. structural This ordered arrangement causes a flat voltage profile, which can limit the performance and stability of the material in lithium-ion batteries.
# Challenge: Formation of spinel phase during synthesis with increased aluminum substitution. structural Spinel phase formation alters the intended monoclinic structure, potentially affecting electrochemical performance.

# %%
challenge = 2
for i in range(len(labels)):
    if labels[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Severe capacity fade during cycling. performance Reduces the long-term energy storage capability of lithium-ion batteries, limiting their practical application.
# Challenge: Voltage decay during cycling, thought to originate from a transformation to a spinel-like phase at 3V. structural Voltage decay reduces the energy density and efficiency of the battery over time.
# Challenge: Poor cycle performance of F-doped material, retaining only ∼70% capacity after 200 cycles. performance Limits the long-term usability of the material in practical battery applications.
# Challenge: Phase transition observed around 280–290 K with hysteresis, leading to a dramatic drop in conductivity. structural Limits the material's performance as a cathode in rechargeable Li-ion batteries, particularly at lower temperatures.
# Challenge: Capacity fading during cycling occurs in the higher charge voltage range (x < 0.45). structural This problem limits the material's long-term performance and reliability as a cathode in lithium-ion batteries.
# Challenge: Structural instability during lithium extraction leads to peak splitting in XRD patterns at higher charge depths (x = 0.25). structural This instability indicates a transition from a two-phase to a one-phase structure, which contributes to capacity fading.
# Challenge: Degradation of electrochemical performance due to Mn3O4 impurity. performance Lower specific capacity and rate capability in battery applications.
# Challenge: Poor cyclability of the charge-discharge process in the 4-V region. procedural Limits commercial applications of LiMn2O4 as a cathode material for rechargeable lithium batteries.
# Challenge: Structural changes caused by Jahn-Teller distortion upon deep discharging could degrade cycling performance. structural Jahn-Teller distortion leads to structural instability, reducing the material's effectiveness as a cathode in rechargeable batteries.
# Challenge: Decrease in discharge capacity (Qdis) at higher Co content (x = 1). electrochemical The reduced capacity limits the material's effectiveness as a high-energy-density electrode.
# Challenge: Irreversible phase transition at the 2.7 V plateau due to Jahn-Teller distortion of Mn3+ in the tetragonal phase. structural The distortion causes anisotropic strain, leading to particle fracture and internal contact loss upon cycling, which degrades battery performance.
# Challenge: High impedance in parent composition (x = 0.0) limits transport properties. electronic Reduced efficiency in applications requiring fast electron transport.
# Challenge: Fast capacity fading during charge/discharge cycling at relatively high temperatures (e.g., 55°C). procedural This problem significantly reduces the cycle stability and overall performance of the material as a cathode in lithium-ion batteries.
# Challenge: Poor transport property in the 3 × 3 × 1 superstructure due to the formation of a truncated square tessellation of Mn4+ ions, which immobilizes polarons via spin blockade. electronic This immobilization seriously affects the performance of Li-ion conduction, limiting the material's effectiveness as a cathode in Li-ion batteries.
# Challenge: Capacity decline observed during cycling, particularly when cycling over both voltage plateaus. performance Capacity fade reduces the practical utility of the material as a rechargeable battery cathode.
# Challenge: Capacity fade due to particle cracking and pulverization during extended cycling. structural Leads to reduced cycle life and diminished electrochemical performance of the electrode.
# Challenge: Irreversible oxygen evolution reaction during charging beyond 4.5 V. chemical Results in structural decomposition of Li2MnO3 to MnO2-like phase, contributing to initial capacity loss and poor cycling performance.
# Challenge: Two-phase reaction of LiMO2 phase during charging leads to significant lattice mismatch and stress. structural Induces particle cracking and contributes to capacity fade over extended cycling.
# Challenge: Decreased electrical conductivity with increasing titanium content. electrical Lower electrical conductivity can reduce the efficiency of the electrode material in battery applications.
# Challenge: High capacity loss (~95 mAh/g) was observed during the first cycling of o-LiMnO2 electrodes. electrochemical The significant capacity loss reduces the initial performance and long-term reliability of the material as a cathode in Li-ion batteries.
# Challenge: Capacity fading in batteries using LiMn2O4 as an anode material due to phase transitions. structural Phase transitions lead to structural instability, reducing battery performance and lifespan.
# Challenge: High-temperature-prepared LiMnO2 materials generally exhibit poor electrochemical reactivity, leading to low capacities (~70 mAh/g). electrochemical Poor electrochemical performance limits the material's viability as a cathode in lithium rechargeable batteries.
# Challenge: Severe capacity fading during long-term charge-discharge cycles. structural Capacity fading reduces the effectiveness and lifespan of the cathode material in lithium-ion batteries.
# Challenge: Capacity decay at high temperatures due to aggravated Jahn-Teller distortions and HF acid attack. chemical High-temperature cycling leads to faster degradation of the cathode material, limiting its performance in practical applications.
# Challenge: Determining the optimal Co3O4 coating amount for enhanced electrochemical performance. procedural Excessive Co3O4 coating adversely affects electrochemical performance, while insufficient coating fails to provide adequate protection.
# Challenge: Presence of Jahn-Teller distortion significantly affects the reversibility of lithium insertion/deinsertion processes and creates high cell polarization even at low cycling currents. structural Reduces the efficiency and stability of the material when used as a cathode in lithium-ion batteries.
# Challenge: Cycling efficiency and lithium-ion diffusion rate are inferior compared to other electrodes when discharged at the same current density. procedural Reduced cycling efficiency and diffusion rate can limit the practical application of the material in lithium-ion batteries.
# Challenge: Significant capacity failure observed after high-temperature storage, particularly for shallow de-lithiated phases. structural The capacity failure reduces the effectiveness of the material as a cathode in lithium-ion batteries, limiting its practical application.
# Challenge: The shallow de-lithiated phase is highly unstable and undergoes significant decomposition during high-temperature storage. chemical Decomposition leads to phase transitions and Mn dissolution, which degrade the material's electrochemical performance.
# Challenge: Fully charged state exhibits Mn dissolution and structural instability during high-temperature storage. chemical Mn dissolution reduces the material's capacity and leads to the formation of secondary phases, degrading battery performance.
# Challenge: Capacity fading upon cycling, which becomes severe at elevated temperatures (40°C). structural Reduces the long-term performance and reliability of the material as a cathode in lithium-ion batteries.
# Challenge: Discharge capacity reduces upon doping with Fe and Mg. chemical Limits the energy storage capacity of the material, which is a key performance metric for battery applications.
# Challenge: Capacity fading due to structural instability induced by Jahn-Teller distortion and manganese dissolution via Mn3+ disproportionation reaction. structural Reduces the long-term electrochemical performance and stability of the cathode material in lithium-ion batteries.
# Challenge: Existence of a second phase with different lattice parameters, leading to spot splitting on the (400) plane. structural Complicates the crystallographic analysis and affects the prediction of battery performance.
# Challenge: Thermal instability towards electrolyte in electrochemically delithiated state. chemical This instability leads to oxygen release and formation of secondary phases, compromising battery safety and performance.
# Challenge: Significant stacking faults and cation mixing in the transition-metal layers. structural Structural defects can hinder lithium-ion migration and reduce electrochemical performance.
# Challenge: High Coulomb potential barriers caused by Mn4+ ions obstructing lithium-ion migration paths. chemical Reduced lithium-ion mobility negatively impacts charge-discharge capacity and overall battery performance.
# Challenge: Formation of a solid layer on the cathode surface during charging. chemical This layer could consume charge and affect the accuracy of lithium extraction measurements, potentially impacting battery performance.
# Challenge: Capacity fading becomes very fast for high Cr content (y=0.75). structural Rapid capacity fading limits the material's effectiveness as a positive electrode in lithium batteries.
# Challenge: Structural defects such as Td and 16c defects accumulate upon cycling, especially at high Cr content. structural Defects reduce the number of accessible sites for lithium ions, leading to capacity loss and lower battery performance.
# Challenge: High irreversible capacity loss with oxygen removal during the first charge. chemical This reduces the efficiency and energy density of the material, undermining its commercial viability for applications like electric vehicles.
# Challenge: Low electronic conductivity. structural Limits the rate capability and overall performance of the material in practical applications.
# Challenge: Inevitable phase transformation from layered to spinel phase during cycling. structural Degrades the structural stability and leads to capacity fade over cycles, reducing the lifespan of the material.
# Challenge: Electrochemical inactivity due to Mn in tetravalent oxidation state. chemical Limits the material's ability to function effectively as a cathode in lithium-ion batteries.
# Challenge: Structural changes after cycling due to the presence of Jahn–Teller active Mn3+ ions. structural Leads to battery failure and reduced cycling stability.
# Challenge: Side reactions involving Mn3+ ions leading to Mn2+ dissolution in non-aqueous electrolytes. chemical Causes battery failure and reduces cycling stability due to loss of active material.
# Challenge: Reduction in initial charge capacity with increasing cobalt content. electrochemical Lower initial capacity reduces the energy density of the battery.
# Challenge: Phase transition near ambient temperature in undoped LiMn2O4. structural Phase transition leads to structural instability and capacity fading during cycling.

# %% [markdown]
# HDBSCAN (Hierarchical Density-Based Spatial Clustering of Applications with Noise) to cluster challenge and solution embeddings. HDBSCAN is particularly effective for datasets with clusters of varying densities and can identify noise points (outliers) that don't belong to any cluster.

# %%
# Initialize HDBSCAN with desired parameters
import hdbscan
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=3,       # Minimum size of clusters; adjust as needed
    min_samples=1,            # Minimum samples in a neighborhood for a point to be a core point
    metric='euclidean',       # Distance metric
    cluster_selection_method='eom'  # Method to select clusters
)

# Fit the model to your embeddings
labels_hdbscan = clusterer.fit_predict(reduced_vectors_PCA)
# Get the cluster labels
print(labels_hdbscan)
# Out:
# [ 1  5  2 15 31 27 22 29  5 31  2 14  7 12 16 23 12 29  9  8  8 -1 -1 17
#  25 -1  3 -1 24  8 -1 -1 15  4 11  5 11 11 19 22 -1 15 25 24  0  0 -1  0
#  18 27 10 31 16 26 27  6 -1 -1 30  3  8 14 23  2 22 19 23 19 18 17 11 11
#  -1 -1 21 -1 11  1 11 15 11  4 -1 -1 21  5  6  9  9 -1 24 -1  3 16 15 23
#  31 29 26  1  4 13  5 15 19 10  7  2  5 11 16  6  3 11  2 -1 -1 20 14 12
#  21  7 24 18 -1 20 13 -1 24 13 15  8 31 30  8 17 28 -1 -1 14  5 -1 -1  7
#  17 30  2  4 28 31 10  9 14 26 28 13 27 18 28 14 22 11 25 13 14 16 20 27
#  16 31 15  2 20]
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

plt.scatter(reduced_vectors_PCA[:, 0], reduced_vectors_PCA[:, 1], c=labels_hdbscan, cmap='Spectral', s=50)
plt.title('K-Means Clustering after PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
import hdbscan

# Try different combinations
for min_cluster_size in range(2, 6):
    for min_samples in range(1, min_cluster_size + 1):
        clusterer = hdbscan.HDBSCAN(
            min_cluster_size=min_cluster_size,
            min_samples=min_samples,
            metric='euclidean',
            cluster_selection_method='eom'
        )
        labels = clusterer.fit_predict(challenge_embeddings)
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise = list(labels).count(-1)
        print(f"min_cluster_size: {min_cluster_size}, min_samples: {min_samples}, "
              f"Clusters: {n_clusters}, Noise points: {n_noise}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 12
#       5 for min_samples in range(1, min_cluster_size + 1):
#       6     clusterer = hdbscan.HDBSCAN(
#       7         min_cluster_size=min_cluster_size,
#       8         min_samples=min_samples,
#       9         metric='euclidean',
#      10         cluster_selection_method='eom'
#      11     )
# ---> 12     labels = clusterer.fit_predict(challenge_embeddings)
#      13     n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
#      14     n_noise = list(labels).count(-1)
#
# NameError: name 'challenge_embeddings' is not defined

# %%
import umap
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Reduce dimensionality
reducer = umap.UMAP(n_components=2, random_state=42)
embedding_2d = reducer.fit_transform(reduced_vectors_PCA)

# Apply Agglomerative Clustering
clusterer = AgglomerativeClustering(n_clusters=4, linkage='average')
labels_agglomerative = clusterer.fit_predict(embedding_2d)

# Visualization
plt.scatter(embedding_2d[:, 0], embedding_2d[:, 1], c=labels_agglomerative, cmap='Spectral', s=50)
plt.title('Agglomerative Clustering Results')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.colorbar(label='Cluster Label')
plt.show()
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
challenge = 0
for i in range(len(labels_agglomerative)):
    if labels_agglomerative[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Difficulty in determining the crystallographic position of low-level dopants (F and Cr). procedural Complicates the understanding of the relationship between doping and electrochemical performance.
# Challenge: Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. procedural High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance.
# Challenge: Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. chemical Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.
# Challenge: Structural instability during lithium extraction leads to peak splitting in XRD patterns at higher charge depths (x = 0.25). structural This instability indicates a transition from a two-phase to a one-phase structure, which contributes to capacity fading.
# Challenge: Difficulty in determining lithium ion limits and distribution in the spinel structure. structural This challenge affects the understanding of the material's stoichiometry and its electrochemical performance.
# Challenge: Structural phase transition from cubic to tetragonal at 290 K in stoichiometric samples. structural Causes anomalies in resistivity and susceptibility, potentially affecting material stability and performance.
# Challenge: The synthesis of a material free of stacking faults is not possible with the described synthesis routes. structural Stacking faults affect the structural integrity and potentially the performance of the material in its intended applications.
# Challenge: Discrepancies in modeling the experimental X-ray diffraction pattern profile and interpreting electron diffraction patterns. procedural Uncertainty in structural characterization affects the reliability of the material's structural model and its correlation with performance.
# Challenge: Presence of spinel-type defects at the surface of particles synthesized at high temperatures. chemical Surface defects can alter the material's electrochemical properties and reduce its performance in battery applications.
# Challenge: Formation of tetragonal spinel phases during high-temperature synthesis. structural The tetragonal distortion affects the material's stability and electrochemical performance, which is critical for its application in lithium-ion batteries.
# Challenge: Presence of twinning in the orthorhombic phase at low temperatures. structural Twinning complicates the determination of the crystal structure and lattice parameters, affecting the accuracy of structural analysis.
# Challenge: Expected increase in saturation magnetization (MS) with increasing x is not observed. magnetic Deviation from expected behavior complicates the correlation between cation distribution and magnetic properties.
# Challenge: Determining the distribution of lithium ions was difficult due to their weak X-ray scattering properties. procedural Accurate determination of lithium ion distribution is essential for understanding the material's electrochemical performance and structural stability.
# Challenge: Presence of additional spots indicating superlattice structure and diffuse scattering in X-ray precession photographs. structural These features suggest ordered local structure or short-range ordering, complicating the determination of the average structure.
# Challenge: Fragility and surface grooves observed in the delithiated crystals, along with a color change from black to brown. procedural These changes indicate potential mechanical instability and altered material properties, which could affect performance in practical applications.
# Challenge: Preparation of an extremely thick electrode with high active material loading for neutron diffraction studies. procedural High loading density is required to ensure sufficient material for neutron diffraction, but achieving this without compromising electrode performance is challenging.
# Challenge: Minimizing background noise in neutron diffraction data caused by hydrogen-rich components in the electrochemical cell. procedural High background noise can obscure critical structural information about the material under study.
# Challenge: Broadening and shifting of XRD peaks due to microstructural parameters such as small crystallite size and microstrain. structural Makes accurate refinement of cationic occupancy factors difficult, potentially affecting structural analysis.
# Challenge: Difficulty in directly determining the positions of hydrogen or deuterium atoms in the lattice. structural Lack of precise atomic positioning data limits understanding of the proton/deuteron insertion mechanism and its effects on the material's properties.
# Challenge: Difficulties in obtaining reasonable values for the Mn atomic magnetic moment during neutron diffraction analysis. procedural Inaccurate determination of magnetic moments can lead to incorrect modeling of the material's magnetic structure.
# Challenge: Lattice distortion due to size mismatch between Ru+5 and Mn+3 ions. structural Distortion in the lattice affects the material's stability and properties.
# Challenge: High impedance in parent composition (x = 0.0) limits transport properties. electronic Reduced efficiency in applications requiring fast electron transport.
# Challenge: Broadening of diffraction profiles dependent on Cr content, indicating structural strain and reduced crystallite size. structural Reduced crystallite size increases surface area, which can lead to Mn dissolution and negatively affect cycle performance.
# Challenge: Difficulty in determining detailed structural information using X-ray diffraction alone. procedural Limited understanding of Cr substitution effects and structural properties, which are critical for optimizing performance.
# Challenge: Powder diffraction techniques do not fully resolve the true crystal symmetry and structural transition mechanism. structural Incomplete understanding of the structural phase transition and physical properties of the material.
# Challenge: Subtle alteration of diffraction intensities due to the complex structure comprising 504 atoms at 18 crystallographically independent sites in a unit cell of ~5000 Å³. structural This complexity makes accurate structural determination difficult, potentially leading to errors in understanding the material's properties.
# Challenge: Poor transport property in the 3 × 3 × 1 superstructure due to the formation of a truncated square tessellation of Mn4+ ions, which immobilizes polarons via spin blockade. electronic This immobilization seriously affects the performance of Li-ion conduction, limiting the material's effectiveness as a cathode in Li-ion batteries.
# Challenge: Poor agreement in structural refinement due to elongated nuclear densities near oxygen atom sites. structural Elongated nuclear densities suggest static disorder of oxygen atoms, complicating accurate structural modeling.
# Challenge: Low scattering power of X-rays by lithium ions, making it difficult to determine their exact positions in the structure. procedural Complicates the structural refinement and accurate determination of lithium ion distribution.
# Challenge: Formation of multiphase systems during quenching due to temperature gradients and limited thermal conductivity. procedural Multiphase systems complicate structural analysis and reduce sample homogeneity.
# Challenge: Abnormal widening of the (110) diffraction line in X-ray powder diffraction diagrams, attributed to the mixing of a regular diffraction peak of the phase under study and poorly crystallized unreacted Mn2O3. structural This abnormal peak complicates the accurate structural refinement and modeling of the material.
# Challenge: Discrepancies in determining lithium ion content and distribution using different X-ray diffraction methods. procedural Inaccurate determination of lithium ion content and distribution affects the understanding of the material's structural properties and its application potential.
# Challenge: Structural defects such as stacking faults and Li/Mn atomic mixing are prevalent in the synthesized material. structural These defects hinder precise structural analysis and affect the electrochemical behavior of the material.
# Challenge: At low synthesis temperatures, disordered domains dominate, containing a large number of stacking faults and significant Li/Mn atomic mixing. structural Disordered domains promote smooth Li percolation paths but lead to decreased structural order, affecting capacity and performance.
# Challenge: Small concentration of defects formed by gamma irradiation is difficult to detect in bulk samples using conventional XRD techniques. procedural Limits the ability to characterize and understand the influence of defects on the material's properties.
# Challenge: Nanometric samples exhibit different behavior compared to micrometric samples, with Jahn-Teller distortion absent in nanometric samples. structural Complicates the interpretation of results and the design of materials for specific applications.
# Challenge: Difficulty in achieving satisfactory fits using the inverse spinel model for quenched samples. structural This issue complicates the accurate determination of cation distribution and structural properties of the material.
# Challenge: Existence of a second phase with different lattice parameters, leading to spot splitting on the (400) plane. structural Complicates the crystallographic analysis and affects the prediction of battery performance.
# Challenge: Presence of microstructural effects causing underestimation of calculated intensities for certain reflections. microstructural Leads to discrepancies between observed and calculated diffraction patterns, reducing the accuracy of the refinement.
# Challenge: Negative isotropic thermal factor (Biso) value for the Li1 site. thermal/structural Anomalous thermal factor values can indicate issues with the structural model or data quality, potentially affecting the reliability of the refinement.
# Challenge: Low scattering power of lithium complicates precise refinement of Li positions from X-ray diffraction data. procedural Limits the accuracy of structural analysis and understanding of cation distribution.
# Challenge: No superstructure detected despite strong Mg–Mn chemical contrast. structural Absence of superstructure limits the ability to induce cation ordering, which is critical for optimizing material properties.
# Challenge: Extensive Li/Zn cation inversion observed, leading to additional high-frequency bands in IR and Raman spectra. chemical Cation inversion alters the structural symmetry and affects the material's electrochemical properties.
# Challenge: Large batch synthesis resulted in significant fraction of unreacted CuO impurity. procedural Impurity compromises phase purity and structural integrity, affecting material performance.
# Challenge: Minor amounts of LiGa5O8 impurity detected in synthesized sample. chemical Impurity reduces phase purity, potentially affecting electrochemical performance and structural stability.
# Challenge: Discrepancies in lithium content measurements between electrochemical and crystallographic methods. procedural This discrepancy raises questions about the accuracy of lithium content determination, which is critical for understanding the material's electrochemical performance.
# Challenge: High background noise in neutron diffraction data due to incoherent scattering from hydrogenous components in the electrolyte. procedural The high background noise could obscure diffraction peaks, reducing the accuracy of structural refinements.
# Challenge: Formation of mainly three twin components inside the crystal during structural analysis. structural The presence of twin components complicates the accurate measurement of intensity data and structural refinement.
# Challenge: The spinel product was lithium-deficient with vacancies on the tetrahedral 8a sites. structural Lithium deficiency and site vacancies can negatively affect the material's electrochemical performance and stability.
# Challenge: Severe oxidative delithiation during acid treatment, leading to structural changes and reduction in layer spacing. structural Adverse crystal structure changes and reduced interlayer spacing from 4.73 Å to 4.32 Å, affecting material stability and performance.
# Challenge: Low electronic conductivity. structural Limits the rate capability and overall performance of the material in practical applications.
# Challenge: Presence of protons introduced incoherent hydrogen scattering, complicating neutron diffraction refinement. procedural The incoherent scattering increased background noise, reducing the accuracy of structural refinement and site occupancy determination.
# Challenge: Amorphization of the catalyst surface during long-term stability testing. structural Amorphization may reduce the crystallinity of the surface, potentially affecting the long-term catalytic performance.
# Challenge: Achieving nanorod morphology with consistent size distribution. morphological Increased size of nanorods due to high-temperature synthesis conditions may reduce surface area and catalytic activity.
# Challenge: Long computation times for Monte Carlo simulations due to the long-range nature of Coulombic interactions. computational This limits the efficiency of simulations and delays the determination of ground-state configurations for Li/vacancy ordering.
# Challenge: Broadening of XRD diffraction peaks with increasing cobalt content. structural Broadening indicates microstrain and smaller crystallite sizes, which can affect material performance.

# %%
challenge = 1
for i in range(len(labels_agglomerative)):
    if labels_agglomerative[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: Severe capacity fade during cycling. performance Reduces the long-term energy storage capability of lithium-ion batteries, limiting their practical application.
# Challenge: Voltage decay during cycling, thought to originate from a transformation to a spinel-like phase at 3V. structural Voltage decay reduces the energy density and efficiency of the battery over time.
# Challenge: Poor cycle performance of F-doped material, retaining only ∼70% capacity after 200 cycles. performance Limits the long-term usability of the material in practical battery applications.
# Challenge: Phase transition observed around 280–290 K with hysteresis, leading to a dramatic drop in conductivity. structural Limits the material's performance as a cathode in rechargeable Li-ion batteries, particularly at lower temperatures.
# Challenge: Capacity fading during cycling occurs in the higher charge voltage range (x < 0.45). structural This problem limits the material's long-term performance and reliability as a cathode in lithium-ion batteries.
# Challenge: Poor cyclability of the charge-discharge process in the 4-V region. procedural Limits commercial applications of LiMn2O4 as a cathode material for rechargeable lithium batteries.
# Challenge: Sensitivity of phase transitions to lithium deficiency. chemical Even a small lithium deficit (0.02 Li) can induce phase transitions, which may compromise the material's performance and reliability in battery applications.
# Challenge: Structural changes caused by Jahn-Teller distortion upon deep discharging could degrade cycling performance. structural Jahn-Teller distortion leads to structural instability, reducing the material's effectiveness as a cathode in rechargeable batteries.
# Challenge: Decrease in discharge capacity (Qdis) at higher Co content (x = 1). electrochemical The reduced capacity limits the material's effectiveness as a high-energy-density electrode.
# Challenge: Irreversible phase transition at the 2.7 V plateau due to Jahn-Teller distortion of Mn3+ in the tetragonal phase. structural The distortion causes anisotropic strain, leading to particle fracture and internal contact loss upon cycling, which degrades battery performance.
# Challenge: Formation of rock salt phase is dependent on cycling rate, with higher current densities leading to larger quantities of rock salt structure. procedural Higher current densities hinder structural reordering of rock salt phase to spinel, potentially reducing battery performance.
# Challenge: Fast capacity fading during charge/discharge cycling at relatively high temperatures (e.g., 55°C). procedural This problem significantly reduces the cycle stability and overall performance of the material as a cathode in lithium-ion batteries.
# Challenge: Capacity decline observed during cycling, particularly when cycling over both voltage plateaus. performance Capacity fade reduces the practical utility of the material as a rechargeable battery cathode.
# Challenge: Capacity fade due to particle cracking and pulverization during extended cycling. structural Leads to reduced cycle life and diminished electrochemical performance of the electrode.
# Challenge: Two-phase reaction of LiMO2 phase during charging leads to significant lattice mismatch and stress. structural Induces particle cracking and contributes to capacity fade over extended cycling.
# Challenge: Decreased electrical conductivity with increasing titanium content. electrical Lower electrical conductivity can reduce the efficiency of the electrode material in battery applications.
# Challenge: High capacity loss (~95 mAh/g) was observed during the first cycling of o-LiMnO2 electrodes. electrochemical The significant capacity loss reduces the initial performance and long-term reliability of the material as a cathode in Li-ion batteries.
# Challenge: Capacity fading in batteries using LiMn2O4 as an anode material due to phase transitions. structural Phase transitions lead to structural instability, reducing battery performance and lifespan.
# Challenge: High synthesis temperatures lead to ordered crystalline domains, which hinder the formation of smooth Li percolation paths. structural Reduced smooth Li percolation paths negatively affect Li utilization and battery capacity.
# Challenge: Severe capacity fading during long-term charge-discharge cycles. structural Capacity fading reduces the effectiveness and lifespan of the cathode material in lithium-ion batteries.
# Challenge: Capacity decay at high temperatures due to aggravated Jahn-Teller distortions and HF acid attack. chemical High-temperature cycling leads to faster degradation of the cathode material, limiting its performance in practical applications.
# Challenge: Determining the optimal Co3O4 coating amount for enhanced electrochemical performance. procedural Excessive Co3O4 coating adversely affects electrochemical performance, while insufficient coating fails to provide adequate protection.
# Challenge: Presence of Jahn-Teller distortion significantly affects the reversibility of lithium insertion/deinsertion processes and creates high cell polarization even at low cycling currents. structural Reduces the efficiency and stability of the material when used as a cathode in lithium-ion batteries.
# Challenge: Cycling efficiency and lithium-ion diffusion rate are inferior compared to other electrodes when discharged at the same current density. procedural Reduced cycling efficiency and diffusion rate can limit the practical application of the material in lithium-ion batteries.
# Challenge: Significant capacity failure observed after high-temperature storage, particularly for shallow de-lithiated phases. structural The capacity failure reduces the effectiveness of the material as a cathode in lithium-ion batteries, limiting its practical application.
# Challenge: Capacity fading upon cycling, which becomes severe at elevated temperatures (40°C). structural Reduces the long-term performance and reliability of the material as a cathode in lithium-ion batteries.
# Challenge: Discharge capacity reduces upon doping with Fe and Mg. chemical Limits the energy storage capacity of the material, which is a key performance metric for battery applications.
# Challenge: Particles are slightly agglomerated, reducing open surface area and increasing surface energy. morphological Agglomeration can lower packing density and bulk capacity, affecting battery performance.
# Challenge: Capacity fading due to structural instability induced by Jahn-Teller distortion and manganese dissolution via Mn3+ disproportionation reaction. structural Reduces the long-term electrochemical performance and stability of the cathode material in lithium-ion batteries.
# Challenge: Thermal decomposition of the material is accelerated in the presence of electrolyte. chemical This acceleration leads to structural instability and formation of secondary phases, which can compromise the safety and performance of lithium-ion batteries.
# Challenge: Defect sites in the fully charged state act as nucleation sites for new phases during thermal decomposition in the presence of electrolyte. structural These defect sites lead to the formation of undesirable secondary phases, reducing the material's stability and performance.
# Challenge: Thermal instability towards electrolyte in electrochemically delithiated state. chemical This instability leads to oxygen release and formation of secondary phases, compromising battery safety and performance.
# Challenge: Acid treatment causes partial dissolution of the solid and changes in chemical composition and XRD patterns. chemical Partial dissolution and lithium deintercalation can degrade the material's structural and electrochemical properties.
# Challenge: Significant stacking faults and cation mixing in the transition-metal layers. structural Structural defects can hinder lithium-ion migration and reduce electrochemical performance.
# Challenge: High Coulomb potential barriers caused by Mn4+ ions obstructing lithium-ion migration paths. chemical Reduced lithium-ion mobility negatively impacts charge-discharge capacity and overall battery performance.
# Challenge: Formation of a solid layer on the cathode surface during charging. chemical This layer could consume charge and affect the accuracy of lithium extraction measurements, potentially impacting battery performance.
# Challenge: Capacity fading becomes very fast for high Cr content (y=0.75). structural Rapid capacity fading limits the material's effectiveness as a positive electrode in lithium batteries.
# Challenge: Structural defects such as Td and 16c defects accumulate upon cycling, especially at high Cr content. structural Defects reduce the number of accessible sites for lithium ions, leading to capacity loss and lower battery performance.
# Challenge: High irreversible capacity loss with oxygen removal during the first charge. chemical This reduces the efficiency and energy density of the material, undermining its commercial viability for applications like electric vehicles.
# Challenge: Inevitable phase transformation from layered to spinel phase during cycling. structural Degrades the structural stability and leads to capacity fade over cycles, reducing the lifespan of the material.
# Challenge: Acid treatment introduced significant amounts of protons, resulting in partial replacement of lithium by hydrogen and altering the stoichiometry. chemical The proton exchange affects the material's composition and structural stability, potentially impacting its electrochemical performance.
# Challenge: Formation of ordered Li/vacancy arrangement at x ≈ 0.5, leading to a two-phase coexistence reaction. structural This ordered arrangement causes a flat voltage profile, which can limit the performance and stability of the material in lithium-ion batteries.
# Challenge: Difficulty in accurately evaluating the molar amount of lithium ions removed during electrochemical measurements due to self-discharge reactions. procedural This introduces errors in determining the composition x, which affects the accuracy of entropy and potential measurements.
# Challenge: Structural changes after cycling due to the presence of Jahn–Teller active Mn3+ ions. structural Leads to battery failure and reduced cycling stability.
# Challenge: Reduction in initial charge capacity with increasing cobalt content. electrochemical Lower initial capacity reduces the energy density of the battery.
# Challenge: Phase transition near ambient temperature in undoped LiMn2O4. structural Phase transition leads to structural instability and capacity fading during cycling.

# %%
challenge = 2
for i in range(len(labels_agglomerative)):
    if labels_agglomerative[i] == challenge:
        print("Challenge:", challenge_texts[i])
# Out:
# Challenge: The ordered structural model with lithium in tetrahedral 8a site and manganese and titanium in octahedral 16d site did not give satisfactory results for x ≥ 0.5. structural The inability to accurately model the cationic distribution affects the understanding of the material's structural properties and its potential applications.
# Challenge: Substitution by non-magnetic d0 Ti4+ ions weakens the magnetic interactions between manganese ions. magnetic Weakening of magnetic interactions reduces the material's magnetic moment and affects its performance in applications requiring strong magnetic properties.
# Challenge: No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. chemical Limits the ability to achieve desired structural properties for specific applications.
# Challenge: Formation of Mn3O4 impurity during synthesis. chemical The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.
# Challenge: Difficulty in detecting and quantifying Mn3O4 impurity due to structural similarity with LiMn2O4. structural Undetected Mn3O4 impurities can lead to inaccurate assessment of material purity and performance.
# Challenge: Overlapping peaks in PXRD patterns of LiMn2O4 and Mn3O4. instrumental Makes it difficult to distinguish between the two phases, leading to potential misidentification.
# Challenge: Uncertainty in the experimentally-determined oxidation degree of manganese ions. chemical This uncertainty complicates the precise determination of the spinel unit-cell content, which is critical for understanding the material's structure and properties.
# Challenge: Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4. procedural The lack of high-quality single crystals hinders precise structural investigations and understanding of the material's properties.
# Challenge: Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure. procedural Deviation from optimal conditions can lead to the formation of multiple phases or incomplete reactions, compromising material properties.
# Challenge: Determining the site occupation of Mn ions in different oxidation states and their distribution between tetrahedral and octahedral sites. structural Uncertainty in cation distribution affects understanding of material properties and their correlation with magnetic behavior.
# Challenge: Formation of Mn2O3 as a second phase during annealing under oxygen pressure. chemical The presence of Mn2O3 changes the reaction scheme and introduces manganese vacancies in the spinel phase, potentially affecting the material's properties and performance.
# Challenge: The lattice parameter of Li4Mn5O12 was found to be sensitive to synthesis temperature due to variations in manganese valence. chemical This sensitivity affects the stoichiometry and structural integrity of the material, which is critical for its performance as a cathode material.
# Challenge: Attempts to prepare pure samples of CuMn2O4 were unsuccessful. procedural The inability to synthesize pure samples limits the ability to study the material's properties and applications.
# Challenge: Correct oxygen content could not be achieved during synthesis. chemical Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.
# Challenge: Correct oxygen content could not be achieved during synthesis. chemical Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.
# Challenge: Rapid cooling during post-processing led to deviations in cation distribution. procedural Rapid cooling caused Mn ions to remain on A-sites, disrupting the ideal cation distribution and affecting magnetic properties.
# Challenge: Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. chemical Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.
# Challenge: Stoichiometry deviations in Li-rich spinel phase (Li1-yMn2-yO4) affecting conductivity and Jahn-Teller distortion behavior. chemical Small deviations in stoichiometry can lead to variations in conductivity and structural transitions, impacting performance in electrochemical applications.
# Challenge: Weak ferromagnetism observed in the antiferromagnetic phase at low temperatures. magnetic The weak ferromagnetic component could interfere with the material's magnetic stability and performance in applications requiring precise magnetic properties.
# Challenge: Spinel structure exhibits cationic disorder, with about 9% of Li positions occupied by Mn and vice versa. chemical Cationic disorder may affect electrochemical behavior and stability compared to the ordered phase.
# Challenge: Reduction of tetravalent Mn above 400°C in air, making it difficult to obtain well-crystallized Mn4+ lithium manganate spinels. chemical This reduction compromises the high Mn4+ content and phase purity, which are critical for the material's intended applications.
# Challenge: Loss of oxygen during re-lithiation in LiOH solution, leading to slight oxygen deficiency in the relithiated spinel compound. chemical Oxygen deficiency affects the structural integrity and chemical properties of the relithiated material.
# Challenge: Powder samples prepared by solid-state reaction showed significant cationic disorder with up to 3% Mn on the Li sites. chemical Cationic disorder can negatively affect the structural integrity and magnetic properties of the material, which are critical for its application.
# Challenge: Difficulty in confirming mixed valence states of Mn and Ru ions. chemical Uncertainty in understanding the redox mechanisms and material behavior.
# Challenge: Difficulty in synthesizing high-quality single crystals of LiMn2O4. procedural Poor quality single crystals hinder accurate structural and physical property investigations.
# Challenge: Oxygen loss during high-temperature quenching at 800°C and 925°C. chemical Oxygen loss alters the stoichiometry and structural integrity of the spinel phase, leading to the formation of an additional lithium-rich phase (Li2MnO3).
# Challenge: Oxygen vacancies induced by low-temperature ammonia treatment at 200°C. chemical Oxygen vacancies lead to a decrease in manganese oxidation state and structural changes, including increased atomic displacement parameters and altered stoichiometry.
# Challenge: Presence of MnO second phase in all samples. chemical The MnO second phase can negatively affect the purity and performance of the electrode material.
# Challenge: Conventional solid-state reaction methods for synthesizing o-LiMnO2 require high temperatures (700–1050 °C) and involve complicated powder preparation routes, including multiple calcination and physical grinding steps. procedural The complexity and high-temperature requirements make the synthesis process inefficient and less practical for large-scale production.
# Challenge: Difficulty in distinguishing between Mn2+ and Mn3+ ions using X-ray diffraction methods. chemical Inability to accurately determine manganese ion distribution affects understanding of structural stability.
# Challenge: The synthesis of orthorhombic LiMnO2 cannot be performed under air due to its reaction with oxygen, leading to the formation of undesired phases like Li2MnO3 and LiMn2O4. chemical This reaction compromises the purity and stoichiometry of the desired LiMnO2 phase, affecting its structural and electrochemical properties.
# Challenge: Poor lattice parameter reproduction for binary oxide α-Mn2O3 using fitted interatomic potentials. chemical Inaccurate modeling of binary oxides affects the transferability and reliability of interatomic potentials for complex mixed-metal compounds.
# Challenge: Electrochemical reduction of Li2Mn4O9 to Li5Mn4O9 reduces manganese-ion valency and may induce structural changes. chemical Reduction in manganese valency can affect the cubic symmetry and stability of the electrode structure.
# Challenge: Irreversible decomposition of the spinel phase occurs between 600°C and 800°C under N2 flow. chemical This decomposition leads to the formation of Mn3O4 and orthorhombic LiMnO2 phases, which compromises the stability and integrity of the spinel structure.
# Challenge: Incomplete reaction when using lower valent manganese oxides or larger amounts of material. procedural Incomplete reaction leads to impurities and affects the purity and structural integrity of the synthesized material.
# Challenge: Metastable nature of A-MnO2 leads to reversion to more stable phases upon heating. structural Limits the thermal stability and long-term usability of A-MnO2 in high-temperature applications.
# Challenge: Incomplete conversion of LiMn2O4 to A-MnO2 at higher pH levels. chemical Residual lithium and manganese in lower oxidation states affect the purity and performance of A-MnO2.
# Challenge: Ambiguity in determining the correct monoclinic space group for Li2MnO3. structural Incorrect space group assignment could lead to inaccurate structural models and misinterpretation of the material's properties.
# Challenge: Non-stoichiometry in the synthesized oxides affects cation distribution and structural properties. chemical Non-stoichiometry leads to deviations in cation distribution, which can alter the material's structural integrity and its intended application.
# Challenge: Presence of NiO impurity in synthesized sample. chemical Impurity reduces phase purity, which can negatively affect electrochemical performance and structural integrity.
# Challenge: Formation of materials away from the Li2MnO3−Li2NiO3 pseudobinary line during synthesis. procedural Deviation from the intended composition could affect the structural and electrochemical properties of the material.
# Challenge: Formation of single-phase Li4Mn5O12 at moderate temperatures is hindered by the rapid decomposition and complete oxidation of MnCO3 while only partly reacting with the Li2O component of Li2CO3. chemical This prevents the synthesis of a stoichiometric single-phase product, which is critical for achieving desired material properties.
# Challenge: The spinel product exhibited vacancies on both tetrahedral and octahedral sites, indicating incomplete reaction and structural defects. structural Structural defects and site vacancies can compromise the material's stability and electrochemical properties.
# Challenge: Incomplete oxidation of CaFeO2.5 to CaFeO3 due to limited concentration of sodium hypochlorite solution (6%). chemical Resulted in a mixture with only ~40% Fe4+ content, limiting the purity and effectiveness of the synthesized material.
# Challenge: Low-temperature solid-state reaction consistently yielded products containing traces of unreacted lithium carbonate and/or manganese dioxide, broad X-ray reflections, and a manganese oxidation state much lower than the theoretical value of 4.0. chemical and structural The presence of unreacted reagents and broad reflections indicates incomplete reaction and poor crystallinity, which negatively affects the material's properties and performance.
# Challenge: Thermal decomposition of the proton-containing spinel occurred at 350°C in oxygen, leading to phase changes and loss of structural integrity. thermal stability The decomposition limits the material's operational temperature range and affects its long-term stability in applications.
# Challenge: Achieving a chemically ordered spinel structure at low synthesis temperatures. structural Low synthesis temperatures may lead to local ionic disorder, where lithium and manganese ions occupy random positions, potentially affecting catalytic performance.
# Challenge: Formation of spinel phase during synthesis with increased aluminum substitution. structural Spinel phase formation alters the intended monoclinic structure, potentially affecting electrochemical performance.
# Challenge: Formation of impurities during synthesis at low temperatures. chemical Impurities can negatively affect the structural and electrochemical properties of the material.

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Evaluate clustering
silhouette = silhouette_score(reduced_vectors_PCA, labels_agglomerative)
davies_bouldin = davies_bouldin_score(reduced_vectors_PCA, labels_agglomerative)
calinski_harabasz = calinski_harabasz_score(reduced_vectors_PCA, labels_agglomerative)

print(f"Silhouette Score: {silhouette}")
print(f"Davies-Bouldin Index: {davies_bouldin}")
print(f"Calinski-Harabasz Index: {calinski_harabasz}")
# Out:
# Silhouette Score: 0.3289840661566085
# Davies-Bouldin Index: 0.839089182247667
# Calinski-Harabasz Index: 131.5400574424726

# %% [markdown]
# # Other embedding models

# %% [markdown]
# other embedding models that are more suitable for scientific text. Here are some options:
#
# 1. SciBERT
# Description: SciBERT is a BERT-based model trained on scientific text, including papers from Semantic Scholar.
# Use Case: It is specifically designed for scientific and technical domains, making it a good choice for embedding scientific challenges and solutions.

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load SciBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
model = AutoModel.from_pretrained("allenai/scibert_scivocab_uncased")

# Function to get embeddings
def get_sci_embeddings(texts):
    embeddings = []
    for text in texts:
        inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
        with torch.no_grad():
            outputs = model(**inputs)
            # Use the [CLS] token embedding
            embeddings.append(outputs.last_hidden_state[:, 0, :].squeeze().numpy())
    return embeddings

# Example usage
challenge_embeddings_scibert = get_sci_embeddings(challenge_texts)
solution_embeddings_scibert = get_sci_embeddings(solution_texts)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from sklearn.decomposition import PCA

# Reduce dimensionality to 2 components
pca = PCA(n_components=2)
reduced_vectors_PCA_scibert = pca.fit_transform(challenge_embeddings_scibert)
reduced_vectors_PCA_scibert[0]
# Out:
# array([-0.20321822, -0.35377316])

# %%
import umap

# Reduce dimensionality to 2 components
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=42)
reduced_vectors_umap_scibert = reducer.fit_transform(challenge_embeddings_scibert)
reduced_vectors_umap_scibert[0]
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# array([12.010628 ,  5.4182577], dtype=float32)

# %%
from sklearn.metrics import silhouette_score
scores_scibert = []
# Compute silhouette score for different numbers of clusters
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    labels = kmeans.fit_predict(reduced_vectors_PCA_scibert)
    score = silhouette_score(reduced_vectors_PCA_scibert, labels)
    scores_scibert.append(score)
    print(f"Number of clusters: {n_clusters}, Silhouette Score: {score}")
# Out:
# Number of clusters: 2, Silhouette Score: 0.42215272325220177
# Number of clusters: 3, Silhouette Score: 0.49603568978771373
# Number of clusters: 4, Silhouette Score: 0.5002188228782743
# Number of clusters: 5, Silhouette Score: 0.4173917736600555
# Number of clusters: 6, Silhouette Score: 0.4185239664184955
# Number of clusters: 7, Silhouette Score: 0.39495730625792774
# Number of clusters: 8, Silhouette Score: 0.3627759907511732
# Number of clusters: 9, Silhouette Score: 0.36062929771302843

# %%
import matplotlib.pyplot as plt

plt.plot(range(2, 10), scores_scibert, marker='o')
plt.title('Silhouette Scores vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
silhouette_scores = []
davies_bouldin_scores = []
calinski_harabasz_scores = []
# Compute silhouette score for different numbers of clusters

# Evaluate clustering
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    labels = kmeans.fit_predict(reduced_vectors_PCA_scibert)
    silhouette = silhouette_score(reduced_vectors_PCA_scibert, labels)
    davies_bouldin = davies_bouldin_score(reduced_vectors_PCA_scibert, labels)
    calinski_harabasz = calinski_harabasz_score(reduced_vectors_PCA_scibert, labels)
    silhouette_scores.append(silhouette)
    davies_bouldin_scores.append(davies_bouldin)
    calinski_harabasz_scores.append(calinski_harabasz)
    print(f"Number of clusters: {n_clusters}, Silhouette Score: {silhouette}, Davies-Bouldin Index: {davies_bouldin}, Calinski-Harabasz Index: {calinski_harabasz}")
    # print(f"Silhouette Score: {silhouette}")
    # print(f"Davies-Bouldin Index: {davies_bouldin}")
    # print(f"Calinski-Harabasz Index: {calinski_harabasz}")
# Out:
# Number of clusters: 2, Silhouette Score: 0.42215272325220177, Davies-Bouldin Index: 0.9341002204994451, Calinski-Harabasz Index: 131.55709755995514
# Number of clusters: 3, Silhouette Score: 0.49603568978771373, Davies-Bouldin Index: 0.683749007363236, Calinski-Harabasz Index: 219.3909150694746
# Number of clusters: 4, Silhouette Score: 0.5002188228782743, Davies-Bouldin Index: 0.6771406726283784, Calinski-Harabasz Index: 224.8179653832529
# Number of clusters: 5, Silhouette Score: 0.4173917736600555, Davies-Bouldin Index: 0.8525007270940013, Calinski-Harabasz Index: 211.79940955854036
# Number of clusters: 6, Silhouette Score: 0.4185239664184955, Davies-Bouldin Index: 0.8120396716258925, Calinski-Harabasz Index: 197.98391253749077
# Number of clusters: 7, Silhouette Score: 0.39495730625792774, Davies-Bouldin Index: 0.7992272276305935, Calinski-Harabasz Index: 201.8219933011369
# Number of clusters: 8, Silhouette Score: 0.3627759907511732, Davies-Bouldin Index: 0.8732162569493518, Calinski-Harabasz Index: 200.60697080378182
# Number of clusters: 9, Silhouette Score: 0.36062929771302843, Davies-Bouldin Index: 0.8472392728211171, Calinski-Harabasz Index: 191.1249714753425

# %%
from sklearn.metrics import silhouette_score
scores_umap_scibert = []
# Compute silhouette score for different numbers of clusters
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    labels = kmeans.fit_predict(reduced_vectors_umap_scibert)
    score = silhouette_score(reduced_vectors_umap_scibert, labels)
    scores_umap_scibert.append(score)
    print(f"Number of clusters: {n_clusters}, Silhouette Score: {score}")
# Out:
# Number of clusters: 2, Silhouette Score: 0.45748892426490784
# Number of clusters: 3, Silhouette Score: 0.4891713857650757
# Number of clusters: 4, Silhouette Score: 0.4809879958629608
# Number of clusters: 5, Silhouette Score: 0.4132201671600342
# Number of clusters: 6, Silhouette Score: 0.39000359177589417
# Number of clusters: 7, Silhouette Score: 0.4080441892147064
# Number of clusters: 8, Silhouette Score: 0.38391396403312683
# Number of clusters: 9, Silhouette Score: 0.40087854862213135

# %% [markdown]
# # KMeans clustering

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt


# Initialize KMeans
kmeans = KMeans(n_clusters=4, random_state=0)

# Fit the model
kmeans.fit(reduced_vectors_PCA_scibert)

# Predict the clusters
labels = kmeans.predict(reduced_vectors_PCA_scibert)

# Cluster centers
centroids = kmeans.cluster_centers_

# %%
import matplotlib.pyplot as plt

plt.scatter(reduced_vectors_PCA_scibert[:, 0], reduced_vectors_PCA_scibert[:, 1], c=labels, cmap='Spectral', s=50)
plt.title('K-Means Clustering after PCA')
plt.colorbar(label='Cluster Label')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Evaluate clustering
silhouette = silhouette_score(reduced_vectors_PCA_scibert, labels)
davies_bouldin = davies_bouldin_score(reduced_vectors_PCA_scibert, labels)
calinski_harabasz = calinski_harabasz_score(reduced_vectors_PCA_scibert, labels)

print(f"Silhouette Score: {silhouette}")
print(f"Davies-Bouldin Index: {davies_bouldin}")
print(f"Calinski-Harabasz Index: {calinski_harabasz}")
# Out:
# Silhouette Score: 0.49603568978771373
# Davies-Bouldin Index: 0.683749007363236
# Calinski-Harabasz Index: 219.3909150694746

# %% [markdown]
# # Clustering solutions
