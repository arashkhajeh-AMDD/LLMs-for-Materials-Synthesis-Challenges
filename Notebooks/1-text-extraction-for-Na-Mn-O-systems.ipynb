# %%
from pyprojroot import here
import sys
sys.path.append(str(here()))
from src.utils.pymupdf_loader import PyMuPDFLoader

# %%
data_dir = here("data/papers/Na-Mn-O")
data_dir
# Out:
# PosixPath('/Users/arashkhajeh/GitHub/LLM-for-Materials/data/papers/Na-Mn-O')

# %%
pdf_loader = PyMuPDFLoader(data_dir)

# %%
pdf_texts = pdf_loader.load_pdfs()

# %%
print("No. of Loaded pdfs: " + str(len(pdf_texts)))
for i, pdf_text in enumerate(pdf_texts):
    print(f"PDF {i+1} Text: {pdf_text[:50]}...")  # Print first 100 characters of each PDF text
    print(f"PDF {i+1} Length: {len(pdf_text)}")
# Out:
# No. of Loaded pdfs: 6
# PDF 1 Text: P2−NaxCoyMn1−yO2 (y = 0, 0.1) as Cathode Materials...
# PDF 1 Length: 58628
# PDF 2 Text: Solid State Ionics 126 (1999) 3–24 www.elsevier.co...
# PDF 2 Length: 46213
# PDF 3 Text: Electrochimica Acta 212 (2016) 458–464 Contents li...
# PDF 3 Length: 34046
# PDF 4 Text: Nano Energy 76 (2020) 104997 Available online 20 J...
# PDF 4 Length: 62774
# PDF 5 Text: Nano Energy 76 (2020) 104997 Available online 20 J...
# PDF 5 Length: 62774
# PDF 6 Text: Contents lists available at ScienceDirect Journal ...
# PDF 6 Length: 43517

# %%
pdf_texts[0]
# Out:
# 'P2−NaxCoyMn1−yO2 (y = 0, 0.1) as Cathode Materials in Sodium-Ion Batteries\ue0d5Effects of Doping and Morphology To Enhance Cycling Stability Nicolas Bucher,∇,†,‡,§ Steffen Hartung,∇,†,‡,§ Joseph B. Franklin,∥Anna M. Wise,⊥Linda Y. Lim,⊥,# Han-Yi Chen,†,‡,§ Johanna Nelson Weker,⊥Michael F. Toney,⊥and Madhavi Srinivasan*,†,§,∥ †TUM CREATE, Singapore 138602, Singapore ‡Technical University of Munich, Garching 85748, Germany §School of Materials Science and Engineering, Nanyang Technological University, Singapore 639798, Singapore ∥Energy Research Institute at NTU (ERI@N), Nanyang Technological University, Research Techno Plaza, 50 Nanyang Drive, Singapore 637553, Singapore ⊥Stanford Synchrotron Radiation Lightsource, SLAC National Accelerator Laboratory, 2575 Sand Hill Road, Menlo Park, California 94025, United States #Department of Materials Science and Engineering, Stanford University, 496 Lomita Mall, Stanford, California 94305, United States * S Supporting Information ABSTRACT: Sodium-ion batteries have become a subject of increasing interest and are considered as an alternative to the ubiquitous lithium-ion battery. To compare the effect of two improvement strategies for metal oxide cathodes, specifically Codoping and morphology optimization, four representatives of the prominent material class of layered NaxMO2 (M = transition metal) have been studied: hexagonal flakes and hollow spheres of P2− NaxMnO2 and P2−NaxCo0.1Mn0.9O2. The better electrochemical performance of the spheres over the flakes and of the Co-doped over the undoped materials are explained on the basis of structural features revealed by operando synchrotron X-ray diffraction. The higher cycling stability of the material doped with ∼10% Co is attributed to three effects: (i) the suppression of a Jahn−Tellerinduced structural transition from the initial hexagonal to an orthorhombic phase that is observed in NaxMnO2; (ii) suppression of ordering processes of Na+; and (iii) enhanced Na+ kinetics as revealed by galvanostatic intermittent titration technique measurements and in situ electrochemical impedance measurements. Increased capacity and cycling stability of spheres over flakes may be related to smaller changes of the unit cell volume of spheres and thus to reduced structural stress. Co-doped spheres combine the advantages of both strategies and exhibit the best cycling stability. ■INTRODUCTION Sodium-ion batteries (NIBs) have received significant attention recently and are considered a viable alternative to the ubiquitous lithium-ion batteries (LIBs).1−5 NIBs have a cost advantage over LIBs for two main reasons. Na, unlike Li, does not alloy with Al in the anodic potential region. Thus, Cu, which is used as the anodic current collector in LIBs, can be replaced with the cheaper Al for NIBs.6−8 Second, Na resources are more widespread and abundant than Li-based raw materials.1,9 One of the most promising classes of cathode materials is layered oxides, NaxMO2 (M = transition metal).10,11 Within this class, there are several dominant subgroups, which are defined on the basis of the coordination of the Na-ions between the transition metal−oxygen layers. Following the nomenclature introduced by Delmas et al.,12 in O-type materials, Na+ is coordinated by oxygen octahedrally, whereas in P-type materials, the coordination is prismatic. Differences in stacking, i.e., shifts of the layers composed of edge-sharing MO6-octahedra against one another, are indicated by numbers. In a P2-structure, e.g., two layers of MO6octahedra need to be depicted in the unit cell to accurately describe the structure. The first studies on insertion processes into these layered oxides have been conducted in the 1980s.12−17 Recently, particularly P2-type materials have received considerable interest because of their good compromise regarding cycling stability and capacity.18−26 In these Received: November 23, 2015 Revised: March 14, 2016 Published: March 15, 2016 Article pubs.acs.org/cm © ...

# %%
# write the pdf_texts to a dictionary and write in a text file
file_path = here("data/papers/Na-Mn-O/Na-Mn-O-pymupdf.txt")
with open(file_path, "w") as f:
    for pdf_text in pdf_texts:
        f.write(pdf_text + "\n\n")

# %%
import os
# Load the pdfs one by one, make a dictionary with the pdf name as key and text as value
pdf_texts_dict = {}
folder_path = here("data/papers/Na-Mn-O")

for pdf_file_name in os.listdir(folder_path):
    # get file name without extension
    if not pdf_file_name.endswith(".pdf"):
        continue

    print(pdf_file_name)
    # Get the pdf name without the extension
    id = os.path.splitext(pdf_file_name)[0]
    print(f"Loading {id} ...")
    # Load the pdf text
    pdf_loader = PyMuPDFLoader(os.path.join(folder_path))
    pdf_text = pdf_loader.load_a_pdf(pdf_file_name)
    # Add the pdf text to the dictionary
    pdf_texts_dict[id] = pdf_text
# Write the pdf_texts_dict to a json file
import json
file_path = here("data/papers/Na-Mn-O/Na-Mn-O_dict.json")
with open(file_path, "w", encoding="utf-8") as f:
    json.dump(pdf_texts_dict, f, indent=4, ensure_ascii=False)
# Out:
# 000690060.pdf
# Loading 000690060 ...
# 040201870.pdf
# Loading 040201870 ...
# 010855392.pdf
# Loading 010855392 ...
# 000720518.pdf
# Loading 000720518 ...
# 000720519.pdf
# Loading 000720519 ...
# 010916740.pdf
# Loading 010916740 ...

# %% [markdown]
# Based on a detailed comparison of the three methods you used to extract text from the scientific PDF (as seen in the uploaded files), here’s a scoring and rationale for each, on a scale from 0 to 100:
#
# ✅ 1. **PyMuPDF (file: Na-Mn-O-pymupdf.txt) — **Score: 92/100
# Pros:
#
# Very clean and linear text flow.
#
# Good preservation of logical document structure.
#
# Figure and section headers are mostly correctly placed.
#
# Superscripts, subscripts, and special characters are normalized nicely.
#
# Cons:
#
# Occasionally introduces artifacts like "ﬁ" instead of "fi".
#
# Some minor layout inconsistencies in highly formatted sections (e.g., tables).
#
# 🟡 2. **pdfplumber (file: Na-Mn-O-pdfplumber.txt) — Score: 77/100
# Pros:
#
# Very good at preserving line-by-line formatting, particularly for figures/tables.
#
# Captures most numeric data with high fidelity.
#
# Cons:
#
# Excessive line breaks disrupt paragraph-level cohesion.
#
# Sometimes breaks mid-sentence due to hard carriage returns.
#
# Header/footer text sometimes intermingles with body content.
#
# 🔴 3. **PyPDF (file: Na-Mn-O-pypdf.txt) — Score: 54/100
# Pros:
#
# Extracts raw text with some semantic boundaries preserved.
#
# Cons:
#
# Frequent garbling of section labels and figure legends.
#
# Loss of whitespace and visual segmentation makes the text harder for LLMs to parse.
#
# Mixed or missing characters in special notation (e.g., chemical formulas, math).
#
# Overall less robust than the other two.
