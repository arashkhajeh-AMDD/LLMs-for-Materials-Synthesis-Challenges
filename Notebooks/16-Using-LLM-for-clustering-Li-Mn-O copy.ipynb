# %%
from pyprojroot import here
import json
import os
data_dir = here("data/papers/Li-Mn-O")

files = os.listdir(data_dir)
files = [f for f in files if f.endswith('_synthesis_and_challenges.json')]

print("Files:", files)
#
challenge_texts = []
solution_texts = []
materials_names = []
stages = []

# Loop through each file and extract the relevant information
for file in files:
    input_file = os.path.join(data_dir, file)

    with open(input_file, "r", encoding="utf-8") as f:
        synthesis_data = json.load(f)

    challenges_info = synthesis_data.get("challenges_info", [])

    # Prepare challenge and solution texts
    for c in challenges_info:
        if c.get("stage") == "synthesis":
            challenge_texts.append(c.get("challenge", {}).get("description", "") + " "  + c.get("challenge", {}).get("impact", ""))
            solution_texts.append(c.get("solution", {}).get("description", "") + " " + c.get("solution", {}).get("methodology", ""))
            materials_names.append(c.get("material", ""))
            stages.append(c.get("stage", ""))
    

print("Num. of materials:", len(materials_names), "Materials:", materials_names)
print("Num. of stages:", len(stages), "Stages:", stages)
print("Num. of challenges:", len(challenge_texts), "Challenges:", challenge_texts)
print("Num. of solutions:", len(solution_texts), "Solutions:", solution_texts)
# Out:
# Files: ['Zeitschrift anorg allge chemie - September 1975 - Hoppe - Zur Kenntnis der Oxomanganate III     ber LiMnO2 und  ‐NaMnO2  1_synthesis_and_challenges.json', 'pang-et-al-2017-effects-of-fluorine-and-chromium-doping-on-the-performance-of-lithium-rich-li1-xmo2-(m-ni-mn-co)_synthesis_and_challenges.json', '1-s2.0-S0167273806002165-main_synthesis_and_challenges.json', '1-s2.0-S0167273899002350-main_synthesis_and_challenges.json', 'liu-et-al-2019-unified-view-of-the-local-cation-ordered-state-in-inverse-spinel-oxides_synthesis_and_challenges.json', '1-s2.0-002245969580034M-main_synthesis_and_challenges.json', 'c5ce02358k_synthesis_and_challenges.json', '1-s2.0-S0097848500000607-main_synthesis_and_challenges.json', '1-s2.0-S0022459697973667-main_synthesis_and_challenges.json', '1-s2.0-S0167273809003646-main_synthesis_and_challenges.json', '1-s2.0-S0925838805003890-main_synthesis_and_challenges.json', 'akimoto-et-al-2000-single-crystal-x-ray-diffraction-study-of-the-spinel-type-limn2o4_synthesis_and_challenges.json', '1-s2.0-S0025540806000468-main_synthesis_and_challenges.json', '1-s2.0-S0022459696901760-main_synthesis_and_challenges.json', '1-s2.0-S0022459603001890-main_synthesis_and_challenges.json', '1-s2.0-S0022459697972820-main_synthesis_and_challenges.json', 'mukai-uyama-2017-toward-positive-electrode-materials-with-high-energy-density-electrochemical-and-structural-studies-on_synthesis_and_challenges.json', 'uchida-et-al-2003-synthesis-crystal-structure-and-magnetic-property-of-delithiated-lixmno2-(x-0-1)-single-crystals-a_synthesis_and_challenges.json', 'song-et-al-2018-metastable-li1-δmn2o4-(0-δ-1)-spinel-phases-revealed-by-in-operando-neutron-diffraction-and-first_synthesis_and_challenges.json', '1-s2.0-002236976690045X-main_synthesis_and_challenges.json', '1-s2.0-S0022459699984062-main_synthesis_and_challenges.json', '1-s2.0-S1293255806002779-main_synthesis_and_challenges.json', 's10008-007-0384-3_synthesis_and_challenges.json', 'thomas-et-al-1998-ion-exchange-in-manganese-dioxide-spinel-proton-deuteron-and-lithium-sites-determined-from-neutron_synthesis_and_challenges.json', '1-s2.0-0022459688903052-main_synthesis_and_challenges.json', 's42452-020-2260-z_synthesis_and_challenges.json', '1-s2.0-S0022459699983512-main_synthesis_and_challenges.json', '1-s2.0-S0022024801011903-main_synthesis_and_challenges.json', '2_4840IshizawaOA_synthesis_and_challenges.json', '1-s2.0-S016727380600703X-main_synthesis_and_challenges.json', 'a804851g_synthesis_and_challenges.json', '1-s2.0-002245968690068X-main_synthesis_and_challenges.json', '1-s2.0-S0022459697976118-main_synthesis_and_challenges.json', '381499a0_synthesis_and_challenges.json', '1-s2.0-0022459687903690-main_synthesis_and_challenges.json', 'chen-et-al-2016-the-origin-of-capacity-fade-in-the-li2mno3-limo2-(m-li-ni-co-mn)-microsphere-positive-electrode-an_synthesis_and_challenges.json', '1-s2.0-S0167273898003658-main_synthesis_and_challenges.json', '1-s2.0-S016727380200320X-main_synthesis_and_challenges.json', 'piszora-2006-structures-of-quenched-lixmn3-xo4-spinels_synthesis_and_challenges.json', 'jm9950501919_synthesis_and_challenges.json', '1-s2.0-0025540884900151-main_synthesis_and_challenges.json', '1-s2.0-S002245960098770X-main_synthesis_and_challenges.json', 'komatsu-et-al-2016-dependence-of-structural-defects-in-li2mno3-on-synthesis-temperature_synthesis_and_challenges.json', '1-s2.0-S0022459685711541-main_synthesis_and_challenges.json', '1-s2.0-S0925838816328821-main_synthesis_and_challenges.json', '1-s2.0-S0167273817310986-main_synthesis_and_challenges.json', '1-s2.0-002554089090032W-main_synthesis_and_challenges.json', '1-s2.0-S0167273802006926-main_synthesis_and_challenges.json', '1-s2.0-S0378775301006875-main_synthesis_and_challenges.json', '1-s2.0-S0038109802001497-main_synthesis_and_challenges.json', '1-s2.0-S0022459696971893-main_synthesis_and_challenges.json', '1-s2.0-S0921452609011909-main_synthesis_and_challenges.json', '1-s2.0-S0167273817310998-main_syn ...
# Num. of materials: 54 Materials: ['LiMnTiO4', 'LiNiVO4', 'Zn2SnO4', 'LiMn2O4', 'Li2MnO3', 'LiMn2O4', 'LiMn2O4', 'LiₓMn₁₊ₓFe₂₋₂ₓO₄', 'Li4Mn5O12', 'LiCoxMn2−xO4', 'LiMnO2', 'Li1+δMn2O4 (0 ≤ δ ≤ 1)', 'CuMn2O4', 'LiMg0.5Mn1.5O4', 'LiCo0.5Mn1.5O4', 'LiMn2O4', 'LiMnO2', 'Li1.27Mn1.73O4', 'Li2MnO3', 'Li2Mn1−xRuxO3 (x = 0.05, 0.1)', 'LiMn2-yCryO4', 'LiMn2O4', 'Li1+xMn2−xO4', 'Li1.05Mn2O4', 'LiMnO2', 'Li2[Mn2]O4', 'Li(MnTi)O', 'o-LiMnO2', 'LixMn3-xO4', 'LiMnO2', 'Li2MnO3', 'Li2MnO3', 'Co3O4-coated LiNi0.03Mn1.97O4', 'LiMn2O4', 'Li2Mn4O9', 'LiMn2O4', 'LiMn2O4', 'Li1-xNi1+xO2', 'LiMn1.5Mg0.5O4', 'LiMn1.5Zn0.5O4', 'LiMn1.5Ni0.5O4', 'LiMn1.5Cu0.5O4', 'LiMn1.5Ga0.5O4', 'Li2(NixMn1−x)O3(−δ)', 'Li4Mn5O12', 'Li2Mn3O7', 'Li2Mn4O9', 'CaFeO3', 'Li2Mn4O9', 'Li0.92HMn4O9', 'Li4Mn5O12', 'LiMn2O4', 'Li2MnO3', 'LiMn2−yCoyO4']
# Num. of stages: 54 Stages: ['synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis', 'synthesis']
# Num. of challenges: 54 Challenges: ["Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance.", 'Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.', 'No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. Limits the ability to achieve desired structural properties for specific applications.', 'Formation of Mn3O4 impurity during synthesis. The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.', 'The synthesis of a material free of stacking faults is not possible with the described synthesis routes. Stacking faults affect the structural integrity and potentially the performance of the material in its intended applications.', "Formation of tetragonal spinel phases during high-temperature synthesis. The tetragonal distortion affects the material's stability and electrochemical performance, which is critical for its application in lithium-ion batteries.", "Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4. The lack of high-quality single crystals hinders precise structural investigations and understanding of the material's properties.", 'Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure. Deviation from optimal conditions can lead to the formation of multiple phases or incomplete reactions, compromising material properties.', 'The lattice parameter of Li4Mn5O12 was found to be sensitive to synthesis temperature due to variations in manganese valence. This sensitivity affects the stoichiometry and structural integrity of the material, which is critical for its performance as a cathode material.', 'Presence of Li2MnO3 impurities in samples with x ≥ 0.75. The impurities are electrochemically inactive, leading to a significant reduction in the rechargeable capacity (Qrech) and energy density (W).', 'Gradual and irreversible structural transformation of orthorhombic LiMnO2 into a spinel-type structure during several discharge-charge cycles. This structural change is generally unfavorable for practical applications as it affects the stability and performance of the electrode material.', 'Preparation of an extremely thick electrode with high active material loading for neutron diffraction studies. High loading density is required to ensure sufficient material for neutron diffraction, but achieving this without compromising electrode performance is challenging.', "Attempts to prepare pure samples of CuMn2O4 were unsuccessful. The inability to synthesize pure samples limits the ability to study the material's properties and applications.", "Correct oxygen content could not be achieved during synthesis. Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.", "Correct oxygen content could not be achieved during synthesis. Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.", 'Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.', "Structural disorder caused by the presence of manganese ions in lithium positions (MnLi) and lithium ions in manganese ones (LiMn). This disorder affects the material's magnetic properties and contributes to the appearance of weak ferromagnetism, which may hinder its performance as a cathode material.", "Reduction of tetravalent Mn above 400°C ...
# Num. of solutions: 54 Solutions: ['Used the Pechini method to prepare denser samples with better connectivity. Synthesized samples using a precursor gel method involving citric acid and ethylene glycol, followed by calcination and sintering.', 'Proposed annealing at lower temperatures for very long durations or using low-temperature soft synthetic methods. Extended annealing and alternative synthesis routes.', 'Refined short-range structure to confirm full cation ordering within one-unit cell length. Local structure refinement using neutron PDF data.', 'Careful control of synthesis parameters such as reaction time and precursor concentrations. Adjusting LiOH concentration and reaction time to minimize Mn3O4 formation.', 'Increasing the synthesis temperature reduces the degree of disorder and stacking faults. Higher annealing temperatures were used during synthesis to improve crystallinity and reduce stacking faults.', 'Rapid quenching in solid CO2 after high-temperature synthesis. Cooling the samples quickly to preserve the high-temperature valence of manganese and avoid structural distortions.', 'A flux growth method was employed using a mixture of LiMn2O4 powder and lithium chloride in a sealed gold tube, heated at 1173 K for 10 days and gradually cooled to 297 K. Flux growth method with controlled heating and cooling in a sealed gold tube.', 'Thermal decomposition of freeze-dried format solutions followed by annealing under controlled oxygen partial pressure and temperature regime. Careful control of synthesis temperature (800–900°C) and quick cooling process.', 'Controlled synthesis conditions were employed, including slow heating and cooling under flowing oxygen to stabilize the manganese valence and achieve the desired stoichiometry. Heating at specific temperatures (e.g., 700°C) with controlled oxygen flow (200 ml/min) and slow cooling in the furnace.', 'Optimization of the Co/Mn ratio to x = 0.5, which avoids the formation of Li2MnO3 impurities. Systematic variation of x in the LiCoxMn2−xO4 composition and structural analysis using XRD and Raman spectroscopy.', 'Electrochemically generated spinel electrodes were found to exhibit significantly better and more stable charge-discharge cycle characteristics compared to regular spinel-type LiMn2O4 electrodes. Utilization of electrochemical cycling to stabilize the spinel structure and improve its performance.', 'A novel methodology was developed using aluminum foam as a sacrificial template to produce a highly porous, thick electrode with a 3-dimensional conducting pathway. Utilized aluminum foam to create a porous structure while maintaining high active material loading (∼378 mg·cm−2).', 'The authors noted the issue but did not provide a specific solution for synthesizing pure samples. No solution methodology was described.', 'The authors acknowledged the issue but did not provide a specific solution to achieve the correct oxygen content. No solution methodology was described.', 'The authors acknowledged the issue but did not provide a specific solution to achieve the correct oxygen content. No solution methodology was described.', 'Increasing the annealing temperature to 1073 K to eliminate impurity phases and achieve pure spinel phase. Thermal treatment at higher temperatures to promote solid-state reactions and phase purity.', 'Detailed structural investigations using neutron and X-ray diffraction to characterize the disorder and its effects. Rietveld refinement of neutron and X-ray diffraction data, combined with first-principles calculations.', 'Heating under flowing oxygen followed by slow cooling to favor high oxygen and Mn4+ content. Controlled oxygen flow and slow cooling during synthesis.', 'Annealing the powder samples at 1000°C for 50 hours resulted in a significant narrowing of X-ray diffraction lines, indicating improved structural order. High-temperature annealing for extended periods to reduce cationic disorder.', 'Optimized synthesis conditions to induce r ...

# %% [markdown]
# # Using ChatGPT

# %% [markdown]
# Cluster 1: Structural Defects and Disorder
# Challenges related to stacking faults, cation mixing, and other structural imperfections that affect material properties.​
#
# The synthesis of a material free of stacking faults is not possible with the described synthesis routes.
#
# Structural disorder caused by the presence of manganese ions in lithium positions (MnLi) and lithium ions in manganese ones (LiMn).
#
# Powder samples prepared by solid-state reaction showed significant cationic disorder with up to 3% Mn on the Li sites.
#
# Structural defects such as stacking faults and Li/Mn atomic mixing are prevalent in the synthesized material.
#
# At low synthesis temperatures, disordered domains dominate, containing a large number of stacking faults and significant Li/Mn atomic mixing.​
#
# Cluster 2: Impurity Formation
# Challenges involving the formation of unwanted phases or compounds during synthesis that degrade performance.​
#
# Formation of Mn3O4 impurity during synthesis.
#
# Presence of Li2MnO3 impurities in samples with x ≥ 0.75.
#
# Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures.
#
# Presence of MnO second phase in all samples.
#
# Presence of NiO impurity in synthesized sample.
#
# Large batch synthesis resulted in significant fraction of unreacted CuO impurity.
#
# Minor amounts of LiGa5O8 impurity detected in synthesized sample.​
#
# Cluster 3: Cation Ordering and Site Occupancy
# Challenges related to achieving desired cation arrangements within the crystal lattice.​
#
# Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+.
#
# No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+.
#
# No superstructure detected despite strong Mg–Mn chemical contrast.
#
# Extensive Li/Zn cation inversion observed, leading to additional high-frequency bands in IR and Raman spectra.
#
# Achieving a chemically ordered spinel structure at low synthesis temperatures.​
#
# Cluster 4: Oxygen Stoichiometry Issues
# Challenges arising from deviations in oxygen content during synthesis, affecting material properties.​
#
# Correct oxygen content could not be achieved during synthesis.
#
# Oxygen loss during high-temperature quenching at 800°C and 925°C.
#
# Loss of oxygen during synthesis at higher temperatures and longer reaction times.
#
# Reduction of tetravalent Mn above 400°C in air, making it difficult to obtain well-crystallized Mn4+ lithium manganate spinels.​
#
# Cluster 5: Phase Stability and Transformations
# Challenges related to unwanted phase transitions or instability during synthesis or cycling.​
#
# Formation of tetragonal spinel phases during high-temperature synthesis.
#
# Gradual and irreversible structural transformation of orthorhombic LiMnO2 into a spinel-type structure during several discharge-charge cycles.
#
# Irreversible decomposition of the spinel phase occurs between 600°C and 800°C under N2 flow.
#
# Formation of multiphase systems during quenching due to temperature gradients and limited thermal conductivity.​
#
# Cluster 6: Synthesis Conditions and Scalability
# Challenges pertaining to the synthesis process, including temperature requirements and scalability.​
#
# Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure.
#
# Conventional solid-state reaction methods for synthesizing o-LiMnO2 require high temperatures (700–1050 °C) and involve complicated powder preparation routes.
#
# Formation of materials away from the Li2MnO3−Li2NiO3 pseudobinary line during synthesis.
#
# Formation of single-phase Li4Mn5O12 at moderate temperatures is hindered by the rapid decomposition and complete oxidation of MnCO3.​
#
# Cluster 7: Morphological Challenges
# Challenges related to achieving desired particle sizes, shapes, or morphologies.​
#
# Achieving nanorod morphology with consistent size distribution.
#
# Broadening of diffraction profiles dependent on Cr content, indicating structural strain and reduced crystallite size.
#
# Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates.​
#
# Cluster 8: Lithium Content and Distribution
# Challenges concerning lithium stoichiometry and its distribution within the material.​
#
# The lattice parameter of Li4Mn5O12 was found to be sensitive to synthesis temperature due to variations in manganese valence.
#
# The spinel product was lithium-deficient with vacancies on the tetrahedral 8a sites.
#
# The spinel product exhibited vacancies on both tetrahedral and octahedral sites, indicating incomplete reaction and structural defects.
#
# Difficulty in achieving complete lithium extraction beyond the composition Li0.5[Mn2]O4.​
#
# Cluster 9: Analytical and Characterization Limitations
# Challenges stemming from difficulties in characterizing or analyzing the synthesized materials.​
#
# Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4.
#
# Preparation of an extremely thick electrode with high active material loading for neutron diffraction studies.
#
# Small concentration of defects formed by gamma irradiation is difficult to detect in bulk samples using conventional XRD techniques.​
# Zilliz
# +1
# DEV Community
# +1
#
# Cluster 10: Chemical Composition and Substitution Effects
# Challenges arising from elemental substitutions or compositional variations.​
#
# Lattice distortion due to size mismatch between Ru+5 and Mn+3 ions.
#
# Formation of spinel phase during synthesis with increased aluminum substitution.
#
# Non-stoichiometry in the synthesized oxides affects cation distribution and structural properties.
#
# Acid treatment introduced significant amounts of protons, resulting in partial replacement of lithium by hydrogen.

# %% [markdown]
# Generate Sentence Embeddings
# Use a pre-trained model to convert your text data into numerical embeddings:

# %% [markdown]
# # Categorize challenges using Azure Openai API

# %%
# Load environment variables from .env file
import dotenv
dotenv.load_dotenv()

# Set Azure OpenAI credentials
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_EMBEDDING_DEPLOYMENT_NAME = os.getenv("AZURE_EMBEDDING_DEPLOYMENT_NAME") # Deployment name
AZURE_EMBEDDING_MODEL_NAME = os.getenv("AZURE_EMBEDDING_MODEL_NAME")  # Model name
AZURE_EMBEDDING_MODEL_VERSION = os.getenv("AZURE_EMBEDDING_MODEL_VERSION")  # Model version
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")
AZURE_MODEL_DEPLOYMENT_NAME = os.getenv("AZURE_MODEL_DEPLOYMENT_NAME")  # Deployment name

# %%
import os
import json
from langchain_openai import ChatOpenAI, AzureChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

def categorize_challenges(
                       challenge_texts: list,
                       challenge_stage: str = "synthesis",
                       api_key: str = None,  
                       azure: bool = True, 
                       model_name: str = None, 
                       temp: float = 0, 
                       azure_api_version: str = None, 
                       azure_endpoint: str = None) -> json:
    """
    Categorize(cluster) extracted challenges into different categories(clusters).

    Parameters:
        challenges_text (list): List of challenges to categorize.
        api_key (str): OpenAI API key.
        azure (bool): Flag to indicate if Azure OpenAI service should be used.
        model_name (str, optional): The name of the Azure deployment or openai model name. Defaults to None.
        temp (float, optional): The temperature for the model. Defaults to 0.   
        azure_api_version (str, optional): The API version for Azure OpenAI service. Defaults to None.
        azure_endpoint (str, optional): The endpoint for Azure OpenAI service. Defaults to None.
        azure_api_version (str): The API version for Azure OpenAI service. Defaults to None.
        
    Returns:
        json: JSON object containing the the categorized challenges.
    """
    if not azure:
        llm = ChatOpenAI(model_name=model_name or os.getenv("OPENAI_MODEL_NAME"),  # Replace with your OpenAI model name
                         temperature=temp, 
                         openai_api_key=api_key or os.getenv("OPENAI_API_KEY"))
    else:
        llm = AzureChatOpenAI(
            azure_deployment=model_name or os.getenv("AZURE_MODEL_DEPLOYMENT_NAME"),  # Replace with your Azure deployment name
            api_version=azure_api_version or os.getenv("AZURE_OPENAI_API_VERSION"),
            temperature=temp or 0,
            openai_api_key=api_key or os.getenv("AZURE_OPENAI_API_KEY"),
            azure_endpoint=azure_endpoint or os.getenv("AZURE_OPENAI_ENDPOINT")  # Explicitly pass the endpoint
        )

    challenges_prompt = f"""
    A list of challenges related to {challenge_stage} of materials has been provided. Your task is to carefully read the following list of challenges and categorize them into different categories.
    At the same time, try to minimize overlapping between the categories by adding new categories if necessary.
    The categories should be based on the content of the challenges and should not be too broad or too specific.
    The categories should be meaningful and relevant to the challenges provided.
    The challenges are as follows:
    {challenge_texts}

    IMPORTANT:
    - The total number of challenges in the output must match the number provided in the input.
    - Each challenge must appear in the output exactly once, under a single category.
    - If a challenge seems ambiguous or hard to categorize, place it in a category like "Unclear" or "Other" rather than omitting it.
    - Return ONLY the output as a JSON object in the following format:
    
    {{
        "Category 1 label": ["challenge 1", "challenge 2"],
        "Category 2 label": ["challenge 3", "challenge 4"]
    }}
    """
    system_msg = SystemMessage(content="You are a helpful and precise materials scientist. ")
    response = llm.invoke([
    system_msg,
    HumanMessage(content=challenges_prompt)
    ])

    # Separate the JSON part of the response
    try:
        json_start = response.content.index("{")
        json_end = response.content.rindex("}") + 1
        json_str = response.content[json_start:json_end]
    except ValueError:
        raise ValueError("Failed to extract JSON from LLM response. Check the response format.")

    try:
        extracted_output = json.loads(json_str)
    except json.JSONDecodeError as e:
        raise ValueError(f"Failed to parse LLM response as JSON: {json_str}") from e

    return extracted_output

# %%
categorized_challenges = categorize_challenges(challenge_texts=challenge_texts,
                                   api_key=AZURE_OPENAI_API_KEY,
                                   azure=True,
                                   model_name=AZURE_MODEL_DEPLOYMENT_NAME,
                                   temp=0.0,
                                   azure_api_version=AZURE_OPENAI_API_VERSION,
                                   azure_endpoint=AZURE_OPENAI_ENDPOINT)
print("Categories:", categorized_challenges)
print("Num. of categories:", len(categorized_challenges))
# Out:
# Categories: {'Porosity and Connectivity Issues': ["Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance."], 'Cation Ordering Challenges': ['Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.', 'No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. Limits the ability to achieve desired structural properties for specific applications.', 'No superstructure detected despite strong Mg–Mn chemical contrast. Absence of superstructure limits the ability to induce cation ordering, which is critical for optimizing material properties.'], 'Impurity Formation': ['Formation of Mn3O4 impurity during synthesis. The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.', 'Presence of Li2MnO3 impurities in samples with x ≥ 0.75. The impurities are electrochemically inactive, leading to a significant reduction in the rechargeable capacity (Qrech) and energy density (W).', 'Presence of impurity phase (Li2MnO3) in the synthesized sample. The impurity phase directly contributes to capacity loss in battery applications, as lithium extraction from Li2MnO3 is precluded due to the manganese ions already being in the Mn4+ oxidation state.', 'Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.', 'Presence of NiO impurity in synthesized sample. Impurity reduces phase purity, which can negatively affect electrochemical performance and structural integrity.', 'Large batch synthesis resulted in significant fraction of unreacted CuO impurity. Impurity compromises phase purity and structural integrity, affecting material performance.', 'Minor amounts of LiGa5O8 impurity detected in synthesized sample. Impurity reduces phase purity, potentially affecting electrochemical performance and structural stability.'], 'Structural Defects and Disorder': ['The synthesis of a material free of stacking faults is not possible with the described synthesis routes. Stacking faults affect the structural integrity and potentially the performance of the material in its intended applications.', "Structural disorder caused by the presence of manganese ions in lithium positions (MnLi) and lithium ions in manganese ones (LiMn). This disorder affects the material's magnetic properties and contributes to the appearance of weak ferromagnetism, which may hinder its performance as a cathode material.", 'Powder samples prepared by solid-state reaction showed significant cationic disorder with up to 3% Mn on the Li sites. Cationic disorder can negatively affect the structural integrity and magnetic properties of the material, which are critical for its application.', 'Structural defects such as stacking faults and Li/Mn atomic mixing are prevalent in the synthesized material. These defects hinder precise structural analysis and affect the electrochemical behavior of the material.', 'At low synthesis temperatures, disordered domains dominate, containing a large number of stacking faults and significant Li/Mn atomic mixing. Disordered domains promote smooth Li percolation paths but lead to decreased structural order, affecting capacity and performance.', "The spinel product exhibited vacancies on both tetrahedral and octahedral sites, indicating incomplete reaction and structural defects. Structural defects and site vacancies can compromise the material's stability and electrochemical properties."], 'Phase Stability and Transformation': ['Gradual and irreversible str ...
# Num. of categories: 10

# %%
print("name of the categories:", list(categorized_challenges.keys()))
s = 0
for k, v in categorized_challenges.items():
    s += len(v)
print("Num. of challenges in the categories:", s)
# Out:
# name of the categories: ['Porosity and Connectivity Issues', 'Cation Ordering Challenges', 'Impurity Formation', 'Structural Defects and Disorder', 'Phase Stability and Transformation', 'Synthesis Conditions and Optimization', 'Material Purity and Reaction Completion', 'Morphology and Crystallinity Challenges', 'Electrochemical Performance Issues', 'Stoichiometry and Composition Challenges']
# Num. of challenges in the categories: 35

# %%
# TO DO
# Should revise the prompt or itterate to ensure each challenge is assigned to one category

# %% [markdown]
# # Adding category label to each challenge to improve visualization

# %%
challenge_texts_for_embedding = []

for challenge in challenge_texts:
    # find catergory for the challenge from list of categories
    for category, challenges in categorized_challenges.items():
        if challenge in challenges:
            
            # append the challenge text and category to the list
            category_challenge = f"{category}: {challenge}"
            challenge_texts_for_embedding.append(category_challenge)

print(challenge_texts_for_embedding)
# Out:
# ["Porosity and Connectivity Issues: Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance.", 'Cation Ordering Challenges: Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.', 'Cation Ordering Challenges: No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. Limits the ability to achieve desired structural properties for specific applications.', 'Impurity Formation: Formation of Mn3O4 impurity during synthesis. The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.', 'Structural Defects and Disorder: The synthesis of a material free of stacking faults is not possible with the described synthesis routes. Stacking faults affect the structural integrity and potentially the performance of the material in its intended applications.', "Phase Stability and Transformation: Formation of tetragonal spinel phases during high-temperature synthesis. The tetragonal distortion affects the material's stability and electrochemical performance, which is critical for its application in lithium-ion batteries.", "Morphology and Crystallinity Challenges: Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4. The lack of high-quality single crystals hinders precise structural investigations and understanding of the material's properties.", 'Synthesis Conditions and Optimization: Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure. Deviation from optimal conditions can lead to the formation of multiple phases or incomplete reactions, compromising material properties.', 'Impurity Formation: Presence of Li2MnO3 impurities in samples with x ≥ 0.75. The impurities are electrochemically inactive, leading to a significant reduction in the rechargeable capacity (Qrech) and energy density (W).', 'Phase Stability and Transformation: Gradual and irreversible structural transformation of orthorhombic LiMnO2 into a spinel-type structure during several discharge-charge cycles. This structural change is generally unfavorable for practical applications as it affects the stability and performance of the electrode material.', "Material Purity and Reaction Completion: Attempts to prepare pure samples of CuMn2O4 were unsuccessful. The inability to synthesize pure samples limits the ability to study the material's properties and applications.", "Synthesis Conditions and Optimization: Correct oxygen content could not be achieved during synthesis. Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.", "Synthesis Conditions and Optimization: Correct oxygen content could not be achieved during synthesis. Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.", 'Impurity Formation: Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.', "Structural Defects and Disorder: Structural disorder caused by the presence of manganese ions in lithium positions (MnLi) and lithium ions in manganese ones (LiMn). This disorder affects the material's magnetic properties and contributes to the appearance of weak ferromagnetism, which may hinder its performance as a cathode material.", 'Structural Defects and Disorder: Powder samples prepared by solid-state reaction showed significant cationic disorder with up to 3% Mn on the  ...

# %%
import openai
from openai import AzureOpenAI

# Setup Azure client (new SDK structure)
client = AzureOpenAI(
    api_key=AZURE_OPENAI_API_KEY,
    api_version=AZURE_OPENAI_API_VERSION,
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
)

# Embedding function using the new SDK
def get_embeddings(texts, deployment_name):
    embeddings = []
    for text in texts:
        response = client.embeddings.create(
            input=text,
            model=deployment_name,  # Must match your Azure deployment name
        )
        embeddings.append(response.data[0].embedding)
    return embeddings

# %%
challenge_texts_for_embedding, len(challenge_texts_for_embedding)
# Out:
# (["Porosity and Connectivity Issues: Solid-state synthesis resulted in high porosity and poor connectivity between well-sintered agglomerates. High porosity and poor connectivity negatively affect the material's electrical conductivity and overall performance.",
#   'Cation Ordering Challenges: Difficulty in achieving long-range cation ordering due to weak electrostatic repulsion between Li+ and Ni2+. Limits the ability to synthesize a long-range ordered phase, which may affect material properties and performance.',
#   'Cation Ordering Challenges: No long-range cation-ordered phase observed despite similar valence states of Sn4+ and Ti4+. Limits the ability to achieve desired structural properties for specific applications.',
#   'Impurity Formation: Formation of Mn3O4 impurity during synthesis. The Mn3O4 impurity degrades the electrochemical performance as it is not electrochemically active in the same voltage range as LiMn2O4.',
#   'Structural Defects and Disorder: The synthesis of a material free of stacking faults is not possible with the described synthesis routes. Stacking faults affect the structural integrity and potentially the performance of the material in its intended applications.',
#   "Phase Stability and Transformation: Formation of tetragonal spinel phases during high-temperature synthesis. The tetragonal distortion affects the material's stability and electrochemical performance, which is critical for its application in lithium-ion batteries.",
#   "Morphology and Crystallinity Challenges: Difficulty in synthesizing high-quality single crystals of spinel-type LiMn2O4. The lack of high-quality single crystals hinders precise structural investigations and understanding of the material's properties.",
#   'Synthesis Conditions and Optimization: Formation of single-phase spinels requires precise synthesis conditions, including temperature and oxygen partial pressure. Deviation from optimal conditions can lead to the formation of multiple phases or incomplete reactions, compromising material properties.',
#   'Impurity Formation: Presence of Li2MnO3 impurities in samples with x ≥ 0.75. The impurities are electrochemically inactive, leading to a significant reduction in the rechargeable capacity (Qrech) and energy density (W).',
#   'Phase Stability and Transformation: Gradual and irreversible structural transformation of orthorhombic LiMnO2 into a spinel-type structure during several discharge-charge cycles. This structural change is generally unfavorable for practical applications as it affects the stability and performance of the electrode material.',
#   "Material Purity and Reaction Completion: Attempts to prepare pure samples of CuMn2O4 were unsuccessful. The inability to synthesize pure samples limits the ability to study the material's properties and applications.",
#   "Synthesis Conditions and Optimization: Correct oxygen content could not be achieved during synthesis. Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.",
#   "Synthesis Conditions and Optimization: Correct oxygen content could not be achieved during synthesis. Incorrect oxygen content leads to the presence of Mn3+ ions, which affects the material's stoichiometry and magnetic properties.",
#   'Impurity Formation: Formation of impurity phases such as manganese oxides (Mn2O3 and Mn5O8) during synthesis at lower annealing temperatures. Impurity phases reduce the purity of the spinel phase, affecting its structural and functional properties.',
#   "Structural Defects and Disorder: Structural disorder caused by the presence of manganese ions in lithium positions (MnLi) and lithium ions in manganese ones (LiMn). This disorder affects the material's magnetic properties and contributes to the appearance of weak ferromagnetism, which may hinder its performance as a cathode material.",
#   'Structural Defects and Disorder: Powder samples prepared by solid-state reaction showed significant cationic disorder with up to 3% Mn on the Li sites. Cationic disorder can negatively affect the structural integrity and magnetic properties of the material, which are critical for its application.',
#   'Electrochemical Performance Issues: Broadening of diffraction profiles dependent on Cr content, indicating structural strain and reduced crystallite size. Reduced crystallite size increases surface area, which can lead to Mn dissolution and negatively affect cycle performance.',
#   'Morphology and Crystallinity Challenges: Difficulty in synthesizing high-quality single crystals of LiMn2O4. Poor quality single crystals hinder accurate structural and physical property investigations.',
#   'Impurity Formation: Presence of impurity phase (Li2MnO3) in the synthesized sample. The impurity phase directly contributes to capacity loss in battery applications, as lithium extraction from Li2MnO3 is precluded due to the manganese ions already being in the Mn4+ oxidation state.',
#   'Synthesis Conditions and Optimization: Formation of multiphase systems during quenching due to temperature gradients and limited thermal conductivity. Multiphase systems complicate structural analysis and reduce sample homogeneity.',
#   'Synthesis Conditions and Optimization: The synthesis of orthorhombic LiMnO2 cannot be performed under air due to its reaction with oxygen, leading to the formation of undesired phases like Li2MnO3 and LiMn2O4. This reaction compromises the purity and stoichiometry of the desired LiMnO2 phase, affecting its structural and electrochemical properties.',
#   'Structural Defects and Disorder: Structural defects such as stacking faults and Li/Mn atomic mixing are prevalent in the synthesized material. These defects hinder precise structural analysis and affect the electrochemical behavior of the material.',
#   'Structural Defects and Disorder: At low synthesis temperatures, disordered domains dominate, containing a large number of stacking faults and significant Li/Mn atomic mixing. Disordered domains promote smooth Li percolation paths but lead to decreased structural order, affecting capacity and performance.',
#   'Electrochemical Performance Issues: Determining the optimal Co3O4 coating amount for enhanced electrochemical performance. Excessive Co3O4 coating adversely affects electrochemical performance, while insufficient coating fails to provide adequate protection.',
#   'Synthesis Conditions and Optimization: Loss of oxygen during synthesis at higher temperatures and longer reaction times. Oxygen loss alters the stoichiometry and stability of the material, potentially degrading its electrochemical properties.',
#   'Phase Stability and Transformation: Irreversible decomposition of the spinel phase occurs between 600°C and 800°C under N2 flow. This decomposition leads to the formation of Mn3O4 and orthorhombic LiMnO2 phases, which compromises the stability and integrity of the spinel structure.',
#   'Material Purity and Reaction Completion: Incomplete reaction when using lower valent manganese oxides or larger amounts of material. Incomplete reaction leads to impurities and affects the purity and structural integrity of the synthesized material.',
#   "Stoichiometry and Composition Challenges: Non-stoichiometry in the synthesized oxides affects cation distribution and structural properties. Non-stoichiometry leads to deviations in cation distribution, which can alter the material's structural integrity and its intended application.",
#   'Cation Ordering Challenges: No superstructure detected despite strong Mg–Mn chemical contrast. Absence of superstructure limits the ability to induce cation ordering, which is critical for optimizing material properties.',
#   'Impurity Formation: Presence of NiO impurity in synthesized sample. Impurity reduces phase purity, which can negatively affect electrochemical performance and structural integrity.',
#   'Impurity Formation: Large batch synthesis resulted in significant fraction of unreacted CuO impurity. Impurity compromises phase purity and structural integrity, affecting material performance.',
#   'Impurity Formation: Minor amounts of LiGa5O8 impurity detected in synthesized sample. Impurity reduces phase purity, potentially affecting electrochemical performance and structural stability.',
#   "Structural Defects and Disorder: The spinel product exhibited vacancies on both tetrahedral and octahedral sites, indicating incomplete reaction and structural defects. Structural defects and site vacancies can compromise the material's stability and electrochemical properties.",
#   "Material Purity and Reaction Completion: Low-temperature solid-state reaction consistently yielded products containing traces of unreacted lithium carbonate and/or manganese dioxide, broad X-ray reflections, and a manganese oxidation state much lower than the theoretical value of 4.0. The presence of unreacted reagents and broad reflections indicates incomplete reaction and poor crystallinity, which negatively affects the material's properties and performance.",
#   "Stoichiometry and Composition Challenges: Acid treatment introduced significant amounts of protons, resulting in partial replacement of lithium by hydrogen and altering the stoichiometry. The proton exchange affects the material's composition and structural stability, potentially impacting its electrochemical performance.",
#   'Morphology and Crystallinity Challenges: Achieving nanorod morphology with consistent size distribution. Increased size of nanorods due to high-temperature synthesis conditions may reduce surface area and catalytic activity.'],
#  36)

# %%
# Plot the pie chart
# Count the number of challenges in each category
category_counts = {category: len(challenges) for category, challenges in categorized_challenges.items()}
import matplotlib.pyplot as plt
plt.pie(category_counts.values(), labels=category_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.title("Distribution of Challenges Across Categories")
plt.show()

# %%
len(challenge_texts), len(solution_texts), len(challenge_texts_for_embedding), len(embeddings)

# get the embeddings for the challenges
challenges_embeddings = get_embeddings(challenge_texts_for_embedding, AZURE_EMBEDDING_DEPLOYMENT_NAME)

# %%
# dimesional reduction using umap
import umap
import numpy as np
import matplotlib.pyplot as plt


# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)

# Convert the list of embeddings to a NumPy array
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=42)
reduced_vectors_umap = reducer.fit_transform(challenges_embeddings)
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Legend, LegendItem
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20
import pandas as pd

# Prepare the data
challenge_df = pd.DataFrame({
    "x": reduced_vectors_umap[:, 0],
    "y": reduced_vectors_umap[:, 1],
    "challenge_text": [c.split(':')[1] for c in challenge_texts_for_embedding],
    "category": [c.split(':')[0] for c in challenge_texts_for_embedding]
})

source = ColumnDataSource(challenge_df)
unique_categories = challenge_df["category"].unique().tolist()
palette = Category20[len(unique_categories)]
color_map = factor_cmap("category", palette=palette, factors=unique_categories)

# Create a square Bokeh figure
p = figure(title="2D Visualization of Challenges",
           x_axis_label="UMAP Dimension 1",
           y_axis_label="UMAP Dimension 2",
           tools="pan,wheel_zoom,box_zoom,reset,save",
           width=900, height=500)  # Keep plot square

# Create custom legend items by rendering each category separately
legend_items = []
for i, category in enumerate(unique_categories):
    color = palette[i]
    category_df = challenge_df[challenge_df["category"] == category]
    category_source = ColumnDataSource(category_df)
    renderer = p.scatter("x", "y", source=category_source, size=10, color=color, alpha=0.8)
    legend_items.append(LegendItem(label=category, renderers=[renderer]))

# Add hover tool
hover = HoverTool(tooltips=[("Challenge", "@challenge_text"), ("Category", "@category")],
                  point_policy="follow_mouse")
p.add_tools(hover)

# Add the legend outside the plot
legend = Legend(items=legend_items, title="Categories", click_policy="hide")
p.add_layout(legend, 'right')  # Place legend outside but still part of plot layout

# Show plot
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c7bcf30a-5831-4628-bee4-28c21fb55268">Loading BokehJS ...</span>
#     </div>
#   <div id="f5832168-4d55-46cf-874b-735e60f3008e" data-root-id="p33619" style="display: contents;"></div>

# %%
len(challenge_texts_for_embedding)
# Out:
# 36

# %% [markdown]
# # Catergorizing the solutions

# %%
import os
import json
from langchain_openai import ChatOpenAI, AzureChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

def categorize_solutions(
                       solution_texts: list,
                       challenge_stage: str = "synthesis",
                       api_key: str = None,  
                       azure: bool = True, 
                       model_name: str = None, 
                       temp: float = 0, 
                       azure_api_version: str = None, 
                       azure_endpoint: str = None) -> json:
    """
    Categorize extracted solutions into different categories.

    Parameters:
        solution_texts (list): List of solutions to categorize.
        api_key (str): OpenAI API key.
        azure (bool): Flag to indicate if Azure OpenAI service should be used.
        model_name (str, optional): The name of the Azure deployment or openai model name. Defaults to None.
        temp (float, optional): The temperature for the model. Defaults to 0.   
        azure_api_version (str, optional): The API version for Azure OpenAI service. Defaults to None.
        azure_endpoint (str, optional): The endpoint for Azure OpenAI service. Defaults to None.
        azure_api_version (str): The API version for Azure OpenAI service. Defaults to None.
        
    Returns:
        json: JSON object containing the the categorized solutions.
    """
    if not azure:
        llm = ChatOpenAI(model_name=model_name or os.getenv("OPENAI_MODEL_NAME"),  # Replace with your OpenAI model name
                         temperature=temp, 
                         openai_api_key=api_key or os.getenv("OPENAI_API_KEY"))
    else:
        llm = AzureChatOpenAI(
            azure_deployment=model_name or os.getenv("AZURE_MODEL_DEPLOYMENT_NAME"),  # Replace with your Azure deployment name
            api_version=azure_api_version or os.getenv("AZURE_OPENAI_API_VERSION"),
            temperature=temp or 0,
            openai_api_key=api_key or os.getenv("AZURE_OPENAI_API_KEY"),
            azure_endpoint=azure_endpoint or os.getenv("AZURE_OPENAI_ENDPOINT")  # Explicitly pass the endpoint
        )

    solution_prompt = f"""
    A list of solutions related to {challenge_stage} of materials has been provided. Your task is to carefully read the following list of solutions and categorize them into different categories.
    At the same time, try to minimize overlapping between the categories by adding new categories if necessary.
    The categories should be based on the content of the solutions and should not be too broad or too specific.
    The categories should be meaningful and relevant to the solutions provided.
    Ensure that each solution is assigned to one and only one category.

    The solutions are as follows:
    {solution_texts}


    ### Output:
    Select a label for each category. Return ONLY the output as JSON object.
    The dictionary should have the following format:
    example:
    {{
        "Category 1 label": ["solution 1", "solution 2"],
        "Category 2 label": ["solution 3", "solution 4"]
    }}
    """
    system_msg = SystemMessage(content="You are a helpful and precise materials scientist. ")
    response = llm.invoke([
    system_msg,
    HumanMessage(content=solution_prompt)
    ])

    # Separate the JSON part of the response
    try:
        json_start = response.content.index("{")
        json_end = response.content.rindex("}") + 1
        json_str = response.content[json_start:json_end]
    except ValueError:
        raise ValueError("Failed to extract JSON from LLM response. Check the response format.")

    try:
        extracted_output = json.loads(json_str)
    except json.JSONDecodeError as e:
        raise ValueError(f"Failed to parse LLM response as JSON: {json_str}") from e

    return extracted_output

# %%
categorized_solutions = categorize_solutions(solution_texts=solution_texts,
                                   api_key=AZURE_OPENAI_API_KEY,
                                   azure=True,
                                   model_name=AZURE_MODEL_DEPLOYMENT_NAME,
                                   temp=0.0,
                                   azure_api_version=AZURE_OPENAI_API_VERSION,
                                   azure_endpoint=AZURE_OPENAI_ENDPOINT)
print("Categories:", categorized_solutions)
print("Num. of categories:", len(categorized_solutions))
# Out:
# Categories: {'Sol-Gel and Wet-Chemical Methods': ['Used the Pechini method to prepare denser samples with better connectivity. Synthesized samples using a precursor gel method involving citric acid and ethylene glycol, followed by calcination and sintering.', 'Controlled aluminum substitution to balance charge and minimize spinel phase formation. Optimization of stoichiometric ratios and synthesis conditions using the sol–gel Pechini method.', 'Use of carboxylic acids (citric and succinic acid) as fuels to assist in decomposition of metal complexes at low temperatures. Carboxylic acid-assisted wet-chemical synthesis with heating above 400°C.'], 'Annealing and Thermal Treatments': ['Proposed annealing at lower temperatures for very long durations or using low-temperature soft synthetic methods. Extended annealing and alternative synthesis routes.', 'Increasing the synthesis temperature reduces the degree of disorder and stacking faults. Higher annealing temperatures were used during synthesis to improve crystallinity and reduce stacking faults.', 'Increasing the annealing temperature to 1073 K to eliminate impurity phases and achieve pure spinel phase. Thermal treatment at higher temperatures to promote solid-state reactions and phase purity.', 'Annealing the powder samples at 1000°C for 50 hours resulted in a significant narrowing of X-ray diffraction lines, indicating improved structural order. High-temperature annealing for extended periods to reduce cationic disorder.', 'Heating under flowing oxygen followed by slow cooling to favor high oxygen and Mn4+ content. Controlled oxygen flow and slow cooling during synthesis.', 'Increasing synthesis temperature above 770°C reduces disordered domains and promotes the formation of ordered crystalline domains. Heat treatment at higher temperatures to transition from disordered to ordered domains.'], 'Flux Growth and Controlled Cooling': ['A flux growth method was employed using a mixture of LiMn2O4 powder and lithium chloride in a sealed gold tube, heated at 1173 K for 10 days and gradually cooled to 297 K. Flux growth method with controlled heating and cooling in a sealed gold tube.', 'Use of LiCl as a flux material with a controlled evaporation speed at high temperatures. Solvent evaporation flux method with a nominal weight ratio of LiMn2O4:LiCl = 1:8, heated at 1173 K for 10 days in a covered gold crucible.', 'Rapid quenching in solid CO2 after high-temperature synthesis. Cooling the samples quickly to preserve the high-temperature valence of manganese and avoid structural distortions.'], 'Atmospheric Control During Synthesis': ['The synthesis was performed under an inert gas (argon) or a mildly reducing atmosphere (nitrogen mixed with hydrogen). Controlled atmospheric conditions during synthesis to prevent unwanted reactions with oxygen.', 'Strictly controlled reaction conditions to prevent oxygen loss. Maintaining synthesis temperature at 400°C and limiting reaction time to five hours.', 'The authors suggest controlling the oxygen partial pressure during synthesis to stabilize the spinel phase. Using air or O2 atmospheres instead of N2 during thermal treatments.', 'Adjusting the O2 flow rate during the synthesis process to control the composition and cation distribution. Varying the O2 flow rate between 100 ml/min and 200 ml/min during annealing at 875°C.'], 'Solid-State Reactions and Doping': ['Optimized synthesis conditions to induce redox interaction between Ru+4 and Mn+4, resulting in mixed valence states. High-temperature solid-state reaction and doping Ru+4 at Mn+4 sites.', 'Substitutionally doping manganese with titanium. Solid-state reaction with controlled firing temperature and substitution of manganese with titanium.', 'Careful control of precursor ratios and synthesis conditions, including milling, drying, pelletizing, and annealing steps. Solid-state reaction with precise molar ratios, controlled heating and cooling rates, and repeated pelletizing and annealing.'], ...
# Num. of categories: 12

# %%
# Plot the pie chart
# Count the number of solutions in each category
category_counts = {category: len(solutions) for category, solutions in categorized_solutions.items()}
import matplotlib.pyplot as plt
plt.pie(category_counts.values(), labels=category_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.title("Distribution of Solutions Across Categories")
plt.show()

# %% [markdown]
# # Visualizing solutions

# %%
solution_texts_for_embedding = []

for solution in solution_texts:
    # find catergory for the solution from list of categories
    for category, solutions in categorized_solutions.items():
        if solution in solutions:

            # append the solution text and category to the list
            category_solution = f"{category}: {solution}"
            solution_texts_for_embedding.append(category_solution)

print(solution_texts_for_embedding)
# Out:
# ['Sol-Gel and Wet-Chemical Methods: Used the Pechini method to prepare denser samples with better connectivity. Synthesized samples using a precursor gel method involving citric acid and ethylene glycol, followed by calcination and sintering.', 'Annealing and Thermal Treatments: Proposed annealing at lower temperatures for very long durations or using low-temperature soft synthetic methods. Extended annealing and alternative synthesis routes.', 'Structural Refinement and Characterization: Refined short-range structure to confirm full cation ordering within one-unit cell length. Local structure refinement using neutron PDF data.', 'Annealing and Thermal Treatments: Increasing the synthesis temperature reduces the degree of disorder and stacking faults. Higher annealing temperatures were used during synthesis to improve crystallinity and reduce stacking faults.', 'Flux Growth and Controlled Cooling: Rapid quenching in solid CO2 after high-temperature synthesis. Cooling the samples quickly to preserve the high-temperature valence of manganese and avoid structural distortions.', 'Flux Growth and Controlled Cooling: A flux growth method was employed using a mixture of LiMn2O4 powder and lithium chloride in a sealed gold tube, heated at 1173 K for 10 days and gradually cooled to 297 K. Flux growth method with controlled heating and cooling in a sealed gold tube.', 'Optimization of Composition and Stoichiometry: Optimization of the Co/Mn ratio to x = 0.5, which avoids the formation of Li2MnO3 impurities. Systematic variation of x in the LiCoxMn2−xO4 composition and structural analysis using XRD and Raman spectroscopy.', 'Electrochemical Techniques: Electrochemically generated spinel electrodes were found to exhibit significantly better and more stable charge-discharge cycle characteristics compared to regular spinel-type LiMn2O4 electrodes. Utilization of electrochemical cycling to stabilize the spinel structure and improve its performance.', 'Template-Assisted and Porous Structures: A novel methodology was developed using aluminum foam as a sacrificial template to produce a highly porous, thick electrode with a 3-dimensional conducting pathway. Utilized aluminum foam to create a porous structure while maintaining high active material loading (∼378 mg·cm−2).', 'Unspecified or No Solution Provided: The authors noted the issue but did not provide a specific solution for synthesizing pure samples. No solution methodology was described.', 'Unspecified or No Solution Provided: The authors acknowledged the issue but did not provide a specific solution to achieve the correct oxygen content. No solution methodology was described.', 'Unspecified or No Solution Provided: The authors acknowledged the issue but did not provide a specific solution to achieve the correct oxygen content. No solution methodology was described.', 'Annealing and Thermal Treatments: Increasing the annealing temperature to 1073 K to eliminate impurity phases and achieve pure spinel phase. Thermal treatment at higher temperatures to promote solid-state reactions and phase purity.', 'Structural Refinement and Characterization: Detailed structural investigations using neutron and X-ray diffraction to characterize the disorder and its effects. Rietveld refinement of neutron and X-ray diffraction data, combined with first-principles calculations.', 'Annealing and Thermal Treatments: Heating under flowing oxygen followed by slow cooling to favor high oxygen and Mn4+ content. Controlled oxygen flow and slow cooling during synthesis.', 'Annealing and Thermal Treatments: Annealing the powder samples at 1000°C for 50 hours resulted in a significant narrowing of X-ray diffraction lines, indicating improved structural order. High-temperature annealing for extended periods to reduce cationic disorder.', 'Solid-State Reactions and Doping: Optimized synthesis conditions to induce redox interaction between Ru+4 and Mn+4, resulting in mixed valence states. High-temperature solid-state r ...

# %%
solution_texts_for_embedding, len(solution_texts_for_embedding)
# Out:
# (['Sol-Gel and Wet-Chemical Methods: Used the Pechini method to prepare denser samples with better connectivity. Synthesized samples using a precursor gel method involving citric acid and ethylene glycol, followed by calcination and sintering.',
#   'Annealing and Thermal Treatments: Proposed annealing at lower temperatures for very long durations or using low-temperature soft synthetic methods. Extended annealing and alternative synthesis routes.',
#   'Structural Refinement and Characterization: Refined short-range structure to confirm full cation ordering within one-unit cell length. Local structure refinement using neutron PDF data.',
#   'Annealing and Thermal Treatments: Increasing the synthesis temperature reduces the degree of disorder and stacking faults. Higher annealing temperatures were used during synthesis to improve crystallinity and reduce stacking faults.',
#   'Flux Growth and Controlled Cooling: Rapid quenching in solid CO2 after high-temperature synthesis. Cooling the samples quickly to preserve the high-temperature valence of manganese and avoid structural distortions.',
#   'Flux Growth and Controlled Cooling: A flux growth method was employed using a mixture of LiMn2O4 powder and lithium chloride in a sealed gold tube, heated at 1173 K for 10 days and gradually cooled to 297 K. Flux growth method with controlled heating and cooling in a sealed gold tube.',
#   'Optimization of Composition and Stoichiometry: Optimization of the Co/Mn ratio to x = 0.5, which avoids the formation of Li2MnO3 impurities. Systematic variation of x in the LiCoxMn2−xO4 composition and structural analysis using XRD and Raman spectroscopy.',
#   'Electrochemical Techniques: Electrochemically generated spinel electrodes were found to exhibit significantly better and more stable charge-discharge cycle characteristics compared to regular spinel-type LiMn2O4 electrodes. Utilization of electrochemical cycling to stabilize the spinel structure and improve its performance.',
#   'Template-Assisted and Porous Structures: A novel methodology was developed using aluminum foam as a sacrificial template to produce a highly porous, thick electrode with a 3-dimensional conducting pathway. Utilized aluminum foam to create a porous structure while maintaining high active material loading (∼378 mg·cm−2).',
#   'Unspecified or No Solution Provided: The authors noted the issue but did not provide a specific solution for synthesizing pure samples. No solution methodology was described.',
#   'Unspecified or No Solution Provided: The authors acknowledged the issue but did not provide a specific solution to achieve the correct oxygen content. No solution methodology was described.',
#   'Unspecified or No Solution Provided: The authors acknowledged the issue but did not provide a specific solution to achieve the correct oxygen content. No solution methodology was described.',
#   'Annealing and Thermal Treatments: Increasing the annealing temperature to 1073 K to eliminate impurity phases and achieve pure spinel phase. Thermal treatment at higher temperatures to promote solid-state reactions and phase purity.',
#   'Structural Refinement and Characterization: Detailed structural investigations using neutron and X-ray diffraction to characterize the disorder and its effects. Rietveld refinement of neutron and X-ray diffraction data, combined with first-principles calculations.',
#   'Annealing and Thermal Treatments: Heating under flowing oxygen followed by slow cooling to favor high oxygen and Mn4+ content. Controlled oxygen flow and slow cooling during synthesis.',
#   'Annealing and Thermal Treatments: Annealing the powder samples at 1000°C for 50 hours resulted in a significant narrowing of X-ray diffraction lines, indicating improved structural order. High-temperature annealing for extended periods to reduce cationic disorder.',
#   'Solid-State Reactions and Doping: Optimized synthesis conditions to induce redox interaction between Ru+4 and Mn+4, resulting in mixed valence states. High-temperature solid-state reaction and doping Ru+4 at Mn+4 sites.',
#   'Flux Growth and Controlled Cooling: Use of LiCl as a flux material with a controlled evaporation speed at high temperatures. Solvent evaporation flux method with a nominal weight ratio of LiMn2O4:LiCl = 1:8, heated at 1173 K for 10 days in a covered gold crucible.',
#   'Structural Refinement and Characterization: Two-phase Rietveld refinement was used to identify and quantify the impurity phase. Neutron powder diffraction and Rietveld refinement techniques were applied to refine the structure and quantify the impurity phase.',
#   'Structural Refinement and Characterization: Structural refinements were performed to understand the mechanism of oxygen loss and its impact on the spinel lattice. Neutron powder diffraction and Rietveld refinement techniques were used to analyze site occupancies and atomic displacement parameters.',
#   'Electrochemical Techniques: Electrochemical extraction was attempted at low current rates. Electrochemical techniques with controlled current rates.',
#   'Solid-State Reactions and Doping: Substitutionally doping manganese with titanium. Solid-state reaction with controlled firing temperature and substitution of manganese with titanium.',
#   'Hydrothermal and Low-Temperature Methods: A low-temperature hydrothermal approach using fine Mn3O4 and aqueous LiOH solution was developed to synthesize o-LiMnO2 at 170 °C. Hydrothermal treatment with controlled LiOH concentration and temperature conditions.',
#   'Atmospheric Control During Synthesis: The synthesis was performed under an inert gas (argon) or a mildly reducing atmosphere (nitrogen mixed with hydrogen). Controlled atmospheric conditions during synthesis to prevent unwanted reactions with oxygen.',
#   'Annealing and Thermal Treatments: Increasing synthesis temperature above 770°C reduces disordered domains and promotes the formation of ordered crystalline domains. Heat treatment at higher temperatures to transition from disordered to ordered domains.',
#   'Characterization Techniques: Advanced characterization techniques such as HRTEM and 7Li MAS NMR were employed to detect and analyze defects. High-resolution transmission electron microscopy and nuclear magnetic resonance spectroscopy were used to study local structural changes and defect formation.',
#   'Atmospheric Control During Synthesis: Strictly controlled reaction conditions to prevent oxygen loss. Maintaining synthesis temperature at 400°C and limiting reaction time to five hours.',
#   'Atmospheric Control During Synthesis: The authors suggest controlling the oxygen partial pressure during synthesis to stabilize the spinel phase. Using air or O2 atmospheres instead of N2 during thermal treatments.',
#   'Atmospheric Control During Synthesis: Adjusting the O2 flow rate during the synthesis process to control the composition and cation distribution. Varying the O2 flow rate between 100 ml/min and 200 ml/min during annealing at 875°C.',
#   'Characterization Techniques: FTIR spectrum confirmed the absence of additional vibration bands, indicating that octahedral composition alone is insufficient to induce cation ordering. FTIR spectroscopy analysis of vibration modes.',
#   'Structural Refinement and Characterization: Rietveld refinement and spectroscopic analysis identified the cation distribution and its impact on structural symmetry. Rietveld refinement and IR/Raman spectroscopy.',
#   'Structural Refinement and Characterization: Rietveld refinement included NiO impurity in structural analysis to improve statistical accuracy. Rietveld refinement of neutron diffraction data.',
#   'Structural Refinement and Characterization: Impurities were accounted for in subsequent Rietveld refinements to improve structural analysis. Rietveld refinement of neutron diffraction data.',
#   'Structural Refinement and Characterization: Impurity was included in Rietveld refinement to improve structural characterization. Rietveld refinement of X-ray diffraction data.',
#   'Solid-State Reactions and Doping: Careful control of precursor ratios and synthesis conditions, including milling, drying, pelletizing, and annealing steps. Solid-state reaction with precise molar ratios, controlled heating and cooling rates, and repeated pelletizing and annealing.',
#   'Optimization of Composition and Stoichiometry: The composition was adjusted to account for lithium deficiency by introducing vacancies in the octahedral sites and increasing the manganese-to-lithium ratio. Structural refinement based on neutron diffraction data to approximate the expected stoichiometry.',
#   'Optimization of Composition and Stoichiometry: The composition was refined to account for vacancies and adjusted to approximate the expected stoichiometry. Neutron diffraction analysis and structural refinement to determine site occupancy and adjust composition.',
#   'Characterization Techniques: Used iodometric redox titration to quantify Fe4+ content and proceeded with further characterization. Chemical titration and analysis techniques.',
#   "Characterization Techniques: Thermogravimetric analysis confirmed the presence of protons and their bonding nature, allowing characterization of the altered stoichiometry. Thermogravimetric analysis in oxygen was used to quantify proton content and understand its impact on the material's structure.",
#   'Hydrothermal and Low-Temperature Methods: Synthesis performed at 280°C, significantly lower than conventional temperatures (400–700°C). Low-temperature solid-state reaction using γ-MnOOH precursor.',
#   'Hydrothermal and Low-Temperature Methods: Optimization of synthesis temperature and precursor treatment. γ-MnOOH precursor treated at 300°C for 3 hours, followed by heat treatment at 750°C for 10 hours.',
#   'Sol-Gel and Wet-Chemical Methods: Controlled aluminum substitution to balance charge and minimize spinel phase formation. Optimization of stoichiometric ratios and synthesis conditions using the sol–gel Pechini method.',
#   'Sol-Gel and Wet-Chemical Methods: Use of carboxylic acids (citric and succinic acid) as fuels to assist in decomposition of metal complexes at low temperatures. Carboxylic acid-assisted wet-chemical synthesis with heating above 400°C.'],
#  43)

# %%
# get the embeddings for the solutions
solutions_embeddings = get_embeddings(solution_texts_for_embedding, AZURE_EMBEDDING_DEPLOYMENT_NAME)

# %%
# dimesional reduction using umap
import umap
import numpy as np
import matplotlib.pyplot as plt

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)

# Convert the list of embeddings to a NumPy array
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=42)
reduced_vectors_umap_solutions = reducer.fit_transform(solutions_embeddings)
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool, Legend, LegendItem
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20
import pandas as pd

# Prepare the data
solution_df = pd.DataFrame({
    "x": reduced_vectors_umap_solutions[:, 0],
    "y": reduced_vectors_umap_solutions[:, 1],
    "solution_text": [c.split(':')[1] for c in solution_texts_for_embedding],
    "category": [c.split(':')[0] for c in solution_texts_for_embedding]
})

source = ColumnDataSource(solution_df)
unique_categories = solution_df["category"].unique().tolist()
palette = Category20[len(unique_categories)]
color_map = factor_cmap("category", palette=palette, factors=unique_categories)

# Create a square Bokeh figure
p = figure(title="2D Visualization of Solutions",
           x_axis_label="UMAP Dimension 1",
           y_axis_label="UMAP Dimension 2",
           tools="pan,wheel_zoom,box_zoom,reset,save",
           width=900, height=500)  # Keep plot square
scatter = p.scatter("x", "y", source=source, size=10, color=color_map, alpha=0.8)

# Create custom legend items by rendering each category separately
legend_items = []
for i, category in enumerate(unique_categories):
    color = palette[i]
    category_df = solution_df[solution_df["category"] == category]
    category_source = ColumnDataSource(category_df)
    renderer = p.scatter("x", "y", source=category_source, size=10, color=color, alpha=0.8)
    legend_items.append(LegendItem(label=category, renderers=[renderer]))

# Add hover tool
hover = HoverTool(tooltips=[("Solution", "@solution_text"), ("Category", "@category")],
                  point_policy="follow_mouse")
p.add_tools(hover)

# Add the legend outside the plot
legend = Legend(items=legend_items, title="Categories", click_policy="hide")
p.add_layout(legend, 'right')  # Place legend outside but still part of plot layout

# Show plot
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bdb8b7e4-17b8-464d-9bec-b369cd8725cc">Loading BokehJS ...</span>
#     </div>
#   <div id="ed80d6a4-8053-4813-9085-d5178ffbe1fa" data-root-id="p33819" style="display: contents;"></div>

# %% [markdown]
# # Visualize both challenges and solutions in the same plot

# %%
# Make embeddings for the challenges and solutions
# Make a unify list of challenges and solutions
challenges_and_solutions = challenge_texts + solution_texts
# get the embeddings for the challenges and solutions
challenges_and_solutions_embeddings = get_embeddings(challenges_and_solutions, AZURE_EMBEDDING_DEPLOYMENT_NAME)
# dimesional reduction using umap
import umap
import numpy as np
import matplotlib.pyplot as plt
# Convert the list of embeddings to a NumPy array
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=42)
reduced_vectors_umap = reducer.fit_transform(challenges_and_solutions_embeddings)
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Category20
import pandas as pd
import textwrap



# Prepare the data for challenges and solutions
data = pd.DataFrame({
    "x": reduced_vectors_umap[:, 0],  # First dimension of reduced vectors
    "y": reduced_vectors_umap[:, 1],  # Second dimension of reduced vectors
    "text": challenges_and_solutions,  # Combined text of challenges and solutions
    "type": ["Challenge"] * len(challenge_texts) + ["Solution"] * len(solution_texts)  # Type label
})

# Create a ColumnDataSource for Bokeh
source = ColumnDataSource(data)

# Create a Bokeh figure
p = figure(title="2D Visualization of Challenges and Solutions",
           x_axis_label="UMAP Dimension 1",
           y_axis_label="UMAP Dimension 2",
           tools="pan,wheel_zoom,box_zoom,reset,save",
           width=550, height=500)

# Add scatter points for challenges and solutions
palette = ["#1f77b4", "#ff7f0e"]  # Two colors for challenges and solutions
scatter = p.scatter(x="x", y="y", 
                    source=source, 
                    size=10, 
                    color=factor_cmap("type", palette=palette, 
                                      factors=["Challenge", "Solution"]), 
                                      alpha=0.8, legend_field="type")

# Add lines connecting challenges to their corresponding solutions
for i in range(len(challenge_texts)):
    p.line(
        x=[reduced_vectors_umap[i, 0], reduced_vectors_umap[len(challenge_texts) + i, 0]],
        y=[reduced_vectors_umap[i, 1], reduced_vectors_umap[len(challenge_texts) + i, 1]],
        line_width=1,
        color="gray",
        alpha=0.5
    )

# Add hover tool to display text and type
hover = HoverTool(
    tooltips="""
        <div style="width: 300px;">
            <b>Type:</b> @type<br>
            <b></b><pre style="white-space: pre-wrap;">@text</pre>
        </div>
    """,
    point_policy="follow_mouse",
    renderers=[scatter]
)
p.add_tools(hover)

# Customize the legend
p.legend.title = "Type"
p.legend.location = "top_right"
p.legend.click_policy = "hide"  # Allow toggling visibility of points by type

# Show the plot
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b4398328-6360-4f62-bb97-d21a878a5ff2">Loading BokehJS ...</span>
#     </div>
#   <div id="d25dfe34-3236-44ae-bb10-05ece44b7ef3" data-root-id="p34062" style="display: contents;"></div>

# %%
# with added categories

# Make embeddings for the challenges and solutions
# Make a unify list of challenges and solutions
challenges_and_solutions = challenge_texts_for_embedding + solution_texts_for_embedding
# get the embeddings for the challenges and solutions
challenges_and_solutions_embeddings = get_embeddings(challenges_and_solutions, AZURE_EMBEDDING_DEPLOYMENT_NAME)
# dimesional reduction using umap
import umap
import numpy as np
import matplotlib.pyplot as plt
# Convert the list of embeddings to a NumPy array
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=42)
reduced_vectors_umap = reducer.fit_transform(challenges_and_solutions_embeddings)
# Out:
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/arashkhajeh/.pyenv/versions/3.12.0/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Category20
import pandas as pd
import textwrap



# Prepare the data for challenges and solutions
data = pd.DataFrame({
    "x": reduced_vectors_umap[:, 0],  # First dimension of reduced vectors
    "y": reduced_vectors_umap[:, 1],  # Second dimension of reduced vectors
    "text": challenges_and_solutions,  # Combined text of challenges and solutions
    "type": ["Challenge"] * len(challenge_texts_for_embedding) + ["Solution"] * len(solution_texts_for_embedding)  # Type label
})

# Create a ColumnDataSource for Bokeh
source = ColumnDataSource(data)

# Create a Bokeh figure
p = figure(title="2D Visualization of Challenges and Solutions",
           x_axis_label="UMAP Dimension 1",
           y_axis_label="UMAP Dimension 2",
           tools="pan,wheel_zoom,box_zoom,reset,save",
           width=550, height=500)

# Add scatter points for challenges and solutions
palette = ["#1f77b4", "#ff7f0e"]  # Two colors for challenges and solutions

scatter = p.scatter(x="x", y="y", 
                    source=source, 
                    size=10, 
                    color=factor_cmap("type", palette=palette, 
                                      factors=["Challenge", "Solution"]), 
                                      alpha=0.8, legend_field="type")

# Add lines connecting challenges to their corresponding solutions
num_challenges = len(challenge_texts_for_embedding)
num_solutions = len(solution_texts_for_embedding)
num_pairs = min(num_challenges, num_solutions, reduced_vectors_umap.shape[0] // 2)

for i in range(num_pairs):
    challenge_idx = i
    solution_idx = num_challenges + i
    if solution_idx < reduced_vectors_umap.shape[0]:
        p.line(
            x=[reduced_vectors_umap[challenge_idx, 0], reduced_vectors_umap[solution_idx, 0]],
            y=[reduced_vectors_umap[challenge_idx, 1], reduced_vectors_umap[solution_idx, 1]],
            line_width=1,
            color="gray",
            alpha=0.5
        )

# Add hover tool to display text and type
hover = HoverTool(
    tooltips="""
        <div style="width: 300px;">
            <b>Type:</b> @type<br>
            <b></b><pre style="white-space: pre-wrap;">@text</pre>
        </div>
    """,
    point_policy="follow_mouse",
    renderers=[scatter]
)
p.add_tools(hover)

# Customize the legend
p.legend.title = "Type"
p.legend.location = "top_right"
p.legend.click_policy = "hide"  # Allow toggling visibility of points by type

# Show the plot
output_notebook()
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e6941a44-7d7a-43a7-ae04-ca3ff4e964b9">Loading BokehJS ...</span>
#     </div>
#   <div id="b8999c65-6966-49ef-a0bd-c813cef34e8a" data-root-id="p34601" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool, TapTool, CustomJS
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20
import pandas as pd

# Prepare the data for challenges and solutions
data = pd.DataFrame({
    "x": reduced_vectors_umap[:, 0],  # First dimension of reduced vectors
    "y": reduced_vectors_umap[:, 1],  # Second dimension of reduced vectors
    "text": challenges_and_solutions,  # Combined text of challenges and solutions
    "type": ["Challenge"] * len(challenge_texts_for_embedding) + ["Solution"] * len(solution_texts_for_embedding),  # Type label
    "index": list(range(len(challenges_and_solutions)))  # Add an index column for filtering
})

# Initialize alpha values in the DataFrame before converting to source
data['alpha'] = [0.8] * len(data)

# Create a ColumnDataSource for Bokeh
source = ColumnDataSource(data)

# Create a Bokeh figure
p = figure(title="2D Visualization of Challenges and Solutions",
           x_axis_label="UMAP Dimension 1",
           y_axis_label="UMAP Dimension 2",
           tools="pan,wheel_zoom,box_zoom,reset,save,tap",
           width=550, height=500)

# Add scatter points for challenges and solutions
palette = ["#1f77b4", "#ff7f0e"]  # Two colors for challenges and solutions
# Create the scatter plot with dynamic alpha

from bokeh.models import Circle

# Set color mapping manually
color_map = factor_cmap("type", palette=palette, factors=["Challenge", "Solution"])

scatter = p.add_glyph(
    source,
    Circle(
        x="x", y="y", radius=0.15,
        fill_color=color_map,
        line_color=color_map,
        fill_alpha="alpha",
        line_alpha="alpha"
    )
)

# Add lines connecting challenges to their corresponding solutions
num_challenges = len(challenge_texts_for_embedding)
num_solutions = len(solution_texts_for_embedding)
num_pairs = min(num_challenges, num_solutions, reduced_vectors_umap.shape[0] // 2)

for i in range(num_pairs):
    challenge_idx = i
    solution_idx = num_challenges + i
    if solution_idx < reduced_vectors_umap.shape[0]:
        p.line(
            x=[reduced_vectors_umap[challenge_idx, 0], reduced_vectors_umap[solution_idx, 0]],
            y=[reduced_vectors_umap[challenge_idx, 1], reduced_vectors_umap[solution_idx, 1]],
            line_width=1,
            color="gray",
            alpha=0.5
        )

# Add hover tool to display text and type
hover = HoverTool(
    tooltips="""
        <div style="width: 300px;">
            <b>Type:</b> @type<br>
            <b></b><pre style="white-space: pre-wrap;">@text</pre>
        </div>
    """,
    point_policy="follow_mouse",
    renderers=[scatter]
)
p.add_tools(hover)

# Add TapTool with a CustomJS callback to filter points
callback = CustomJS(args=dict(source=source, num_challenges=num_challenges), code="""
    const indices = source.selected.indices;
    const data = source.data;
    const selectedIndex = indices[0];  // Get the first selected index

    if (selectedIndex !== undefined) {
        const selectedType = data['type'][selectedIndex];

        // Determine the related index (challenge <-> solution)
        let relatedIndex = null;
        if (selectedType === "Challenge") {
            relatedIndex = selectedIndex + num_challenges;
        } else if (selectedType === "Solution") {
            relatedIndex = selectedIndex - num_challenges;
        }

        // Filter points to show only the selected point and its related point
        for (let i = 0; i < data['x'].length; i++) {
            if (i === selectedIndex || i === relatedIndex) {
                data['alpha'][i] = 0.8;  // Show related points
            } else {
                data['alpha'][i] = 0.1;  // Dim unrelated points
            }
        }
    } else {
        // Reset all points if nothing is selected
        for (let i = 0; i < data['x'].length; i++) {
            data['alpha'][i] = 0.8;
        }
    }

    source.change.emit();
""")

# source.data['alpha'] = [0.8] * len(data)  # Initialize alpha values
# scatter.glyph.fill_alpha = 'alpha'        # Correct binding
# scatter.glyph.line_alpha = 'alpha'  # Bind alpha to the data source
p.add_tools(TapTool(callback=callback))

# Customize the legend
p.legend.title = "Type"
p.legend.location = "top_right"
p.legend.click_policy = "hide"  # Allow toggling visibility of points by type

# Show the plot
output_notebook()
show(p)
# Out:
# /var/folders/p1/_xzph12174z0rlnng642dchm0000gq/T/ipykernel_12739/1372459620.py:120: UserWarning:
#
#
# You are attempting to set `plot.legend.title` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#
# /var/folders/p1/_xzph12174z0rlnng642dchm0000gq/T/ipykernel_12739/1372459620.py:121: UserWarning:
#
#
# You are attempting to set `plot.legend.location` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#
#
# /var/folders/p1/_xzph12174z0rlnng642dchm0000gq/T/ipykernel_12739/1372459620.py:122: UserWarning:
#
#
# You are attempting to set `plot.legend.click_policy` on a plot that has zero legends added, this will have no effect.
#
# Before legend properties can be set, you must add a Legend explicitly, or call a glyph method with a legend parameter set.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d9bdf4f3-872d-4124-bd61-6287ae15d3ce">Loading BokehJS ...</span>
#     </div>
#   <div id="c6d46b00-30af-4450-ba3e-c3a1c2c5b75e" data-root-id="p40259" style="display: contents;"></div>

# %%
# Next steps:

# 1. Map of solutions and challenges during characterization, testing, etc.
# 2. Can we predict a solution for a new challenge based on the neighboring challenges and existing solutions?
# 3. If yes, how confident are we in the predicted solutions? Can we quantify the uncertainty?
# 4. Can we use the embeddings to find similar challenges and solutions in other (similar) materials?

# %%
# Should we change out clustering method so that examples in the same catergory of challenges associate with one category of solutions? How can we do that?
